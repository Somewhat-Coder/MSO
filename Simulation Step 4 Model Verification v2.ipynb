# %% [markdown]
# # Prelude

# %%
import matplotlib.pyplot as plt
import pulp
import math
import random
import pandas as pd
import numpy as np
import simpy

# %% [markdown]
# # Utilities

# %% [markdown]
# ## Points and Distances

# %%
def dist(p1, p2):
    (x1, y1) = p1
    (x2, y2) = p2
    return int(math.sqrt((x1-x2)**2+(y1-y2)**2))

# %% [markdown]
# ## PlotMap

# %%
def label(i):
    return (label(i//26-1)+chr(65+i%26)) if i>25 else chr(65+i)

# %%
def plotMap(G, T=[], P=[], w=None,
            style='r-o', lw=1, ms=3, 
            styleT='go', msT=3,
            styleP='b-o', lwP=2, msP=3,
            stylePT='go', msPT=7,
            styleW='ro', msW=9,
            text=None, grid=False, labels=False, scale=False):

    V, E = G

    def round_down(x, level): return (x//level)*level
    def round_up(x, level): return (x//level+1)*level
    
    xmin = round_down(min([ x for (x, _) in V ]), 100)
    xmax = round_up(max([ x for (x, _) in V ]), 100)
    ymin = round_down(min([ y for (_, y) in V ]), 100)
    ymax = round_up(max([ y for (_, y) in V ]), 100)
    dx = xmax-xmin
    dy = ymax-ymin
    yoffset = (ymax-ymin)//10
    
    fig = plt.gcf()
    fig.set_size_inches(4, 4)
    plt.xlim(xmin, xmax)
    plt.ylim(ymin-yoffset, ymax)
    
    if not grid:
        plt.axis('off')

    for e in E:
        p1, p2 = e
        plt.plot( [ p1[0], p2[0] ],
                  [ p1[1], p2[1] ], 
                  style, lw=lw, ms=ms)
    if scale:
        # plot 1000m scale
        ybar = ymin-0.9*yoffset
        D = [ (xmin, ybar+50), (xmin, ybar), (xmin+1000, ybar), (xmin+1000, ybar+50) ]
        plt.plot( [ d[0] for d in D ], [ d[1] for d in D ], 'k-', lw=0.5)
        plt.text(xmin+500, ymin-0.7*yoffset, '1000m' , horizontalalignment='center', size=8)
    
    if labels:
        for i in range(len(V)):
            x, y = V[i]
            plt.text(x+0.0150*dx, y-0.0350*dy, label(i), size=8)
        
    for t in T:
        plt.plot( [ t[0] ], [ t[1] ], 
                  styleT, ms=msT)
        
    plt.plot( [ p[0] for p in P ],
              [ p[1] for p in P ], 
              styleP, lw=lwP, ms=msP)
    
    for p in P:
        if p in T:
            plt.plot( [ p[0] ], [ p[1] ], 
                      stylePT, ms=msPT)
    if w is not None:
        plt.plot( [ w[0] ], [ w[1] ], 
                      styleW, ms=msW)
    if text is not None:
        plt.text(xmax, ymin-0.7*yoffset, text, horizontalalignment='right', size=8)
    if grid:
        plt.grid()
    plt.show()

# %% [markdown]
# ## Add Targets

# %%
def addTargets(M, T):
    V, E = M
    E = E.copy()
    V = V.copy()
    for t in T:
        minD = math.inf
        minE = None
        for e in E:
            P, Q = e
            distT = dist(P, t)+dist(t, Q)-dist(P, Q)
            if distT < minD:
                minD = distT
                minE = e
        P, Q = minE
        E.remove( (P, Q) )
        E.append( (P, t) )
        E.append( (t, Q) )
        V.append(t)
    return V, E

# %% [markdown]
# ## Generate Central Warehouse Location

# %%
from statistics import median

def generateWarehouseLocation(M):
    V, _ = M
    xc = median([ x for (x, y) in V ])
    yc = median([ y for (x, y) in V ])
    cloc = (xc, yc)
    minloc = V[0]
    mindist = dist(minloc, cloc)
    for i in range(1, len(V)):
        d = dist(V[i], cloc)
        if d<mindist:
            minloc = V[i]
            mindist = dist(V[i], cloc)
    return minloc

# %% [markdown]
# ## Time Handling (NEW)

# %% [markdown]
# **Convention:** In this project we measure simulation time in seconds. The simulation will start at 0:00. Time related methods will be added as they are needed.

# %% [markdown]
# `timestamp(t)` generates a timestamp string in the form `[dd] hh:mm:ss.d`

# %%
def timestamp(t):
    t = round(t, 1)
    day = int(t)//(24*3600)
    t = t - day*24*3600
    hour = int(t)//3600
    t = t - hour*3600
    mins = int(t)//60
    t = t - mins*60
    secs = int(t)
    t = int(round((t-secs)*10,1)) 
    return f"[{day:2d}] {hour:02d}:{mins:02d}:{secs:02d}.{t:1d}"

# %%
timestamp(24*3600*3+17*3600+615.1)
# Out:
# '[ 3] 17:10:15.1'

# %%
timestamp(24*3600*12+3*3600+122.96)
# Out:
# '[12] 03:02:03.0'

# %%
def day(now):
    return int(now//(24*3600))

# %%
def nextHour(env, hour):
    beginningOfDay = int(env.now//(24*3600))*24*3600
    timeOfDay = env.now-beginningOfDay
    if hour*3600 > timeOfDay:
        return hour*3600 - timeOfDay
    else:
        return hour*3600 + 24*3600 - timeOfDay

# %% [markdown]
# # Finding Shortest Path (as before)

# %%
def pathLength(P):
    return 0 if len(P)<=1 else \
            dist(P[0], P[1])+pathLength(P[1:])

# %%
def shortestPath(M, A, B):

    def h(p): 
        return pathLength(p)+dist(p[-1],B)
    
    # candidates C are pairs of the path so far and 
    # the heuristic function of that path, 
    # sorted by the heuristic function, as maintained by
    # insert function
    def insert(C, p):
        hp = h(p)
        c = (p, hp)
        for i in range(len(C)):
            if C[i][1]>hp:
                return C[:i]+[c]+C[i:]
        return C+[c]   
        
    V, E = M
    assert(A in V and B in V)    
    C = insert([], [A])

    while len(C)>0:
        # take the first candidate out of the list of candidates
        path, _ = C[0]
        C = C[1:]
        if path[-1]==B:
            return path
        else:
            for (x, y) in E:
                if path[-1]==x and y not in path:
                    C = insert(C, path+[y])
                elif path[-1]==y and x not in path:
                    C = insert(C, path+[x])
    return None

# %% [markdown]
# # Finding Short Delivery Route (as before)

# %% [markdown]
# ## Greedy Algorithm

# %%
def FW(M):
    
    V, E = M

    n = len(V)
    d = [ [ math.inf for j in range(n) ] for i in range(n) ]
    p = [ [ None for j in range(n) ] for i in range(n) ]

    for (A, B) in E:
        a = V.index(A)
        b = V.index(B)
        d[a][b] = d[b][a] = dist(A, B)
        p[a][b] = [A, B]
        p[b][a] = [B, A]
    
    for i in range(n):
        d[i][i] = 0
        p[i][i] = [V[i]]
    
    for k in range(n):
        for i in range(n):
            for j in range(n):
                dk = d[i][k] + d[k][j]
                if d[i][j] > dk:
                    d[i][j] = dk
                    p[i][j] = p[i][k][:-1] + p[k][j]
                    
    return d, p

# %%
def createLoopG(M, T, timing=False):
    
    def makeLoop(L):
        loop = []
        for i in range(len(L)-1):
            A = L[i]
            B = L[i+1]
            a = V.index(A)
            b = V.index(B)
            sub = P[a][b]
            loop += sub if len(loop)==0 else sub[1:]
        return loop
        
    if timing:
        start_time = time.time()
        last_time = time.time()
        
    V, E = M
    D, P = FW(M)   # note these are the distances between all vertices in M (and T)
        
    W = T[0]
    customers = T[1:]
    if len(T)==1:
        L = T
    elif len(T)<=3:
        L = T + [T[0]]
    else:
        L = T[:3]+[T[0]]
        T = T[3:]
        while len(T)>0:
            minExt = math.inf
            minInd = None
            selInd = None
            for k in range(len(T)):
                C = T[k]
                c = V.index(C)
                for i in range(0, len(L)-1):
                    A = L[i]
                    B = L[i+1]
                    a = V.index(A)
                    b = V.index(B)
                    ext = D[a][c] + D[c][b] - D[a][b]
                    if ext<minExt:
                        minExt, minInd, selInd = ext, i+1, k
            L = L[:minInd]+[T[selInd]]+L[minInd:]
            T = T[:selInd]+T[selInd+1:]
            
    if timing:
        print(f"createLoopH:    {time.time()-start_time:6.2f}s")

    return makeLoop(L)

# %% [markdown]
# # Finding Optimal Delivery Route

# %% [markdown]
# ## Iterative Integer Programming

# %%
def createTables(M, T):

    def reverse(P):
        return [ P[-i] for i in range(1,len(P)+1) ]
    
    def index(x, L):
        for i in range(len(L)):
            if x==L[i]: 
                return i
        return None

    n = len(T)
    d = [ [ math.inf for t in T ] for t in T ]
    p = [ [ None for t in T ] for t in T ]
    for i in range(n):
        d[i][i] = 0
        p[i][i] = [ T[i] ]
    for i in range(n):
        for j in range(n):
            if p[i][j] is None:
                s = shortestPath(M, T[i], T[j])
                d[i][j] = d[j][i] = pathLength(s)
                p[i][j] = s
                p[j][i] = reverse(s)
                for m in range(len(s)-1):
                    smi = index(s[m], T)
                    if smi is None:
                        continue
                    for l in range(m+1, len(s)):
                        sli = index(s[l], T)
                        if sli is None:
                            continue  
                        sub = s[m:l+1]
                        if p[smi][sli] is None:
                            p[smi][sli] = sub
                            p[sli][smi] = reverse(sub)
                            d[smi][sli] = d[sli][smi] = pathLength(sub)
    return d,p

# %%
def roundtrips(x, n):
    
    def isElem(x, l):
        for i in range(len(l)):
            if l[i]==x:
                return True
        return False

    def startpoint(trips):
        for i in range(n):
            for t in trips:
                if isElem(i, t):
                    break
            else:
                return i
    
    def totalLength(trips):
        s=0
        for i in range(0, len(trips)):
            s += len(trips[i])-1
        return s

    trips = []
    while totalLength(trips)<n:
        start = startpoint(trips)
        trip = [ start ]
        i = start
        while len(trip) < n-totalLength(trips):
            for j in range(0, n):
                if pulp.value(x[i][j])==1:
                    trip.append(j)
                    i=j
                    break        
            if pulp.value(x[trip[-1]][start])==1:
                trip.append(start)
                break
        trips.append(trip)
    return sorted(trips, key=lambda t: len(t), reverse=True)

# %%
import time

def createLoop(M, T, timing=False):
    
    if timing:
        start_time = last_time = time.time()
        
    D, P = createTables(M, T)   # These are the distances between customers and warehouse only
    
    if timing:
        print(f"createTables:   {time.time()-start_time:6.2f}s")
        last_time = time.time()
        
    n = len(T)
    # create variables
    x = pulp.LpVariable.dicts("x", ( range(n), range(n) ),
                            lowBound=0, upBound=1, cat=pulp.LpInteger)
    # create problem
    prob = pulp.LpProblem("Loop",pulp.LpMinimize)
    # add objective function
    prob += pulp.lpSum([ D[i][j]*x[i][j] 
                             for i in range(n) for j in range(n) ])
    # add constraints
    constraints=0
    for j in range(n):
        prob += pulp.lpSum([ x[i][j] for i in range(n) if i!=j ]) ==1
    constraints += n
    for i in range(n):
        prob += pulp.lpSum([ x[i][j] for j in range(n) if i!=j ]) ==1
    constraints += n
    for i in range(n):
        for j in range(n):
            if i!=j:
                prob += x[i][j]+x[j][i] <= 1
                constraints += 1
                
    def cycles(k, n):
        if k==1:
            return [ [i] for i in range(0,n) ]
        else:
            sc=cycles(k-1, n)
            all=[]
            for c in sc:
                for i in range(0,n):
                    if c.count(i)==0:
                        all.append(c+[i])
            return all

    for k in range(3, 4):   
        cycs=cycles(k,n)
        for c in cycs:
            c.append(c[0])
            prob+=pulp.lpSum([ x[c[i]][c[i+1]] for i in range(0,k)]) <= k-1
            constraints += 1    
            
    # initialise solver
    solvers = pulp.listSolvers(onlyAvailable=True)
    solver = pulp.getSolver(solvers[0], msg=0, timeLimit=2)
    res = prob.solve(solver)

    if timing:
        print(f"Solver:         {time.time()-last_time:6.2f}s {constraints:6,d} Constraints")
        last_time = time.time()
        
    trips = roundtrips(x, n)
    while len(trips)>1:
        longest = max([ len(t) for t in trips ])
        for t in trips:
            if len(t)<longest:
                prob += pulp.lpSum([ x[t[i]][t[i+1]] + x[t[i+1]][t[i]]
                                        for i in range(0,len(t)-1) ]) <= len(t)-2
                constraints += 1
            else:
                longest = math.inf
                
        res = prob.solve(solver)
        
        if timing:
            print(f"Solver:         {time.time()-last_time:6.2f}s {constraints:6,d} Constraints")
            last_time = time.time()

        trips = roundtrips(x, n)
    trip = trips[0]
    # print(trip)
    loop = []
    for k in range(len(trip)-1):
        sub = P[trip[k]][trip[k+1]]
        loop += sub if len(loop)==0 else sub[1:]
        
    if timing:
        print(f"createLoop:     {time.time()-start_time:6.2f}s")

    return loop

# %% [markdown]
# # Class Recorder

# %% [markdown]
# We willl use a class Recorder as a reference point for capturing data during the simulation. There will be only one recorder. It will be created at the beginning of every simulation run. Every entity will carry a reference to the Recorder.

# %%
import time

class Recorder:
    
    def __init__(self, env, M, W, C, days, 
                 log=False, plot=False, timing=False):
        self.env = env
        self.M = M
        self.W = W
        self.C = C
        self.days = days
        self.log = log
        self.plot = plot

    def trace(self, event):
        if self.log:
            print(timestamp(self.env.now), event)

    def finish(self):
        # simulation is finished for good
        # by removing the simulation environment we can
        # pickle recorder
        self.env = None

# %% [markdown]
# # Class Customer

# %% [markdown]
# <img src='img/EventGraph Customer.png' width=500/>

# %%
class Customer:
    
    def __init__(self, rec, id, location):
        self.rec = rec
        self.id = id
        self.location = location
        self.atHome = True
        self.answersDoor = False
        self.parcelsReceived = []
        rec.env.process(self.process())
        
    def __str__(self):
        return f"Customer {self.id:d} at {str(self.location):s}"
    
    def leaveHouse(self):
        assert(self.atHome and not self.answersDoor)
        # self.rec.trace(str(self)+" leaves house")
        self.atHome = False
     
    def returnHome(self):
        assert(not self.atHome)
        # self.rec.trace(str(self)+" returns home")
        self.atHome = True
        
    def answerDoor(self):
        if self.atHome:
            answerTime = random.expovariate(1/AVERAGE_TIME_ANSWER_DOOR)
            if answerTime < WAIT_TIME_IF_CUSTOMER_DOESNT_ANSWER_DOOR:                            
                yield self.rec.env.timeout(answerTime)
                self.rec.trace(str(self)+" answers door")
                self.answersDoor = True
            else:
                yield self.rec.env.timeout(WAIT_TIME_IF_CUSTOMER_DOESNT_ANSWER_DOOR)
                self.rec.trace(str(self)+" to slow to answer the door")
                self.answersDoor = False
        else:
            yield self.rec.env.timeout(WAIT_TIME_IF_CUSTOMER_DOESNT_ANSWER_DOOR)
            self.rec.trace(str(self)+" not at home")
            self.answersDoot = False
            
    def acceptParcel(self, parcel):
        assert(self.answersDoor)
        self.parcelsReceived += [parcel]
        self.rec.trace(str(self)+" accepts "+str(parcel))
        
    def signOff(self):
        assert(self.answersDoor)
        self.rec.trace(str(self)+" signs off")
        self.answersDoor = False
        
    def process(self):
        yield self.rec.env.timeout(nextHour(self.rec.env, 8))
        while day(self.rec.env.now)<self.rec.days:
            # in a refinement we may use random times
            self.leaveHouse()
            returnTime = 22 if random.random()<CUSTOMER_NOT_AT_HOME else 18
            yield self.rec.env.timeout(nextHour(self.rec.env, returnTime))
            self.returnHome()
            yield self.rec.env.timeout(nextHour(self.rec.env, 8))

# %% [markdown]
# # Class Parcel

# %% [markdown]
# <img src='img/EventGraph Parcel.png' width=500/>

# %% [markdown]
# Parcels follow through a sequence of states:
# - processing
# - in transit (from manufacture to distribution centre)
# - arrived in distribution centre
# - ready for delivery
# - out for delivery
# - customer not present
# - returned to distribution centre
# - delivered

# %%
class Parcel:
    
    def __init__(self, rec, i, day, cust):
        self.rec = rec
        self.i = i  
        self.arrival = day
        self.cust = cust
        self.status = [  ] # status record and
        self.timing = [  ] # timing

    def __str__(self):
        return f"Parcel {self.i:d} for cust {self.cust.id:d}"

    def index(self):
        return self.i
    
    def destination(self):
        return self.cust.location
    
    def __reg(self, state):
        self.status += [ state ]
        self.timing += [ self.rec.env.now ]
        self.rec.trace(str(self)+" "+state)
        
    def arrivedAtDeliveryCentre(self):
        self.__reg('arr at delivery centre')
        
    def outForDelivery(self): 
        self.__reg('out for delivery')
        
    def returnFromDelivery(self):
        self.__reg('return from delivery')

# %% [markdown]
# # Class Driver

# %% [markdown]
# <img src='img/EventGraph Driver.png' width=500/>

# %%
class Driver:
    
    def __init__(self, rec, DC):
        self.rec = rec
        self.DC = DC
        self.location = None
        self.parcels = None
        self.tour = None
        self.rec.env.process(self.process())
        
    # activity
    def __drive(self, target):
        assert(self.tour[0] == self.location)
        while self.location!=target:
            d = dist(self.location, self.tour[1])
            yield self.rec.env.timeout(d / AVERAGE_SPEED)
            self.location = self.tour[1]
            self.tour = self.tour[1:]
        assert(self.tour[0] == self.location == target)
    
    def arriveForWork(self):
        self.location = self.DC.W
        self.parcels = []
        self.returns = []
        self.tour = [ self.DC.W ]
        self.rec.trace("Driver arrives for work")

    def goesHome(self):
        self.location = None
        self.parcels = None
        self.returns = None
        self.tour = None
        self.rec.trace("Driver goes home")
        
    def leaveForDelivery(self, tour, parcels, addresses):
        self.tour, self.parcels = tour, parcels
        self.rec.trace(f"Driver leaves for delivery " 
                       f"of {len(parcels):d} parcels "
                       f"to {len(addresses):d} customers")
        self.rec.trace(f"Length of delivery tour: {pathLength(tour):,d}m")
        if self.rec.plot:
            plotMap(self.rec.M, T=addresses, P=tour, w=tour[0], 
                    text=f"Day {day(self.rec.env.now):d}:, {pathLength(tour):,d}m")
        
    def process(self):
        yield self.rec.env.timeout(nextHour(self.rec.env, 18))
        while day(self.rec.env.now)<self.rec.days:
            self.arriveForWork()
            tour, parcels, addresses = self.DC.sendForDelivery()
            if len(parcels)==0: 
                self.rec.trace("Nothing to do today")
            else:
                yield self.rec.env.timeout(PREP_TIME_PER_PARCEL*len(parcels))
                self.leaveForDelivery(tour, parcels, addresses)        
                while len(self.parcels)>0:
                    # drive to customer
                    custLocation = self.parcels[0].destination()
                    cust = self.parcels[0].cust
                    self.rec.trace("Driver drives to "+str(cust))
                    yield from self.__drive(custLocation)
                    self.rec.trace("Driver arrived at "+str(cust))
                    # call at customer
                    yield from cust.answerDoor()
                    
                    if cust.answersDoor:
                        while len(self.parcels)>0 and \
                                custLocation == self.parcels[0].destination():
                            cust.acceptParcel(self.parcels[0])
                            yield self.rec.env.timeout(random.expovariate(1/10))
                            self.parcels = self.parcels[1:]
                        cust.signOff()
                        yield self.rec.env.timeout(random.expovariate(1/10))
                    else:
                        while len(self.parcels)>0 and  \
                                custLocation == self.parcels[0].destination():
                            self.returns += [self.parcels[0]]
                            self.parcels = self.parcels[1:]

                # return to delivery centre
                self.rec.trace("Driver returns to delivery centre")
                yield from self.__drive(self.DC.W)
                self.rec.trace("Driver arrived at delivery centre")
            
                for parcel in self.returns:
                    self.DC.returnFromDelivery(parcel)
                    yield self.rec.env.timeout(RETURN_TIME_PER_PARCEL)

                leftOver = len(self.DC.parcels)+len(self.DC.leftOver)
                self.rec.trace(f"{leftOver:d} parcels left for next day")
            
            yield self.rec.env.timeout(600)
        
            self.goesHome()
            
            yield self.rec.env.timeout(nextHour(self.rec.env, 18))

# %% [markdown]
# # Class Delivery Centre

# %% [markdown]
# <img src="img/EventGraph Delivery Centre.png" width=300/>

# %%
class DeliveryCentre:
    
    def __init__(self, rec, M, W):
        self.rec = rec
        self.M = M
        self.W = W
        self.limit = BIKE_RANGE
        
        self.leftOver = []    # list of parcels
        self.parcels = []     # list of parcels scheduled for delivery
        self.dest = []        # list of unique customer destinations
        self.tour = [self.W]  # tour planned for delivery
    
    def __accept(self, parcel):
        custLoc = parcel.destination()
        if custLoc not in self.dest:
            MT = addTargets(self.M, self.dest + [custLoc])
            SH = createLoopG(MT, [self.W] + self.dest + [custLoc])
            if pathLength(SH)<self.limit:
                self.parcels.append(parcel)
                self.dest += [custLoc]
                self.tour = SH
            else: 
                self.leftOver.append(parcel)
        else:
            self.parcels.append(parcel)
        
    def acceptParcel(self, parcel):
        parcel.arrivedAtDeliveryCentre()
        self.__accept(parcel)
            
    def sendForDelivery(self):
        parcels = []
        tour = self.tour
        addresses = []
        
        # pick parcels in sequence to be delivered
        for i in range(1, len(tour)-1):
            dest = tour[i]
            for p in self.parcels:
                if p.destination() == dest and p not in parcels:
                    parcels += [p]
                    p.outForDelivery()
                    if dest not in addresses:
                        addresses += [dest]
         
        # arrange the left overs for next day
        L = self.leftOver
        self.tour = [self.W]
        self.parcels = []
        self.leftOver = []
        self.dest = []
        for p in L:
            self.__accept(p)

        return tour, parcels, addresses
                 
    def returnFromDelivery(self, parcel):
        parcel.returnFromDelivery()
        self.__accept(parcel)

    def getInventory(self):
        return len(self.parcels)+len(self.leftOver)

# %% [markdown]
# # Simulation

# %% [markdown]
# ## Parameters from Specification

# %% [markdown]
# The proportion of customers that for whatever are not at home or return home late

# %%
CUSTOMER_NOT_AT_HOME = 0.9  # 10%

# %% [markdown]
# The maximum bike range. This is passed as parameter to the Delivery Centre
# and taken into account for the daily tour planning

# %%
BIKE_RANGE = 40000

# %% [markdown]
# The time required for driving is based on the distance between way points at an average speed of 15km/h.

# %%
AVERAGE_SPEED = 15/3.6

# %% [markdown]
# The **cumulative preparation time** (route planning and
# sorting of the parcels in the delivery order and
# packing the cargo-bike) is assumed to be 50 sec per
# parcel to be delivered.

# %%
PREP_TIME_PER_PARCEL = 50

# %% [markdown]
# **Additional assumption:** The time to **process returned parcels** in the delivery centre is 30 sec per parce.

# %%
RETURN_TIME_PER_PARCEL = 30

# %% [markdown]
# The average time to answer the door.

# %%
AVERAGE_TIME_ANSWER_DOOR = 40

# %%
WAIT_TIME_IF_CUSTOMER_DOESNT_ANSWER_DOOR = 60

# %% [markdown]
# ## Generate Input Data

# %%
def generateDeliveries(p, C, days, seed=0):
    ## p is the average number of parcels per day per customer
    ## C is the number of customers to be served
    ## days is the number of days for which data are to be generated.
    random.seed(seed)
    deliveries = [ [ ] for _ in range(days) ]
    for c in range(C):
        arr = 0
        while True:
            arr += random.expovariate(p)
            day = int(arr)
            if day>=days:
                break
            deliveries[day].append(c)
    return deliveries

# %% [markdown]
# ## Simulation Routine

# %%
def simulation(M, W, C, p=0.2, days=10, seed=0, 
               log=False, plot=False, timing=False):

    random.seed(seed)
    D = generateDeliveries(p, len(C), days, seed)
    
    env = simpy.Environment()
    rec = Recorder(env, M, W, C, days, 
                   log=log, plot=plot, timing=timing)

    print(f"Simulating delivery of {sum([len(d) for d in D]):d} parcels "
          f"over {len(D):d} days to {len(C):d} customers")

    CUSTOMERS = []
    for i in range(len(C)):
        CUSTOMERS.append(Customer(rec, i, C[i]))

    DC = DeliveryCentre(rec, M, W)
    Z = Driver(rec, DC)
    PARCELS = []

    def parcelGeneratorProcess(env, rec, D, C):
        for day in range(len(D)):
            yield env.timeout(nextHour(env, 17.00))
            for c in D[day]:
                cust = CUSTOMERS[c]
                parcel = Parcel(rec, len(PARCELS), day, cust)
                PARCELS.append(parcel)
                DC.acceptParcel(parcel)

    env.process(parcelGeneratorProcess(env, rec, D, C))
    env.run()

    rec.finish()

    if DC.getInventory()>0:
        print(f"Delivery Centre Inventory: {DC.getInventory():d} parcels")

    return rec

# %% [markdown]
# ## Model Verification

# %%
import pickle
with open('simpleData.pickled', 'rb') as f:
    M, C = pickle.load(f)

# %%
W = generateWarehouseLocation(M)

# %%
plotMap(M, T=C, w=W, scale=True)

# %%
rec1 = simulation(M, W, C, p=0.15, days=4, log=True)
# Out:
# Simulating delivery of 48 parcels over 4 days to 100 customers
# [ 0] 17:00:00.0 Parcel 0 for cust 19 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 1 for cust 27 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 2 for cust 30 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 3 for cust 40 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 4 for cust 54 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 5 for cust 72 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 6 for cust 77 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 7 for cust 79 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 8 for cust 80 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 9 for cust 84 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 10 for cust 89 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 11 for cust 89 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 12 for cust 92 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 13 for cust 96 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 14 for cust 96 arr at delivery centre
# [ 0] 18:00:00.0 Driver arrives for work
# [ 0] 18:00:00.0 Parcel 3 for cust 40 out for delivery
# [ 0] 18:00:00.0 Parcel 4 for cust 54 out for delivery
# [ 0] 18:00:00.0 Parcel 9 for cust 84 out for delivery
# [ 0] 18:00:00.0 Parcel 10 for cust 89 out for delivery
# [ 0] 18:00:00.0 Parcel 11 for cust 89 out for delivery
# [ 0] 18:00:00.0 Parcel 2 for cust 30 out for delivery
# [ 0] 18:00:00.0 Parcel 0 for cust 19 out for delivery
# [ 0] 18:00:00.0 Parcel 1 for cust 27 out for delivery
# [ 0] 18:06:40.0 Driver leaves for delivery of 8 parcels to 7 customers
# [ 0] 18:06:40.0 Length of delivery tour: 36,414m
# [ 0] 18:06:40.0 Driver drives to Customer 40 at (4500, 5107)
# [ 0] 18:09:05.7 Driver arrived at Customer 40 at (4500, 5107)
# [ 0] 18:10:05.7 Customer 40 at (4500, 5107) not at home
# [ 0] 18:10:05.7 Driver drives to Customer 54 at (5416, 5560)
# [ 0] 18:15:34.2 Driver arrived at Customer 54 at (5416, 5560)
# [ 0] 18:16:34.2 Customer 54 at (5416, 5560) not at home
# [ 0] 18:16:34.2 Driver drives to Customer 84 at (6620, 6812)
# [ 0] 18:26:23.7 Driver arrived at Customer 84 at (6620, 6812)
# [ 0] 18:27:23.7 Customer 84 at (6620, 6812) not at home
# [ 0] 18:27:23.7 Driver drives to Customer 89 at (6620, 8231)
# [ 0] 18:33:04.2 Driver arrived at Customer 89 at (6620, 8231)
# [ 0] 18:34:04.2 Customer 89 at (6620, 8231) not at home
# [ 0] 18:34:04.2 Driver drives to Customer 30 at (3068, 6620)
# [ 0] 19:00:43.1 Driver arrived at Customer 30 at (3068, 6620)
# [ 0] 19:01:43.1 Customer 30 at (3068, 6620) not at home
# [ 0] 19:01:43.1 Driver drives to Customer 19 at (1677, 960)
# [ 0] 19:37:56.1 Driver arrived at Customer 19 at (1677, 960)
# [ 0] 19:38:56.1 Customer 19 at (1677, 960) not at home
# [ 0] 19:38:56.1 Driver drives to Customer 27 at (2819, 260)
# [ 0] 19:44:39.5 Driver arrived at Customer 27 at (2819, 260)
# [ 0] 19:44:40.3 Customer 27 at (2819, 260) answers door
# [ 0] 19:44:40.3 Customer 27 at (2819, 260) accepts Parcel 1 for cust 27
# [ 0] 19:44:40.7 Customer 27 at (2819, 260) signs off
# [ 0] 19:44:52.1 Driver returns to delivery centre
# [ 0] 20:38:32.0 Driver arrived at delivery centre
# [ 0] 20:38:32.0 Parcel 3 for cust 40 return from delivery
# [ 0] 20:39:02.0 Parcel 4 for cust 54 return from delivery
# [ 0] 20:39:32.0 Parcel 9 for cust 84 return from delivery
# [ 0] 20:40:02.0 Parcel 10 for cust 89 return from delivery
# [ 0] 20:40:32.0 Parcel 11 for cust 89 return from delivery
# [ 0] 20:41:02.0 Parcel 2 for cust 30 return from delivery
# [ 0] 20:41:32.0 Parcel 0 for cust 19 return from delivery
# [ 0] 20:42:02.0 14 parcels left for next day
# [ 0] 20:52:02.0 Driver goes home
# [ 1] 17:00:00.0 Parcel 15 for cust 11 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 16 for cust 32 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 17 for cust 34 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 18 for cust 35 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 19 for cust 76 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 20 for cust 79 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 21 for cust 90 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 22 for cust 97 arr at delivery centre
# [ 1] 18:00:00.0 Driver arrives for work
# [ 1] 18:00:00.0 Parcel 3 for cust 40 out for delivery
# [ 1] 18:00:00.0 Parcel 2 for cust 30 out for delivery
# [ 1] 18:00:00.0 Parcel 15 for cust 11 out for delivery
# [ 1] 18:00:00.0 Parcel 0 for cust 19 out for delivery
# [ 1] 18:00:00.0 Parcel 16 for cust 32 out for delivery
# [ 1] 18:00:00.0 Parcel 5 for cust 72 out for delivery
# [ 1] 18:00:00.0 Parcel 6 for cust 77 out for delivery
# [ 1] 18:00:00.0 Parcel 7 for cust 79 out for delivery
# [ 1] 18:00:00.0 Parcel 20 for cust 79 out for delivery
# [ 1] 18:00:00.0 Parcel 8 for cust 80 out for delivery
# [ 1] 18:00:00.0 Parcel 19 for cust 76 out for delivery
# [ 1] 18:09:10.0 Driver leaves for delivery of 11 parcels to 10 customers
# [ 1] 18:09:10.0 Length of delivery tour: 39,720m
# [ 1] 18:09:10.0 Driver drives to Customer 40 at (4500, 5107)
# [ 1] 18:11:35.7 Driver arrived at Customer 40 at (4500, 5107)
# [ 1] 18:12:35.7 Customer 40 at (4500, 5107) not at home
# [ 1] 18:12:35.7 Driver drives to Customer 30 at (3068, 6620)
# [ 1] 18:21:53.4 Driver arrived at Customer 30 at (3068, 6620)
# [ 1] 18:22:53.4 Customer 30 at (3068, 6620) not at home
# [ 1] 18:22:53.4 Driver drives to Customer 11 at (703, 2996)
# [ 1] 18:49:21.0 Driver arrived at Customer 11 at (703, 2996)
# [ 1] 18:50:21.0 Customer 11 at (703, 2996) not at home
6 Driver arrived at Customer 38 at (4500, 4765)
# [ 2] 18:12:03.6 Customer 38 at (4500, 4765) not at home
# [ 2] 18:12:03.6 Driver drives to Customer 40 at (4500, 5107)
# [ 2] 18:13:25.7 Driver arrived at Customer 40 at (4500, 5107)
# [ 2] 18:14:25.7 Customer 40 at (4500, 5107) not at home
# [ 2] 18:14:25.7 Driver drives to Customer 30 at (3068, 6620)
# [ 2] 18:23:43.4 Driver arrived at Customer 30 at (3068, 6620)
# [ 2] 18:24:43.4 Customer 30 at (3068, 6620) not at home
# [ 2] 18:24:43.4 Driver drives to Customer 9 at (260, 6204)
# [ 2] 18:37:37.2 Driver arrived at Customer 9 at (260, 6204)
# [ 2] 18:38:37.2 Customer 9 at (260, 6204) not at home
# [ 2] 18:38:37.2 Driver drives to Customer 5 at (260, 5135)
# [ 2] 18:42:53.8 Driver arrived at Customer 5 at (260, 5135)
# [ 2] 18:43:53.8 Customer 5 at (260, 5135) not at home
# [ 2] 18:43:53.8 Driver drives to Customer 11 at (703, 2996)
# [ 2] 18:53:11.0 Driver arrived at Customer 11 at (703, 2996)
# [ 2] 18:54:11.0 Customer 11 at (703, 2996) not at home
# [ 2] 18:54:11.0 Driver drives to Customer 32 at (3248, 260)
# [ 2] 19:11:22.6 Driver arrived at Customer 32 at (3248, 260)
# [ 2] 19:12:22.6 Customer 32 at (3248, 260) not at home
# [ 2] 19:12:22.6 Driver drives to Customer 90 at (6864, 1320)
# [ 2] 19:31:04.8 Driver arrived at Customer 90 at (6864, 1320)
# [ 2] 19:32:04.8 Customer 90 at (6864, 1320) not at home
# [ 2] 19:32:04.8 Driver drives to Customer 92 at (7026, 1320)
# [ 2] 19:32:43.7 Driver arrived at Customer 92 at (7026, 1320)
# [ 2] 19:33:43.7 Customer 92 at (7026, 1320) not at home
# [ 2] 19:33:43.7 Driver drives to Customer 93 at (7296, 1320)
# [ 2] 19:34:48.5 Driver arrived at Customer 93 at (7296, 1320)
# [ 2] 19:35:48.5 Customer 93 at (7296, 1320) not at home
# [ 2] 19:35:48.5 Driver drives to Customer 54 at (5416, 5560)
# [ 2] 20:51:02.4 Driver arrived at Customer 54 at (5416, 5560)
# [ 2] 20:52:02.4 Customer 54 at (5416, 5560) not at home
# [ 2] 20:52:02.4 Driver returns to delivery centre
# [ 2] 20:59:56.6 Driver arrived at delivery centre
# [ 2] 20:59:56.6 Parcel 27 for cust 38 return from delivery
# [ 2] 21:00:26.6 Parcel 3 for cust 40 return from delivery
# [ 2] 21:00:56.6 Parcel 2 for cust 30 return from delivery
# [ 2] 21:01:26.6 Parcel 24 for cust 9 return from delivery
# [ 2] 21:01:56.6 Parcel 23 for cust 5 return from delivery
# [ 2] 21:02:26.6 Parcel 15 for cust 11 return from delivery
# [ 2] 21:02:56.6 Parcel 16 for cust 32 return from delivery
# [ 2] 21:03:26.6 Parcel 21 for cust 90 return from delivery
# [ 2] 21:03:56.6 Parcel 32 for cust 90 return from delivery
# [ 2] 21:04:26.6 Parcel 12 for cust 92 return from delivery
# [ 2] 21:04:56.6 Parcel 33 for cust 93 return from delivery
# [ 2] 21:05:26.6 Parcel 4 for cust 54 return from delivery
# [ 2] 21:05:56.6 33 parcels left for next day
# [ 2] 21:15:56.6 Driver goes home
# [ 3] 17:00:00.0 Parcel 35 for cust 2 arr at delivery centre
# [ 3] 17:00:00.0 Parcel 36 for cust 4 arr at delivery centre
# [ 3] 17:00:00.0 Parcel 37 for cust 28 arr at delivery centre
# [ 3] 17:00:00.0 Parcel 38 for cust 37 arr at delivery centre
# [ 3] 17:00:00.0 Parcel 39 for cust 48 arr at delivery centre
# [ 3] 17:00:00.0 Parcel 40 for cust 49 arr at delivery centre
# [ 3] 17:00:00.0 Parcel 41 for cust 50 arr at delivery centre
# [ 3] 17:00:00.0 Parcel 42 for cust 61 arr at delivery centre
# [ 3] 17:00:00.0 Parcel 43 for cust 68 arr at delivery centre
# [ 3] 17:00:00.0 Parcel 44 for cust 87 arr at delivery centre
# [ 3] 17:00:00.0 Parcel 45 for cust 90 arr at delivery centre
# [ 3] 17:00:00.0 Parcel 46 for cust 92 arr at delivery centre
# [ 3] 17:00:00.0 Parcel 47 for cust 93 arr at delivery centre
# [ 3] 18:00:00.0 Driver arrives for work
# [ 3] 18:00:00.0 Parcel 27 for cust 38 out for delivery
# [ 3] 18:00:00.0 Parcel 3 for cust 40 out for delivery
# [ 3] 18:00:00.0 Parcel 2 for cust 30 out for delivery
# [ 3] 18:00:00.0 Parcel 37 for cust 28 out for delivery
# [ 3] 18:00:00.0 Parcel 24 for cust 9 out for delivery
# [ 3] 18:00:00.0 Parcel 23 for cust 5 out for delivery
# [ 3] 18:00:00.0 Parcel 36 for cust 4 out for delivery
# [ 3] 18:00:00.0 Parcel 35 for cust 2 out for delivery
# [ 3] 18:00:00.0 Parcel 15 for cust 11 out for delivery
# [ 3] 18:00:00.0 Parcel 25 for cust 15 out for delivery
# [ 3] 18:00:00.0 Parcel 26 for cust 25 out for delivery
# [ 3] 18:00:00.0 Parcel 4 for cust 54 out for delivery
# [ 3] 18:00:00.0 Parcel 34 for cust 94 out for delivery
# [ 3] 18:00:00.0 Parcel 22 for cust 97 out for delivery
# [ 3] 18:00:00.0 Parcel 9 for cust 84 out for delivery
# [ 3] 18:00:00.0 Parcel 44 for cust 87 out for delivery
# [ 3] 18:00:00.0 Parcel 10 for cust 89 out for delivery
# [ 3] 18:00:00.0 Parcel 11 for cust 89 out for delivery
# [ 3] 18:00:00.0 Parcel 28 for cust 50 out for delivery
# [ 3] 18:00:00.0 Parcel 41 for cust 50 out for delivery
# [ 3] 18:00:00.0 Parcel 40 for cust 49 out for delivery
# [ 3] 18:00:00.0 Parcel 39 for cust 48 out for delivery
# [ 3] 18:18:20.0 Driver leaves for delivery of 22 parcels to 20 customers
# [ 3] 18:18:20.0 Length of delivery tour: 38,996m
# [ 3] 18:18:20.0 Driver drives to Customer 38 at (4500, 4765)
# [ 3] 18:19:23.6 Driver arrived at Customer 38 at (4500, 4765)
# [ 3] 18:20:23.6 Customer 38 at (4500, 4765) not at home
# [ 3] 18:20:23.6 Driver drives to Customer 40 at (4500, 5107)
# [ 3] 18:21:45.7 Driver arrived at Customer 40 at (4500, 5107)
# [ 3] 18:22:45.7 Customer 40 at (4500, 5107) not at home
# [ 3] 18:22:45.7 Driver drives to Customer 30 at (3068, 6620)
# [ 3] 18:32:03.4 Driver arrived at Customer 30 at (3068, 6620)
# [ 3] 18:33:03.4 Customer 30 at (3068, 6620) not at home
# [ 3] 18:33:03.4 Driver drives to Customer 28 at (2879, 6620)
# [ 3] 18:33:48.8 Driver arrived at Customer 28 at (2879, 6620)
# [ 3] 18:34:48.8 Customer 28 at (2879, 6620) not at home
# [ 3] 18:34:48.8 Driver drives to Customer 9 at (260, 6204)
# [ 3] 18:46:57.2 Driver arrived at Customer 9 at (260, 6204)
# [ 3] 18:47:57.2 Customer 9 at (260, 6204) not at home
# [ 3] 18:47:57.2 Driver drives to Customer 5 at (260, 5135)
# [ 3] 18:52:13.8 Driver arrived at Customer 5 at (260, 5135)
# [ 3] 18:53:13.8 Customer 5 at (260, 5135) not at home
# [ 3] 18:53:13.8 Driver drives to Customer 4 at (260, 4991)
# [ 3] 18:53:48.3 Driver arrived at Customer 4 at (260, 4991)
# [ 3] 18:54:48.3 Customer 4 at (260, 4991) not at home
# [ 3] 18:54:48.3 Driver drives to Customer 2 at (260, 4756)
# [ 3] 18:55:44.7 Driver arrived at Customer 2 at (260, 4756)
# [ 3] 18:56:44.7 Customer 2 at (260, 4756) not at home
# [ 3] 18:56:44.7 Driver drives to Customer 11 at (703, 2996)
# [ 3] 19:04:31.0 Driver arrived at Customer 11 at (703, 2996)
# [ 3] 19:05:31.0 Customer 11 at (703, 2996) not at home
# [ 3] 19:05:31.0 Driver drives to Customer 15 at (1320, 7071)
# [ 3] 19:26:47.4 Driver arrived at Customer 15 at (1320, 7071)
# [ 3] 19:27:47.4 Customer 15 at (1320, 7071) not at home
# [ 3] 19:27:47.4 Driver drives to Customer 25 at (2380, 5939)
# [ 3] 19:36:33.4 Driver arrived at Customer 25 at (2380, 5939)
# [ 3] 19:37:33.4 Customer 25 at (2380, 5939) not at home
# [ 3] 19:37:33.4 Driver drives to Customer 54 at (5416, 5560)
# [ 3] 19:54:10.9 Driver arrived at Customer 54 at (5416, 5560)
# [ 3] 19:54:34.4 Customer 54 at (5416, 5560) answers door
# [ 3] 19:54:34.4 Customer 54 at (5416, 5560) accepts Parcel 4 for cust 54
# [ 3] 19:54:39.0 Customer 54 at (5416, 5560) signs off
# [ 3] 19:55:08.8 Driver drives to Customer 94 at (7439, 5560)
# [ 3] 20:03:14.3 Driver arrived at Customer 94 at (7439, 5560)
# [ 3] 20:04:14.3 Customer 94 at (7439, 5560) not at home
# [ 3] 20:04:14.3 Driver drives to Customer 97 at (8209, 6089)
# [ 3] 20:08:11.7 Driver arrived at Customer 97 at (8209, 6089)
# [ 3] 20:09:11.7 Customer 97 at (8209, 6089) not at home
# [ 3] 20:09:11.7 Driver drives to Customer 84 at (6620, 6812)
# [ 3] 20:21:26.1 Driver arrived at Customer 84 at (6620, 6812)
# [ 3] 20:22:26.1 Customer 84 at (6620, 6812) not at home
# [ 3] 20:22:26.1 Driver drives to Customer 87 at (6620, 7446)
# [ 3] 20:24:58.2 Driver arrived at Customer 87 at (6620, 7446)
# [ 3] 20:25:58.2 Customer 87 at (6620, 7446) not at home
# [ 3] 20:25:58.2 Driver drives to Customer 89 at (6620, 8231)
# [ 3] 20:29:06.6 Driver arrived at Customer 89 at (6620, 8231)
# [ 3] 20:30:06.6 Customer 89 at (6620, 8231) not at home
# [ 3] 20:30:06.6 Driver drives to Customer 50 at (5076, 8740)
# [ 3] 20:38:19.3 Driver arrived at Customer 50 at (5076, 8740)
# [ 3] 20:38:21.7 Customer 50 at (5076, 8740) answers door
# [ 3] 20:38:21.7 Customer 50 at (5076, 8740) accepts Parcel 28 for cust 50
# [ 3] 20:38:27.0 Customer 50 at (5076, 8740) accepts Parcel 41 for cust 50
# [ 3] 20:38:32.4 Customer 50 at (5076, 8740) signs off
# [ 3] 20:38:45.4 Driver drives to Customer 49 at (4987, 8740)
# [ 3] 20:39:06.8 Driver arrived at Customer 49 at (4987, 8740)
# [ 3] 20:40:06.8 Customer 49 at (4987, 8740) not at home
# [ 3] 20:40:06.8 Driver drives to Customer 48 at (4908, 8740)
# [ 3] 20:40:25.7 Driver arrived at Customer 48 at (4908, 8740)
# [ 3] 20:41:25.7 Customer 48 at (4908, 8740) not at home
# [ 3] 20:41:25.7 Driver returns to delivery centre
# [ 3] 21:13:43.0 Driver arrived at delivery centre
# [ 3] 21:13:43.0 Parcel 27 for cust 38 return from delivery
# [ 3] 21:14:13.0 Parcel 3 for cust 40 return from delivery
# [ 3] 21:14:43.0 Parcel 2 for cust 30 return from delivery
# [ 3] 21:15:13.0 Parcel 37 for cust 28 return from delivery
# [ 3] 21:15:43.0 Parcel 24 for cust 9 return from delivery
# [ 3] 21:16:13.0 Parcel 23 for cust 5 return from delivery
# [ 3] 21:16:43.0 Parcel 36 for cust 4 return from delivery
# [ 3] 21:17:13.0 Parcel 35 for cust 2 return from delivery
# [ 3] 21:17:43.0 Parcel 15 for cust 11 return from delivery
# [ 3] 21:18:13.0 Parcel 25 for cust 15 return from delivery
# [ 3] 21:18:43.0 Parcel 26 for cust 25 return from delivery
# [ 3] 21:19:13.0 Parcel 34 for cust 94 return from delivery
# [ 3] 21:19:43.0 Parcel 22 for cust 97 return from delivery
# [ 3] 21:20:13.0 Parcel 9 for cust 84 return from delivery
# [ 3] 21:20:43.0 Parcel 44 for cust 87 return from delivery
# [ 3] 21:21:13.0 Parcel 10 for cust 89 return from delivery
# [ 3] 21:21:43.0 Parcel 11 for cust 89 return from delivery
# [ 3] 21:22:13.0 Parcel 40 for cust 49 return from delivery
# [ 3] 21:22:43.0 Parcel 39 for cust 48 return from delivery
# [ 3] 21:23:13.0 43 parcels left for next day
# [ 3] 21:33:13.0 Driver goes home
# Delivery Centre Inventory: 43 parcels

# %%
rec2 = simulation(M, W, C, p=0.3, days=4, seed=1, log=True, plot=True)
# Out:
# Simulating delivery of 117 parcels over 4 days to 100 customers
# [ 0] 17:00:00.0 Parcel 0 for cust 0 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 1 for cust 2 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 2 for cust 4 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 3 for cust 4 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 4 for cust 6 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 5 for cust 7 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 6 for cust 9 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 7 for cust 9 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 8 for cust 11 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 9 for cust 11 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 10 for cust 12 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 11 for cust 15 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 12 for cust 17 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 13 for cust 25 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 14 for cust 35 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 15 for cust 38 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 16 for cust 41 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 17 for cust 52 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 18 for cust 52 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 19 for cust 57 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 20 for cust 59 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 21 for cust 59 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 22 for cust 60 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 23 for cust 62 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 24 for cust 64 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 25 for cust 65 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 26 for cust 68 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 27 for cust 68 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 28 for cust 68 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 29 for cust 69 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 30 for cust 71 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 31 for cust 76 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 32 for cust 82 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 33 for cust 88 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 34 for cust 93 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 35 for cust 93 arr at delivery centre
# [ 0] 18:00:00.0 Driver arrives for work
# [ 0] 18:00:00.0 Parcel 15 for cust 38 out for delivery
# [ 0] 18:00:00.0 Parcel 16 for cust 41 out for delivery
# [ 0] 18:00:00.0 Parcel 24 for cust 64 out for delivery
# [ 0] 18:00:00.0 Parcel 29 for cust 69 out for delivery
# [ 0] 18:00:00.0 Parcel 30 for cust 71 out for delivery
# [ 0] 18:00:00.0 Parcel 33 for cust 88 out for delivery
# [ 0] 18:00:00.0 Parcel 17 for cust 52 out for delivery
# [ 0] 18:00:00.0 Parcel 18 for cust 52 out for delivery
# [ 0] 18:00:00.0 Parcel 13 for cust 25 out for delivery
# [ 0] 18:00:00.0 Parcel 11 for cust 15 out for delivery
# [ 0] 18:00:00.0 Parcel 6 for cust 9 out for delivery
# [ 0] 18:00:00.0 Parcel 7 for cust 9 out for delivery
# [ 0] 18:00:00.0 Parcel 5 for cust 7 out for delivery
# [ 0] 18:00:00.0 Parcel 4 for cust 6 out for delivery
# [ 0] 18:00:00.0 Parcel 2 for cust 4 out for delivery
# [ 0] 18:00:00.0 Parcel 3 for cust 4 out for delivery
# [ 0] 18:00:00.0 Parcel 1 for cust 2 out for delivery
# [ 0] 18:00:00.0 Parcel 0 for cust 0 out for delivery
# [ 0] 18:00:00.0 Parcel 8 for cust 11 out for delivery
# [ 0] 18:00:00.0 Parcel 9 for cust 11 out for delivery
# [ 0] 18:00:00.0 Parcel 10 for cust 12 out for delivery
# [ 0] 18:00:00.0 Parcel 12 for cust 17 out for delivery
# [ 0] 18:18:20.0 Driver leaves for delivery of 22 parcels to 18 customers
# [ 0] 18:18:20.0 Length of delivery tour: 38,856m
# [ 0] 18:18:20.0 Driver drives to Customer 38 at (4500, 4765)
# [ 0] 18:19:23.6 Driver arrived at Customer 38 at (4500, 4765)
# [ 0] 18:20:23.6 Customer 38 at (4500, 4765) not at home
# [ 0] 18:20:23.6 Driver drives to Customer 41 at (4500, 5208)
# [ 0] 18:22:09.9 Driver arrived at Customer 41 at (4500, 5208)
# [ 0] 18:23:09.9 Customer 41 at (4500, 5208) not at home
# [ 0] 18:23:09.9 Driver drives to Customer 64 at (5846, 5560)
# [ 0] 18:29:57.4 Driver arrived at Customer 64 at (5846, 5560)
# [ 0] 18:30:57.4 Customer 64 at (5846, 5560) not at home
# [ 0] 18:30:57.4 Driver drives to Customer 69 at (6126, 5560)
# [ 0] 18:32:04.6 Driver arrived at Customer 69 at (6126, 5560)
# [ 0] 18:33:04.6 Customer 69 at (6126, 5560) not at home
# [ 0] 18:33:04.6 Driver drives to Customer 71 at (6408, 5560)
# [ 0] 18:34:12.3 Driver arrived at Customer 71 at (6408, 5560)
# [ 0] 18:34:43.8 Customer 71 at (6408, 5560) answers door
# [ 0] 18:34:43.8 Customer 71 at (6408, 5560) accepts Parcel 30 for cust 71
# [ 0] 18:34:52.4 Customer 71 at (6408, 5560) signs off
# [ 0] 18:35:01.5 Driver drives to Customer 88 at (6620, 7535)
# [ 0] 18:43:46.3 Driver arrived at Customer 88 at (6620, 7535)
# [ 0] 18:44:46.3 Customer 88 at (6620, 7535) not at home
# [ 0] 18:44:46.3 Driver drives to Customer 52 at (5243, 8740)
# [ 0] 18:55:06.0 Driver arrived at Customer 52 at (5243, 8740)
# [ 0] 18:56:06.0 Customer 52 at (5243, 8740) not at home
# [ 0] 18:56:06.0 Driver drives to Customer 25 at (2380, 5939)
# [ 0] 19:35:46.1 Driver arrived at Customer 25 at (2380, 5939)
# [ 0] 19:36:46.1 Customer 25 at (2380, 5939) not at home
# [ 0] 19:36:46.1 Driver drives to Customer 15 at (1320, 7071)
# [ 0] 19:45:32.2 Driver arrived at Customer 15 at (1320, 7071)
# [ 0] 19:45:43.4 Customer 15 at (1320, 7071) answers door
# [ 0] 19:45:43.4 Customer 15 at (1320, 7071) accepts Parcel 11 for cust 15
# [ 0] 19:45:43.6 Customer 15 at (1320, 7071) signs off
# [ 0] 19:45:46.4 Driver drives to Customer 9 at (260, 6204)
# [ 0] 19:53:28.9 Driver arrived at Customer 9 at (260, 6204)
# [ 0] 19:54:28.9 Customer 9 at (260, 6204) not at home
# [ 0] 19:54:28.9 Driver drives to Customer 7 at (260, 5340)
# [ 0] 19:57:56.3 Driver arrived at Customer 7 at (260, 5340)
# [ 0] 19:58:56.3 Customer 7 at (260, 5340) not at home
# [ 0] 19:58:56.3 Driver drives to Customer 6 at (260, 5225)
# [ 0] 19:59:23.9 Driver arrived at Customer 6 at (260, 5225)
# [ 0] 20:00:23.9 Customer 6 at (260, 5225) not at home
# [ 0] 20:00:23.9 Driver drives to Customer 4 at (260, 4991)
# [ 0] 20:01:20.0 Driver arrived at Customer 4 at (260, 4991)
# [ 0] 20:02:20.0 Customer 4 at (260, 4991) not at home
# [ 0] 20:02:20.0 Driver drives to Customer 2 at (260, 4756)
# [ 0] 20:03:16.4 Driver arrived at Customer 2 at (260, 4756)
# [ 0] 20:04:16.4 Customer 2 at (260, 4756) not at home
# [ 0] 20:04:16.4 Driver drives to Customer 0 at (260, 4455)
# [ 0] 20:05:28.7 Driver arrived at Customer 0 at (260, 4455)
# [ 0] 20:05:31.7 Customer 0 at (260, 4455) answers door
# [ 0] 20:05:31.7 Customer 0 at (260, 4455) accepts Parcel 0 for cust 0
# [ 0] 20:05:39.7 Customer 0 at (260, 4455) signs off
# [ 0] 20:05:40.4 Driver drives to Customer 11 at (703, 2996)
# [ 0] 20:12:14.5 Driver arrived at Customer 11 at (703, 2996)
# [ 0] 20:13:14.5 Customer 11 at (703, 2996) not at home
# [ 0] 20:13:14.5 Driver drives to Customer 12 at (1104, 2594)
# [ 0] 20:15:30.6 Driver arrived at Customer 12 at (1104, 2594)
# [ 0] 20:16:30.6 Customer 12 at (1104, 2594) not at home
# [ 0] 20:16:30.6 Driver drives to Customer 17 at (1420, 1218)
# [ 0] 20:22:32.0 Driver arrived at Customer 17 at (1420, 1218)
# [ 0] 20:23:32.0 Customer 17 at (1420, 1218) not at home
# [ 0] 20:23:32.0 Driver returns to delivery centre
# [ 0] 21:10:00.6 Driver arrived at delivery centre
# [ 0] 21:10:00.6 Parcel 15 for cust 38 return from delivery
# [ 0] 21:10:30.6 Parcel 16 for cust 41 return from delivery
# [ 0] 21:11:00.6 Parcel 24 for cust 64 return from delivery
# [ 0] 21:11:30.6 Parcel 29 for cust 69 return from delivery
# [ 0] 21:12:00.6 Parcel 33 for cust 88 return from delivery
# [ 0] 21:12:30.6 Parcel 17 for cust 52 return from delivery
# [ 0] 21:13:00.6 Parcel 18 for cust 52 return from delivery
# [ 0] 21:13:30.6 Parcel 13 for cust 25 return from delivery
# [ 0] 21:14:00.6 Parcel 6 for cust 9 return from delivery
# [ 0] 21:14:30.6 Parcel 7 for cust 9 return from delivery
# [ 0] 21:15:00.6 Parcel 5 for cust 7 return from delivery
# [ 0] 21:15:30.6 Parcel 4 for cust 6 return from delivery
# [ 0] 21:16:00.6 Parcel 2 for cust 4 return from delivery
# [ 0] 21:16:30.6 Parcel 3 for cust 4 return from delivery
# [ 0] 21:17:00.6 Parcel 1 for cust 2 return from delivery
# [ 0] 21:17:30.6 Parcel 8 for cust 11 return from delivery
# [ 0] 21:18:00.6 Parcel 9 for cust 11 return from delivery
# [ 0] 21:18:30.6 Parcel 10 for cust 12 return from delivery
# [ 0] 21:19:00.6 Parcel 12 for cust 17 return from delivery
# [ 0] 21:19:30.6 33 parcels left for next day
# [ 0] 21:29:30.6 Driver goes home
# [ 1] 17:00:00.0 Parcel 36 for cust 5 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 37 for cust 6 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 38 for cust 10 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 39 for cust 12 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 40 for cust 13 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 41 for cust 13 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 42 for cust 17 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 43 for cust 20 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 44 for cust 25 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 45 for cust 26 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 46 for cust 29 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 47 for cust 40 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 48 for cust 47 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 49 for cust 52 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 50 for cust 60 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 51 for cust 61 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 52 for cust 61 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 53 for cust 62 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 54 for cust 64 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 55 for cust 74 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 56 for cust 75 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 57 for cust 76 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 58 for cust 78 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 59 for cust 79 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 60 for cust 81 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 61 for cust 89 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 62 for cust 90 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 63 for cust 95 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 64 for cust 98 arr at delivery centre
# [ 1] 18:00:00.0 Driver arrives for work
# [ 1] 18:00:00.0 Parcel 15 for cust 38 out for delivery
# [ 1] 18:00:00.0 Parcel 47 for cust 40 out for delivery
# [ 1] 18:00:00.0 Parcel 16 for cust 41 out for delivery
# [ 1] 18:00:00.0 Parcel 38 for cust 10 out for delivery
# [ 1] 18:00:00.0 Parcel 6 for cust 9 out for delivery
# [ 1] 18:00:00.0 Parcel 7 for cust 9 out for delivery
# [ 1] 18:00:00.0 Parcel 5 for cust 7 out for delivery
# [ 1] 18:00:00.0 Parcel 4 for cust 6 out for delivery
# [ 1] 18:00:00.0 Parcel 37 for cust 6 out for delivery
# [ 1] 18:00:00.0 Parcel 36 for cust 5 out for delivery
# [ 1] 18:00:00.0 Parcel 2 for cust 4 out for delivery
# [ 1] 18:00:00.0 Parcel 3 for cust 4 out for delivery
# [ 1] 18:00:00.0 Parcel 1 for cust 2 out for delivery
# [ 1] 18:00:00.0 Parcel 8 for cust 11 out for delivery
# [ 1] 18:00:00.0 Parcel 9 for cust 11 out for delivery
# [ 1] 18:00:00.0 Parcel 10 for cust 12 out for delivery
# [ 1] 18:00:00.0 Parcel 39 for cust 12 out for delivery
# [ 1] 18:00:00.0 Parcel 40 for cust 13 out for delivery
# [ 1] 18:00:00.0 Parcel 41 for cust 13 out for delivery
# [ 1] 18:00:00.0 Parcel 12 for cust 17 out for delivery
# [ 1] 18:00:00.0 Parcel 42 for cust 17 out for delivery
# [ 1] 18:00:00.0 Parcel 43 for cust 20 out for delivery
# [ 1] 18:00:00.0 Parcel 46 for cust 29 out for delivery
# [ 1] 18:00:00.0 Parcel 48 for cust 47 out for delivery
# [ 1] 18:00:00.0 Parcel 19 for cust 57 out for delivery
# [ 1] 18:00:00.0 Parcel 20 for cust 59 out for delivery
# [ 1] 18:00:00.0 Parcel 21 for cust 59 out for delivery
# [ 1] 18:00:00.0 Parcel 22 for cust 60 out for delivery
# [ 1] 18:00:00.0 Parcel 50 for cust 60 out for delivery
# [ 1] 18:00:00.0 Parcel 51 for cust 61 out for delivery
# [ 1] 18:00:00.0 Parcel 52 for cust 61 out for delivery
# [ 1] 18:00:00.0 Parcel 23 for cust 62 out for delivery
# [ 1] 18:00:00.0 Parcel 53 for cust 62 out for delivery
# [ 1] 18:00:00.0 Parcel 14 for cust 35 out for delivery
# [ 1] 18:28:20.0 Driver leaves for delivery of 34 parcels to 23 customers
# [ 1] 18:28:20.0 Length of delivery tour: 39,832m
# [ 1] 18:28:20.0 Driver drives to Customer 38 at (4500, 4765)
# [ 1] 18:29:23.6 Driver arrived at Customer 38 at (4500, 4765)
# [
# [ 1] 21:34:18.0 Parcel 36 for cust 5 return from delivery
# [ 1] 21:34:48.0 Parcel 1 for cust 2 return from delivery
# [ 1] 21:35:18.0 Parcel 8 for cust 11 return from delivery
# [ 1] 21:35:48.0 Parcel 9 for cust 11 return from delivery
# [ 1] 21:36:18.0 Parcel 40 for cust 13 return from delivery
# [ 1] 21:36:48.0 Parcel 41 for cust 13 return from delivery
# [ 1] 21:37:18.0 Parcel 12 for cust 17 return from delivery
# [ 1] 21:37:48.0 Parcel 42 for cust 17 return from delivery
# [ 1] 21:38:18.0 Parcel 43 for cust 20 return from delivery
# [ 1] 21:38:48.0 Parcel 46 for cust 29 return from delivery
# [ 1] 21:39:18.0 Parcel 48 for cust 47 return from delivery
# [ 1] 21:39:48.0 Parcel 19 for cust 57 return from delivery
# [ 1] 21:40:18.0 Parcel 20 for cust 59 return from delivery
# [ 1] 21:40:48.0 Parcel 21 for cust 59 return from delivery
# [ 1] 21:41:18.0 Parcel 22 for cust 60 return from delivery
# [ 1] 21:41:48.0 Parcel 50 for cust 60 return from delivery
# [ 1] 21:42:18.0 Parcel 51 for cust 61 return from delivery
# [ 1] 21:42:48.0 Parcel 52 for cust 61 return from delivery
# [ 1] 21:43:18.0 Parcel 23 for cust 62 return from delivery
# [ 1] 21:43:48.0 Parcel 53 for cust 62 return from delivery
# [ 1] 21:44:18.0 Parcel 14 for cust 35 return from delivery
# [ 1] 21:44:48.0 56 parcels left for next day
# [ 1] 21:54:48.0 Driver goes home
# [ 2] 17:00:00.0 Parcel 65 for cust 9 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 66 for cust 10 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 67 for cust 11 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 68 for cust 12 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 69 for cust 14 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 70 for cust 22 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 71 for cust 24 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 72 for cust 26 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 73 for cust 31 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 74 for cust 32 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 75 for cust 32 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 76 for cust 32 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 77 for cust 34 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 78 for cust 35 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 79 for cust 37 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 80 for cust 39 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 81 for cust 46 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 82 for cust 47 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 83 for cust 48 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 84 for cust 49 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 85 for cust 50 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 86 for cust 61 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 87 for cust 63 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 88 for cust 66 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 89 for cust 73 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 90 for cust 81 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 91 for cust 81 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 92 for cust 84 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 93 for cust 87 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 94 for cust 89 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 95 for cust 89 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 96 for cust 93 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 97 for cust 95 arr at delivery centre
# [ 2] 18:00:00.0 Driver arrives for work
# [ 2] 18:00:00.0 Parcel 15 for cust 38 out for delivery
# [ 2] 18:00:00.0 Parcel 80 for cust 39 out for delivery
# [ 2] 18:00:00.0 Parcel 47 for cust 40 out for delivery
# [ 2] 18:00:00.0 Parcel 16 for cust 41 out for delivery
# [ 2] 18:00:00.0 Parcel 45 for cust 26 out for delivery
# [ 2] 18:00:00.0 Parcel 72 for cust 26 out for delivery
# [ 2] 18:00:00.0 Parcel 70 for cust 22 out for delivery
# [ 2] 18:00:00.0 Parcel 38 for cust 10 out for delivery
# [ 2] 18:00:00.0 Parcel 66 for cust 10 out for delivery
# [ 2] 18:00:00.0 Parcel 65 for cust 9 out for delivery
# [ 2] 18:00:00.0 Parcel 5 for cust 7 out for delivery
# [ 2] 18:00:00.0 Parcel 4 for cust 6 out for delivery
# [ 2] 18:00:00.0 Parcel 37 for cust 6 out for delivery
# [ 2] 18:00:00.0 Parcel 36 for cust 5 out for delivery
# [ 2] 18:00:00.0 Parcel 1 for cust 2 out for delivery
# [ 2] 18:00:00.0 Parcel 8 for cust 11 out for delivery
# [ 2] 18:00:00.0 Parcel 9 for cust 11 out for delivery
# [ 2] 18:00:00.0 Parcel 67 for cust 11 out for delivery
# [ 2] 18:00:00.0 Parcel 68 for cust 12 out for delivery
# [ 2] 18:00:00.0 Parcel 40 for cust 13 out for delivery
# [ 2] 18:00:00.0 Parcel 41 for cust 13 out for delivery
# [ 2] 18:00:00.0 Parcel 12 for cust 17 out for delivery
# [ 2] 18:00:00.0 Parcel 42 for cust 17 out for delivery
# [ 2] 18:00:00.0 Parcel 43 for cust 20 out for delivery
# [ 2] 18:00:00.0 Parcel 46 for cust 29 out for delivery
# [ 2] 18:00:00.0 Parcel 73 for cust 31 out for delivery
# [ 2] 18:00:00.0 Parcel 74 for cust 32 out for delivery
# [ 2] 18:00:00.0 Parcel 75 for cust 32 out for delivery
# [ 2] 18:00:00.0 Parcel 76 for cust 32 out for delivery
# [ 2] 18:00:00.0 Parcel 79 for cust 37 out for delivery
# [ 2] 18:00:00.0 Parcel 48 for cust 47 out for delivery
# [ 2] 18:00:00.0 Parcel 82 for cust 47 out for delivery
# [ 2] 18:00:00.0 Parcel 19 for cust 57 out for delivery
# [ 2] 18:00:00.0 Parcel 25 for cust 65 out for delivery
# [ 2] 18:00:00.0 Parcel 89 for cust 73 out for delivery
# [ 2] 18:00:00.0 Parcel 55 for cust 74 out for delivery
# [ 2] 18:00:00.0 Parcel 56 for cust 75 out for delivery
# [ 2] 18:00:00.0 Parcel 31 for cust 76 out for delivery
# [ 2] 18:00:00.0 Parcel 57 for cust 76 out for delivery
# [ 2] 18:00:00.0 Parcel 58 for cust 78 out for delivery
# [ 2] 18:00:00.0 Parcel 26 for cust 68 out for delivery
# [ 2] 18:00:00.0 Parcel 27 for cust 68 out for delivery
# [ 2] 18:00:00.0 Parcel 28 for cust 68 out for delivery
# [ 2] 18:35:50.0 Driver leaves for delivery of 43 parcels to 30 customers
# [ 2] 18:35:50.0 Length of delivery tour: 39,954m
# [ 2] 18:35:50.0 Driver drives to Customer 38 at (4500, 4765)
# [ 2] 18:36:53.6 Driver arrived at Customer 38 at (4500, 4765)
# [
# [ 2] 20:23:45.9 Customer 76 at (6620, 2144) not at home
# [ 2] 20:23:45.9 Driver drives to Customer 78 at (6620, 2616)
# [ 2] 20:25:39.2 Driver arrived at Customer 78 at (6620, 2616)
# [ 2] 20:26:39.2 Customer 78 at (6620, 2616) not at home
# [ 2] 20:26:39.2 Driver drives to Customer 68 at (6038, 2380)
# [ 2] 20:29:55.5 Driver arrived at Customer 68 at (6038, 2380)
# [ 2] 20:30:55.5 Customer 68 at (6038, 2380) not at home
# [ 2] 20:30:55.5 Driver returns to delivery centre
# [ 2] 21:45:56.0 Driver arrived at delivery centre
# [ 2] 21:45:56.0 Parcel 15 for cust 38 return from delivery
# [ 2] 21:46:26.0 Parcel 80 for cust 39 return from delivery
# [ 2] 21:46:56.0 Parcel 47 for cust 40 return from delivery
# [ 2] 21:47:26.0 Parcel 16 for cust 41 return from delivery
# [ 2] 21:47:56.0 Parcel 45 for cust 26 return from delivery
# [ 2] 21:48:26.0 Parcel 72 for cust 26 return from delivery
# [ 2] 21:48:56.0 Parcel 70 for cust 22 return from delivery
# [ 2] 21:49:26.0 Parcel 38 for cust 10 return from delivery
# [ 2] 21:49:56.0 Parcel 66 for cust 10 return from delivery
# [ 2] 21:50:26.0 Parcel 65 for cust 9 return from delivery
# [ 2] 21:50:56.0 Parcel 5 for cust 7 return from delivery
# [ 2] 21:51:26.0 Parcel 4 for cust 6 return from delivery
# [ 2] 21:51:56.0 Parcel 37 for cust 6 return from delivery
# [ 2] 21:52:26.0 Parcel 36 for cust 5 return from delivery
# [ 2] 21:52:56.0 Parcel 1 for cust 2 return from delivery
# [ 2] 21:53:26.0 Parcel 8 for cust 11 return from delivery
# [ 2] 21:53:56.0 Parcel 9 for cust 11 return from delivery
# [ 2] 21:54:26.0 Parcel 67 for cust 11 return from delivery
# [ 2] 21:54:56.0 Parcel 68 for cust 12 return from delivery
# [ 2] 21:55:26.0 Parcel 40 for cust 13 return from delivery
# [ 2] 21:55:56.0 Parcel 41 for cust 13 return from delivery
# [ 2] 21:56:26.0 Parcel 12 for cust 17 return from delivery
# [ 2] 21:56:56.0 Parcel 42 for cust 17 return from delivery
# [ 2] 21:57:26.0 Parcel 43 for cust 20 return from delivery
# [ 2] 21:57:56.0 Parcel 46 for cust 29 return from delivery
# [ 2] 21:58:26.0 Parcel 73 for cust 31 return from delivery
# [ 2] 21:58:56.0 Parcel 74 for cust 32 return from delivery
# [ 2] 21:59:26.0 Parcel 75 for cust 32 return from delivery
# [ 2] 21:59:56.0 Parcel 76 for cust 32 return from delivery
# [ 2] 22:00:26.0 Parcel 79 for cust 37 return from delivery
# [ 2] 22:00:56.0 Parcel 48 for cust 47 return from delivery
# [ 2] 22:01:26.0 Parcel 82 for cust 47 return from delivery
# [ 2] 22:01:56.0 Parcel 89 for cust 73 return from delivery
# [ 2] 22:02:26.0 Parcel 55 for cust 74 return from delivery
# [ 2] 22:02:56.0 Parcel 56 for cust 75 return from delivery
# [ 2] 22:03:26.0 Parcel 31 for cust 76 return from delivery
# [ 2] 22:03:56.0 Parcel 57 for cust 76 return from delivery
# [ 2] 22:04:26.0 Parcel 58 for cust 78 return from delivery
# [ 2] 22:04:56.0 Parcel 26 for cust 68 return from delivery
# [ 2] 22:05:26.0 Parcel 27 for cust 68 return from delivery
# [ 2] 22:05:56.0 Parcel 28 for cust 68 return from delivery
# [ 2] 22:06:26.0 87 parcels left for next day
# [ 2] 22:16:26.0 Driver goes home
# [ 3] 17:00:00.0 Parcel 98 for cust 2 arr at delivery centre
# [ 3] 17:00:00.0 Parcel 99 for cust 3 arr at delivery centre
# [ 3] 17:00:00.0 Parcel 100 for cust 21 arr at delivery centre
# [ 3] 17:00:00.0 Parcel 101 for cust 28 arr at delivery centre
# [ 3] 17:00:00.0 Parcel 102 for cust 38 arr at delivery centre
# [ 3] 17:00:00.0 Parcel 103 for cust 40 arr at delivery centre
# [ 3] 17:00:00.0 Parcel 104 for cust 48 arr at delivery centre
# [ 3] 17:00:00.0 Parcel 105 for cust 49 arr at delivery centre
# [ 3] 17:00:00.0 Parcel 106 for cust 51 arr at delivery centre
# [ 3] 17:00:00.0 Parcel 107 for cust 58 arr at delivery centre
# [ 3] 17:00:00.0 Parcel 108 for cust 63 arr at delivery centre
# [ 3] 17:00:00.0 Parcel 109 for cust 64 arr at delivery centre
# [ 3] 17:00:00.0 Parcel 110 for cust 66 arr at delivery centre
# [ 3] 17:00:00.0 Parcel 111 for cust 70 arr at delivery centre
# [ 3] 17:00:00.0 Parcel 112 for cust 73 arr at delivery centre
# [ 3] 17:00:00.0 Parcel 113 for cust 84 arr at delivery centre
# [ 3] 17:00:00.0 Parcel 114 for cust 87 arr at delivery centre
# [ 3] 17:00:00.0 Parcel 115 for cust 90 arr at delivery centre
# [ 3] 17:00:00.0 Parcel 116 for cust 99 arr at delivery centre
# [ 3] 18:00:00.0 Driver arrives for work
# [ 3] 18:00:00.0 Parcel 15 for cust 38 out for delivery
# [ 3] 18:00:00.0 Parcel 102 for cust 38 out for delivery
# [ 3] 18:00:00.0 Parcel 80 for cust 39 out for delivery
# [ 3] 18:00:00.0 Parcel 47 for cust 40 out for delivery
# [ 3] 18:00:00.0 Parcel 103 for cust 40 out for delivery
# [ 3] 18:00:00.0 Parcel 16 for cust 41 out for delivery
# [ 3] 18:00:00.0 Parcel 101 for cust 28 out for delivery
# [ 3] 18:00:00.0 Parcel 70 for cust 22 out for delivery
# [ 3] 18:00:00.0 Parcel 100 for cust 21 out for delivery
# [ 3] 18:00:00.0 Parcel 38 for cust 10 out for delivery
# [ 3] 18:00:00.0 Parcel 66 for cust 10 out for delivery
# [ 3] 18:00:00.0 Parcel 65 for cust 9 out for delivery
# [ 3] 18:00:00.0 Parcel 5 for cust 7 out for delivery
# [ 3] 18:00:00.0 Parcel 4 for cust 6 out for delivery
# [ 3] 18:00:00.0 Parcel 37 for cust 6 out for delivery
# [ 3] 18:00:00.0 Parcel 36 for cust 5 out for delivery
# [ 3] 18:00:00.0 Parcel 99 for cust 3 out for delivery
# [ 3] 18:00:00.0 Parcel 1 for cust 2 out for delivery
# [ 3] 18:00:00.0 Parcel 98 for cust 2 out for delivery
# [ 3] 18:00:00.0 Parcel 8 for cust 11 out for delivery
# [ 3] 18:00:00.0 Parcel 9 for cust 11 out for delivery
# [ 3] 18:00:00.0 Parcel 67 for cust 11 out for delivery
# [ 3] 18:00:00.0 Parcel 68 for cust 12 out for delivery
# [ 3] 18:00:00.0 Parcel 40 for cust 13 out for delivery
# [ 3] 18:00:00.0 Parcel 41 for cust 13 out for delivery
# [ 3] 18:00:00.0 Parcel 12 for cust 17 out for delivery
# [ 3] 18:00:00.0 Parcel 42 for cust 17 out for delivery
# [ 3] 18:00:00.0 Parcel 43 for cust 20 out for delivery
# [ 3] 18:00:00.0 Parcel 46 for cust 29 out for delivery
# [ 3] 18:00:00.0 Parcel 73 for cust 31 out for delivery
# [ 3] 18:00:00.0 Parcel 74 for cust 32 out for delivery
# [ 3] 18:00:00.0 Parcel 75 for cust 32 out for delivery
# [ 3] 18:00:00.0 Parcel 76 for cust 32 out for delivery
# [ 3] 18:00:00.0 Parcel 79 for cust 37 out for delivery
# [ 3] 18:00:00.0 Parcel 48 for cust 47 out for delivery
# [ 3] 18:00:00.0 Parcel 82 for cust 47 out for delivery
# [ 3] 18:00:00.0 Parcel 107 for cust 58 out for delivery
# [ 3] 18:00:00.0 Parcel 20 for cust 59 out for delivery
# [ 3] 18:00:00.0 Parcel 21 for cust 59 out for delivery
# [ 3] 18:00:00.0 Parcel 62 for cust 90 out for delivery
# [ 3] 18:00:00.0 Parcel 115 for cust 90 out for delivery
# [ 3] 18:00:00.0 Parcel 34 for cust 93 out for delivery
# [ 3] 18:00:00.0 Parcel 35 for cust 93 out for delivery
# [ 3] 18:00:00.0 Parcel 96 for cust 93 out for delivery
# [ 3] 18:00:00.0 Parcel 45 for cust 26 out for delivery
# [ 3] 18:00:00.0 Parcel 72 for cust 26 out for delivery
# [ 3] 18:00:00.0 Parcel 13 for cust 25 out for delivery
# [ 3] 18:00:00.0 Parcel 44 for cust 25 out for delivery
# [ 3] 18:40:00.0 Driver leaves for delivery of 48 parcels to 30 customers
# [ 3] 18:40:00.0 Length of delivery tour: 39,966m
# [ 3] 18:40:00.0 Driver drives to Customer 38 at (4500, 4765)
# [ 3] 18:41:03.6 Driver arrived at Customer 38 at (4500, 4765)
# [ 3] 18:42:03.6 Customer 38 at (4500, 4765) not at home
# [ 3] 18:42:03.6 Driver drives to Customer 39 at (4500, 4910)
# [ 3] 18:42:38.4 Driver arrived at Customer 39 at (4500, 4910)
# [ 3] 18:43:38.4 Customer 39 at (4500, 4910) not at home
# [ 3] 18:43:38.4 Driver drives to Customer 40 at (4500, 5107)
# [ 3] 18:44:25.7 Driver arrived at Customer 40 at (4500, 5107)
# [ 3] 18:45:25.7 Customer 40 at (4500, 5107) not at home
# [ 3] 18:45:25.7 Driver drives to Customer 41 at (4500, 5208)
# [ 3] 18:45:49.9 Driver arrived at Customer 41 at (4500, 5208)
# [ 3] 18:46:49.9 Customer 41 at (4500, 5208) not at home
# [ 3] 18:46:49.9 Driver drives to Customer 28 at (2879, 6620)
# [ 3] 18:56:28.8 Driver arrived at Customer 28 at (2879, 6620)
# [ 3] 18:57:28.8 Customer 28 at (2879, 6620) not at home
# [ 3] 18:57:28.8 Driver drives to Customer 22 at (1969, 6620)
# [ 3] 19:01:07.2 Driver arrived at Customer 22 at (1969, 6620)
# [ 3] 19:02:07.2 Customer 22 at (1969, 6620) not at home
# [ 3] 19:02:07.2 Driver drives to Customer 21 at (1791, 6620)
# [ 3] 19:02:49.9 Driver arrived at Customer 21 at (1791, 6620)
# [ 3] 19:03:49.9 Customer 21 at (1791, 6620) not at home
# [ 3] 19:03:49.9 Driver drives to Customer 10 at (671, 6620)
# [ 3] 19:08:18.7 Driver arrived at Customer 10 at (671, 6620)
# [ 3] 19:09:18.7 Customer 10 at (671, 6620) not at home
# [ 3] 19:09:18.7 Driver drives to Customer 9 at (260, 6204)
# [ 3] 19:12:37.2 Driver arrived at Customer 9 at (260, 6204)
# [ 3] 19:13:37.2 Customer 9 at (260, 6204) not at home
# [ 3] 19:13:37.2 Driver drives to Customer 7 at (260, 5340)
# [ 3] 19:17:04.6 Driver arrived at Customer 7 at (260, 5340)
# [ 3] 19:18:04.6 Customer 7 at (260, 5340) not at home
# [ 3] 19:18:04.6 Driver drives to Customer 6 at (260, 5225)
# [ 3] 19:18:32.2 Driver arrived at Customer 6 at (260, 5225)
# [ 3] 19:19:32.2 Customer 6 at (260, 5225) not at home
# [ 3] 19:19:32.2 Driver drives to Customer 5 at (260, 5135)
# [ 3] 19:19:53.8 Driver arrived at Customer 5 at (260, 5135)
# [ 3] 19:20:53.8 Customer 5 at (260, 5135) not at home
# [ 3] 19:20:53.8 Driver drives to Customer 3 at (260, 4918)
# [ 3] 19:21:45.8 Driver arrived at Customer 3 at (260, 4918)
# [ 3] 19:22:45.8 Customer 3 at (260, 4918) not at home
# [ 3] 19:22:45.8 Driver drives to Customer 2 at (260, 4756)
# [ 3] 19:23:24.7 Driver arrived at Customer 2 at (260, 4756)
# [ 3] 19:24:24.7 Customer 2 at (260, 4756) not at home
# [ 3] 19:24:24.7 Driver drives to Customer 11 at (703, 2996)
# [ 3] 19:32:11.0 Driver arrived at Customer 11 at (703, 2996)
# [ 3] 19:33:11.0 Customer 11 at (703, 2996) not at home
# [ 3] 19:33:11.0 Driver drives to Customer 12 at (1104, 2594)
# [ 3] 19:35:27.1 Driver arrived at Customer 12 at (1104, 2594)
# [ 3] 19:36:27.1 Customer 12 at (1104, 2594) not at home
# [ 3] 19:36:27.1 Driver drives to Customer 13 at (1320, 1929)
# [ 3] 19:39:28.3 Driver arrived at Customer 13 at (1320, 1929)
# [ 3] 19:40:28.3 Customer 13 at (1320, 1929) not at home
# [ 3] 19:40:28.3 Driver drives to Customer 17 at (1420, 1218)
# [ 3] 19:43:28.6 Driver arrived at Customer 17 at (1420, 1218)
# [ 3] 19:44:28.6 Customer 17 at (1420, 1218) not at home
# [ 3] 19:44:28.6 Driver drives to Customer 20 at (1739, 900)
# [ 3] 19:46:16.6 Driver arrived at Customer 20 at (1739, 900)
# [ 3] 19:47:16.6 Customer 20 at (1739, 900) not at home
# [ 3] 19:47:16.6 Driver drives to Customer 29 at (2994, 260)
# [ 3] 19:53:21.1 Driver arrived at Customer 29 at (2994, 260)
# [ 3] 19:54:21.1 Customer 29 at (2994, 260) not at home
# [ 3] 19:54:21.1 Driver drives to Customer 31 at (3101, 260)
# [ 3] 19:54:46.8 Driver arrived at Customer 31 at (3101, 260)
# [ 3] 19:55:46.8 Customer 31 at (3101, 260) not at home
# [ 3] 19:55:46.8 Driver drives to Customer 32 at (3248, 260)
# [ 3] 19:56:22.1 Driver arrived at Customer 32 at (3248, 260)
# [ 3] 19:57:22.1 Customer 32 at (3248, 260) not at home
# [ 3] 19:57:22.1 Driver drives to Customer 37 at (4138, 260)
# [ 3] 20:00:55.7 Driver arrived at Customer 37 at (4138, 260)
# [ 3] 20:01:55.7 Customer 37 at (4138, 260) not at home
# [ 3] 20:01:55.7 Driver drives to Customer 47 at (4825, 260)
# [ 3] 20:04:40.6 Driver arrived at Customer 47 at (4825, 260)
# [ 3] 20:05:40.6 Customer 47 at (4825, 260) not at home
# [ 3] 20:05:40.6 Driver drives to Customer 58 at (5560, 1479)
# [ 3] 20:13:29.5 Driver arrived at Customer 58 at (5560, 1479)
# [ 3] 20:14:29.5 Customer 58 at (5560, 1479) not at home
# [ 3] 20:14:29.5 Driver drives to Customer 59 at (5560, 1672)
# [ 3] 20:15:15.8 Driver arrived at Customer 59 at (5560, 1672)
# [ 3] 20:16:15.8 Customer 59 at (5560, 1672) not at home
# [ 3] 20:16:15.8 Driver drives to Customer 90 at (6864, 1320)
# [ 3] 20:22:53.3 Driver arrived at Customer 90 at (6864, 1320)
# [ 3] 20:23:53.3 Customer 90 at (6864, 1320) not at home
# [ 3] 20:23:53.3 Driver drives to Customer 93 at (7296, 1320)
# [ 3] 20:25:37.0 Driver arrived at Customer 93 at (7296, 1320)
# [ 3] 20:26:37.0 Customer 93 at (7296, 1320) not at home
# [ 3] 20:26:37.0 Driver drives to Customer 26 at (2380, 6213)
# [ 3] 21:29:34.1 Driver arrived at Customer 26 at (2380, 6213)
# [ 3] 21:30:34.1 Customer 26 at (2380, 6213) not at home
# [ 3] 21:30:34.1 Driver drives to Customer 25 at (2380, 5939)
# [ 3] 21:31:39.8 Driver arrived at Customer 25 at (2380, 5939)
# [ 3] 21:32:39.8 Customer 25 at (2380, 5939) not at home
# [ 3] 21:32:39.8 Driver returns to delivery centre
# [ 3] 21:49:51.8 Driver arrived at delivery centre
# [ 3] 21:49:51.8 Parcel 15 for cust 38 return from delivery
# [ 3] 21:50:21.8 Parcel 102 for cust 38 return from delivery
# [ 3] 21:50:51.8 Parcel 80 for cust 39 return from delivery
# [ 3] 21:51:21.8 Parcel 47 for cust 40 return from delivery
# [ 3] 21:51:51.8 Parcel 103 for cust 40 return from delivery
# [ 3] 21:52:21.8 Parcel 16 for cust 41 return from delivery
# [ 3] 21:52:51.8 Parcel 101 for cust 28 return from delivery
# [ 3] 21:53:21.8 Parcel 70 for cust 22 return from delivery
# [ 3] 21:53:51.8 Parcel 100 for cust 21 return from delivery
# [ 3] 21:54:21.8 Parcel 38 for cust 10 return from delivery
# [ 3] 21:54:51.8 Parcel 66 for cust 10 return from delivery
# [ 3] 21:55:21.8 Parcel 65 for cust 9 return from delivery
# [ 3] 21:55:51.8 Parcel 5 for cust 7 return from delivery
# [ 3] 21:56:21.8 Parcel 4 for cust 6 return from delivery
# [ 3] 21:56:51.8 Parcel 37 for cust 6 return from delivery
# [ 3] 21:57:21.8 Parcel 36 for cust 5 return from delivery
# [ 3] 21:57:51.8 Parcel 99 for cust 3 return from delivery
# [ 3] 21:58:21.8 Parcel 1 for cust 2 return from delivery
# [ 3] 21:58:51.8 Parcel 98 for cust 2 return from delivery
# [ 3] 21:59:21.8 Parcel 8 for cust 11 return from delivery
# [ 3] 21:59:51.8 Parcel 9 for cust 11 return from delivery
# [ 3] 22:00:21.8 Parcel 67 for cust 11 return from delivery
# [ 3] 22:00:51.8 Parcel 68 for cust 12 return from delivery
# [ 3] 22:01:21.8 Parcel 40 for cust 13 return from delivery
# [ 3] 22:01:51.8 Parcel 41 for cust 13 return from delivery
# [ 3] 22:02:21.8 Parcel 12 for cust 17 return from delivery
# [ 3] 22:02:51.8 Parcel 42 for cust 17 return from delivery
# [ 3] 22:03:21.8 Parcel 43 for cust 20 return from delivery
# [ 3] 22:03:51.8 Parcel 46 for cust 29 return from delivery
# [ 3] 22:04:21.8 Parcel 73 for cust 31 return from delivery
# [ 3] 22:04:51.8 Parcel 74 for cust 32 return from delivery
# [ 3] 22:05:21.8 Parcel 75 for cust 32 return from delivery
# [ 3] 22:05:51.8 Parcel 76 for cust 32 return from delivery
# [ 3] 22:06:21.8 Parcel 79 for cust 37 return from delivery
# [ 3] 22:06:51.8 Parcel 48 for cust 47 return from delivery
# [ 3] 22:07:21.8 Parcel 82 for cust 47 return from delivery
# [ 3] 22:07:51.8 Parcel 107 for cust 58 return from delivery
# [ 3] 22:08:21.8 Parcel 20 for cust 59 return from delivery
# [ 3] 22:08:51.8 Parcel 21 for cust 59 return from delivery
# [ 3] 22:09:21.8 Parcel 62 for cust 90 return from delivery
# [ 3] 22:09:51.8 Parcel 115 for cust 90 return from delivery
# [ 3] 22:10:21.8 Parcel 34 for cust 93 return from delivery
# [ 3] 22:10:51.8 Parcel 35 for cust 93 return from delivery
# [ 3] 22:11:21.8 Parcel 96 for cust 93 return from delivery
# [ 3] 22:11:51.8 Parcel 45 for cust 26 return from delivery
# [ 3] 22:12:21.8 Parcel 72 for cust 26 return from delivery
# [ 3] 22:12:51.8 Parcel 13 for cust 25 return from delivery
# [ 3] 22:13:21.8 Parcel 44 for cust 25 return from delivery
# [ 3] 22:13:51.8 106 parcels left for next day
# [ 3] 22:23:51.8 Driver goes home
# Delivery Centre Inventory: 106 parcels

# %%
rec3 = simulation(M, W, C, p=0.6, days=4, log=True)
# Out:
# Simulating delivery of 227 parcels over 4 days to 100 customers
# [ 0] 17:00:00.0 Parcel 0 for cust 1 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 1 for cust 2 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 2 for cust 7 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 3 for cust 12 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 4 for cust 13 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 5 for cust 15 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 6 for cust 16 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 7 for cust 19 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 8 for cust 23 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 9 for cust 29 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 10 for cust 37 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 11 for cust 38 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 12 for cust 39 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 13 for cust 43 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 14 for cust 43 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 15 for cust 44 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 16 for cust 44 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 17 for cust 44 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 18 for cust 45 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 19 for cust 45 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 20 for cust 46 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 21 for cust 47 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 22 for cust 49 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 23 for cust 50 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 24 for cust 51 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 25 for cust 52 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 26 for cust 53 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 27 for cust 55 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 28 for cust 55 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 29 for cust 56 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 30 for cust 58 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 31 for cust 59 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 32 for cust 61 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 33 for cust 62 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 34 for cust 66 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 35 for cust 68 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 36 for cust 69 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 37 for cust 70 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 38 for cust 70 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 39 for cust 71 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 40 for cust 72 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 41 for cust 73 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 42 for cust 73 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 43 for cust 76 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 44 for cust 76 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 45 for cust 76 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 46 for cust 79 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 47 for cust 84 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 48 for cust 84 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 49 for cust 85 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 50 for cust 86 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 51 for cust 86 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 52 for cust 86 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 53 for cust 87 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 54 for cust 90 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 55 for cust 91 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 56 for cust 95 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 57 for cust 95 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 58 for cust 95 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 59 for cust 97 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 60 for cust 98 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 61 for cust 99 arr at delivery centre
# [ 0] 18:00:00.0 Driver arrives for work
# [ 0] 18:00:00.0 Parcel 11 for cust 38 out for delivery
# [ 0] 18:00:00.0 Parcel 12 for cust 39 out for delivery
# [ 0] 18:00:00.0 Parcel 24 for cust 51 out for delivery
# [ 0] 18:00:00.0 Parcel 26 for cust 53 out for delivery
# [ 0] 18:00:00.0 Parcel 8 for cust 23 out for delivery
# [ 0] 18:00:00.0 Parcel 5 for cust 15 out for delivery
# [ 0] 18:00:00.0 Parcel 6 for cust 16 out for delivery
# [ 0] 18:00:00.0 Parcel 2 for cust 7 out for delivery
# [ 0] 18:00:00.0 Parcel 1 for cust 2 out for delivery
# [ 0] 18:00:00.0 Parcel 0 for cust 1 out for delivery
# [ 0] 18:00:00.0 Parcel 3 for cust 12 out for delivery
# [ 0] 18:00:00.0 Parcel 4 for cust 13 out for delivery
# [ 0] 18:00:00.0 Parcel 7 for cust 19 out for delivery
# [ 0] 18:00:00.0 Parcel 9 for cust 29 out for delivery
# [ 0] 18:00:00.0 Parcel 10 for cust 37 out for delivery
# [ 0] 18:00:00.0 Parcel 15 for cust 44 out for delivery
# [ 0] 18:00:00.0 Parcel 16 for cust 44 out for delivery
# [ 0] 18:00:00.0 Parcel 17 for cust 44 out for delivery
# [ 0] 18:00:00.0 Parcel 18 for cust 45 out for delivery
# [ 0] 18:00:00.0 Parcel 19 for cust 45 out for delivery
# [ 0] 18:00:00.0 Parcel 21 for cust 47 out for delivery
# [ 0] 18:00:00.0 Parcel 27 for cust 55 out for delivery
# [ 0] 18:00:00.0 Parcel 28 for cust 55 out for delivery
# [ 0] 18:00:00.0 Parcel 29 for cust 56 out for delivery
# [ 0] 18:00:00.0 Parcel 30 for cust 58 out for delivery
# [ 0] 18:00:00.0 Parcel 31 for cust 59 out for delivery
# [ 0] 18:00:00.0 Parcel 32 for cust 61 out for delivery
# [ 0] 18:00:00.0 Parcel 33 for cust 62 out for delivery
# [ 0] 18:23:20.0 Driver leaves for delivery of 28 parcels to 24 customers
# [ 0] 18:23:20.0 Length of delivery tour: 39,024m
# [ 0] 18:23:20.0 Driver drives to Customer 38 at (4500, 4765)
# [ 0] 18:24:23.6 Driver arrived at Customer 38 at (4500, 4765)
# [ 0] 18:25:23.6 Customer 38 at (4500, 4765) not at home
# [ 0] 18:25:23.6 Driver drives to Customer 39 at (4500, 4910)
# [ 0] 18:25:58.4 Driver arrived at Customer 39 at (4500, 4910)
# [ 0] 18:26:58.4 Customer 39 at (4500, 4910) not at home
# [ 0] 18:26:58.4 Driver drives to Customer 51 at (5082, 5560)
# [ 0] 18:31:54.1 Driver arrived at Customer 51 at (5082, 5560)
# [ 0] 18:32:54.1 Customer 51 at (5082, 5560) not at home
# [ 0] 18:32:54.1 Driver drives to Customer 53 at (5247, 5560)
# [ 0] 18:33:33.7 Driver arrived at Customer 53 at (5247, 5560)
# [ 0] 18:34:11.5 Customer 53 at (5247, 5560) answers door
# [ 0] 18:34:11.5 Customer 53 at (5247, 5560) accepts Parcel 26 for cust 53
# [ 0] 18:34:16.4 Customer 53 at (5247, 5560) signs off
# [ 0] 18:34:16.9 Driver drives to Customer 23 at (2106, 6620)
# [ 0] 18:48:36.1 Driver arrived at Customer 23 at (2106, 6620)
# [ 0] 18:49:36.1 Customer 23 at (2106, 6620) not at home
# [ 0] 18:49:36.1 Driver drives to Customer 15 at (1320, 7071)
# [ 0] 18:54:33.0 Driver arrived at Customer 15 at (1320, 7071)
# [ 0] 18:54:58.4 Customer 15 at (1320, 7071) answers door
# [ 0] 18:54:58.4 Customer 15 at (1320, 7071) accepts Parcel 5 for cust 15
# [ 0] 18:55:00.1 Customer 15 at (1320, 7071) signs off
# [ 0] 18:55:00.4 Driver drives to Customer 16 at (1320, 7339)
# [ 0] 18:56:04.7 Driver arrived at Customer 16 at (1320, 7339)
# [ 0] 18:57:04.7 Customer 16 at (1320, 7339) not at home
# [ 0] 18:57:04.7 Driver drives to Customer 7 at (260, 5340)
# [ 0] 19:09:18.9 Driver arrived at Customer 7 at (260, 5340)
# [ 0] 19:09:57.3 Customer 7 at (260, 5340) answers door
# [ 0] 19:09:57.3 Customer 7 at (260, 5340) accepts Parcel 2 for cust 7
# [ 0] 19:10:07.3 Customer 7 at (260, 5340) signs off
# [ 0] 19:10:08.4 Driver drives to Customer 2 at (260, 4756)
# [ 0] 19:12:28.5 Driver arrived at Customer 2 at (260, 4756)
# [ 0] 19:13:28.5 Customer 2 at (260, 4756) not at home
# [ 0] 19:13:28.5 Driver drives to Customer 1 at (260, 4584)
# [ 0] 19:14:09.8 Driver arrived at Customer 1 at (260, 4584)
# [ 0] 20:08:07.3 Customer 61 at (5560, 2022) answers door
# [ 0] 20:08:07.3 Customer 61 at (5560, 2022) accepts Parcel 32 for cust 61
# [ 0] 20:08:28.6 Customer 61 at (5560, 2022) signs off
# [ 0] 20:08:38.0 Driver drives to Customer 62 at (5560, 2149)
# [ 0] 20:09:08.5 Driver arrived at Customer 62 at (5560, 2149)
# [ 0] 20:10:08.5 Customer 62 at (5560, 2149) not at home
# [ 0] 20:10:08.5 Driver returns to delivery centre
# [ 0] 21:22:19.5 Driver arrived at delivery centre
# [ 0] 21:22:19.5 Parcel 11 for cust 38 return from delivery
# [ 0] 21:22:49.5 Parcel 12 for cust 39 return from delivery
# [ 0] 21:23:19.5 Parcel 24 for cust 51 return from delivery
# [ 0] 21:23:49.5 Parcel 8 for cust 23 return from delivery
# [ 0] 21:24:19.5 Parcel 6 for cust 16 return from delivery
# [ 0] 21:24:49.5 Parcel 1 for cust 2 return from delivery
# [ 0] 21:25:19.5 Parcel 0 for cust 1 return from delivery
# [ 0] 21:25:49.5 Parcel 3 for cust 12 return from delivery
# [ 0] 21:26:19.5 Parcel 4 for cust 13 return from delivery
# [ 0] 21:26:49.5 Parcel 7 for cust 19 return from delivery
# [ 0] 21:27:19.5 Parcel 9 for cust 29 return from delivery
# [ 0] 21:27:49.5 Parcel 10 for cust 37 return from delivery
# [ 0] 21:28:19.5 Parcel 15 for cust 44 return from delivery
# [ 0] 21:28:49.5 Parcel 16 for cust 44 return from delivery
# [ 0] 21:29:19.5 Parcel 17 for cust 44 return from delivery
# [ 0] 21:29:49.5 Parcel 18 for cust 45 return from delivery
# [ 0] 21:30:19.5 Parcel 19 for cust 45 return from delivery
# [ 0] 21:30:49.5 Parcel 21 for cust 47 return from delivery
# [ 0] 21:31:19.5 Parcel 29 for cust 56 return from delivery
# [ 0] 21:31:49.5 Parcel 30 for cust 58 return from delivery
# [ 0] 21:32:19.5 Parcel 31 for cust 59 return from delivery
# [ 0] 21:32:49.5 Parcel 33 for cust 62 return from delivery
# [ 0] 21:33:19.5 56 parcels left for next day
# [ 0] 21:43:19.5 Driver goes home
# [ 1] 17:00:00.0 Parcel 62 for cust 1 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 63 for cust 2 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 64 for cust 3 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 65 for cust 3 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 66 for cust 4 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 67 for cust 8 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 68 for cust 9 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 69 for cust 11 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 70 for cust 14 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 71 for cust 14 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 72 for cust 15 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 73 for cust 16 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 74 for cust 18 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 75 for cust 19 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 76 for cust 22 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 77 for cust 24 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 78 for cust 28 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 79 for cust 32 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 80 for cust 36 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 81 for cust 39 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 82 for cust 40 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 83 for cust 41 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 84 for cust 45 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 85 for cust 45 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 86 for cust 46 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 87 for cust 46 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 88 for cust 46 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 89 for cust 47 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 90 for cust 50 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 91 for cust 51 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 92 for cust 54 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 93 for cust 54 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 94 for cust 55 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 95 for cust 56 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 96 for cust 57 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 97 for cust 58 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 98 for cust 60 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 99 for cust 62 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 100 for cust 64 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 101 for cust 64 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 102 for cust 67 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 103 for cust 67 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 104 for cust 73 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 105 for cust 75 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 106 for cust 80 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 107 for cust 81 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 108 for cust 82 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 109 for cust 82 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 110 for cust 82 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 111 for cust 85 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 112 for cust 88 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 113 for cust 90 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 114 for cust 93 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 115 for cust 94 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 116 for cust 94 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 117 for cust 94 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 118 for cust 96 arr at delivery centre
# [ 1] 18:00:00.0 Driver arrives for work
# [ 1] 18:00:00.0 Parcel 11 for cust 38 out for delivery
# [ 1] 18:00:00.0 Parcel 12 for cust 39 out for delivery
# [ 1] 18:00:00.0 Parcel 81 for cust 39 out for delivery
# [ 1] 18:00:00.0 Parcel 82 for cust 40 out for delivery
# [ 1] 18:00:00.0 Parcel 83 for cust 41 out for delivery
# [ 1] 18:00:00.0 Parcel 80 for cust 36 out for delivery
# [ 1] 18:00:00.0 Parcel 78 for cust 28 out for delivery
# [ 1] 18:00:00.0 Parcel 8 for cust 23 out for delivery
# [ 1] 18:00:00.0 Parcel 76 for cust 22 out for delivery
# [ 1] 18:00:00.0 Parcel 68 for cust 9 out for delivery
# [ 1] 18:00:00.0 Parcel 67 for cust 8 out for delivery
# [ 1] 18:00:00.0 Parcel 66 for cust 4 out for delivery
# [ 1] 18:00:00.0 Parcel 64 for cust 3 out for delivery
# [ 1] 18:00:00.0 Parcel 65 for cust 3 out for delivery
# [ 1] 18:00:00.0 Parcel 1 for cust 2 out for delivery
# [ 1] 18:00:00.0 Parcel 63 for cust 2 out for delivery
# [ 1] 18:00:00.0 Parcel 0 for cust 1 out for delivery
# [ 1] 18:00:00.0 Parcel 62 for cust 1 out for delivery
# [ 1] 18:00:00.0 Parcel 69 for cust 11 out for delivery
# [ 1] 18:00:00.0 Parcel 70 for cust 14 out for delivery
# [ 1] 18:00:00.0 Parcel 71 for cust 14 out for delivery
# [ 1] 18:00:00.0 Parcel 72 for cust 15 out for delivery
# [ 1] 18:00:00.0 Parcel 6 for cust 16 out for delivery
# [ 1] 18:00:00.0 Parcel 73 for cust 16 out for delivery
# [ 1] 18:00:00.0 Parcel 24 for cust 51 out for delivery
# [ 1] 18:00:00.0 Parcel 91 for cust 51 out for delivery
# [ 1] 18:00:00.0 Parcel 92 for cust 54 out for delivery
# [ 1] 18:00:00.0 Parcel 93 for cust 54 out for delivery
# [ 1] 18:00:00.0 Parcel 100 for cust 64 out for delivery
# [ 1] 18:00:00.0 Parcel 101 for cust 64 out for delivery
# [ 1] 18:00:00.0 Parcel 102 for cust 67 out for delivery
# [ 1] 18:00:00.0 Parcel 103 for cust 67 out for delivery
# [ 1] 18:00:00.0 Parcel 36 for cust 69 out for delivery
# [ 1] 18:00:00.0 Parcel 39 for cust 71 out for delivery
# [ 1] 18:00:00.0 Parcel 55 for cust 91 out for delivery
# [ 1] 18:00:00.0 Parcel 115 for cust 94 out for delivery
# [ 1] 18:00:00.0 Parcel 116 for cust 94 out for delivery
# [ 1] 18:00:00.0 Parcel 117 for cust 94 out for delivery
# [ 1] 18:00:00.0 Parcel 59 for cust 97 out for delivery
# [ 1] 18:00:00.0 Parcel 61 for cust 99 out for delivery
# [ 1] 18:00:00.0 Parcel 47 for cust 84 out for delivery
# [ 1] 18:00:00.0 Parcel 48 for cust 84 out for delivery
# [ 1] 18:00:00.0 Parcel 49 for cust 85 out for delivery
# [ 1] 18:00:00.0 Parcel 111 for cust 85 out for delivery
# [ 1] 18:00:00.0 Parcel 50 for cust 86 out for delivery
# [ 1] 18:00:00.0 Parcel 51 for cust 86 out for delivery
# [ 1] 18:00:00.0 Parcel 52 for cust 86 out for delivery
# [ 1] 18:00:00.0 Parcel 53 for cust 87 out for delivery
# [ 1] 18:00:00.0 Parcel 112 for cust 88 out for delivery
# [ 1] 18:00:00.0 Parcel 25 for cust 52 out for delivery
# [ 1] 18:00:00.0 Parcel 23 for cust 50 out for delivery
# [ 1] 18:00:00.0 Parcel 90 for cust 50 out for delivery
# [ 1] 18:00:00.0 Parcel 22 for cust 49 out for delivery
# [ 1] 18:00:00.0 Parcel 20 for cust 46 out for delivery
# [ 1] 18:00:00.0 Parcel 86 for cust 46 out for delivery
# [ 1] 18:00:00.0 Parcel 87 for cust 46 out for delivery
# [ 1] 18:00:00.0 Parcel 88 for cust 46 out for delivery
# [ 1] 18:00:00.0 Parcel 13 for cust 43 out for delivery
# [ 1] 18:00:00.0 Parcel 14 for cust 43 out for delivery
# [ 1] 18:49:10.0 Driver leaves for delivery of 59 parcels to 38 customers
# [ 1] 18:49:10.0 Length of delivery tour: 39,732m
# [ 1] 18:49:10.0 Driver drives to Customer 38 at (4500, 4765)
# [ 1] 18:50:13.6 Driver arrived at Customer 38 at (4500, 4765)
# [ 1] 18:51:13.6 Customer 38 at (4500, 4765) not at home
# [ 1] 18:51:13.6 Driver drives to Customer 39 at (4500, 4910)
# [ 1] 18:51:48.4 Driver arrived at Customer 39 at (4500, 4910)
# [ 1] 18:52:48.4 Customer 39 at (4500, 4910) not at home
# [ 1] 18:52:48.4 Driver drives to Customer 40 at (4500, 5107)
# [ 1] 18:53:35.7 Driver arrived at Customer 40 at (4500, 5107)
# [ 1] 18:54:35.7 Customer 40 at (4500, 5107) not at home
# [ 1] 18:54:35.7 Driver drives to Customer 41 at (4500, 5208)
# [ 1] 18:54:59.9 Driver arrived at Customer 41 at (4500, 5208)
# [ 1] 18:55:59.9 Customer 41 at (4500, 5208) not at home
# [ 1] 18:55:59.9 Driver drives to Customer 36 at (4043, 6016)
# [ 1] 18:59:59.2 Driver arrived at Customer 36 at (4043, 6016)
# [ 1] 19:00:04.9 Customer 36 at (4043, 6016) answers door
# [ 1] 19:00:04.9 Customer 36 at (4043, 6016) accepts Parcel 80 for cust 36
# [ 1] 22:08:07.6 Parcel 67 for cust 8 return from delivery
# [ 1] 22:08:37.6 Parcel 66 for cust 4 return from delivery
# [ 1] 22:09:07.6 Parcel 64 for cust 3 return from delivery
# [ 1] 22:09:37.6 Parcel 65 for cust 3 return from delivery
# [ 1] 22:10:07.6 Parcel 1 for cust 2 return from delivery
# [ 1] 22:10:37.6 Parcel 63 for cust 2 return from delivery
# [ 1] 22:11:07.6 Parcel 0 for cust 1 return from delivery
# [ 1] 22:11:37.6 Parcel 62 for cust 1 return from delivery
# [ 1] 22:12:07.6 Parcel 69 for cust 11 return from delivery
# [ 1] 22:12:37.6 Parcel 70 for cust 14 return from delivery
# [ 1] 22:13:07.6 Parcel 71 for cust 14 return from delivery
# [ 1] 22:13:37.6 Parcel 72 for cust 15 return from delivery
# [ 1] 22:14:07.6 Parcel 24 for cust 51 return from delivery
# [ 1] 22:14:37.6 Parcel 91 for cust 51 return from delivery
# [ 1] 22:15:07.6 Parcel 92 for cust 54 return from delivery
# [ 1] 22:15:37.6 Parcel 93 for cust 54 return from delivery
# [ 1] 22:16:07.6 Parcel 100 for cust 64 return from delivery
# [ 1] 22:16:37.6 Parcel 101 for cust 64 return from delivery
# [ 1] 22:17:07.6 Parcel 102 for cust 67 return from delivery
# [ 1] 22:17:37.6 Parcel 103 for cust 67 return from delivery
# [ 1] 22:18:07.6 Parcel 36 for cust 69 return from delivery
# [ 1] 22:18:37.6 Parcel 39 for cust 71 return from delivery
# [ 1] 22:19:07.6 Parcel 115 for cust 94 return from delivery
# [ 1] 22:19:37.6 Parcel 116 for cust 94 return from delivery
# [ 1] 22:20:07.6 Parcel 117 for cust 94 return from delivery
# [ 1] 22:20:37.6 Parcel 59 for cust 97 return from delivery
# [ 1] 22:21:07.6 Parcel 61 for cust 99 return from delivery
# [ 1] 22:21:37.6 Parcel 47 for cust 84 return from delivery
# [ 1] 22:22:07.6 Parcel 48 for cust 84 return from delivery
# [ 1] 22:22:37.6 Parcel 49 for cust 85 return from delivery
# [ 1] 22:23:07.6 Parcel 111 for cust 85 return from delivery
# [ 1] 22:23:37.6 Parcel 53 for cust 87 return from delivery
# [ 1] 22:24:07.6 Parcel 112 for cust 88 return from delivery
# [ 1] 22:24:37.6 Parcel 25 for cust 52 return from delivery
# [ 1] 22:25:07.6 Parcel 23 for cust 50 return from delivery
# [ 1] 22:25:37.6 Parcel 90 for cust 50 return from delivery
# [ 1] 22:26:07.6 Parcel 22 for cust 49 return from delivery
# [ 1] 22:26:37.6 Parcel 13 for cust 43 return from delivery
# [ 1] 22:27:07.6 Parcel 14 for cust 43 return from delivery
# [ 1] 22:27:37.6 102 parcels left for next day
# [ 1] 22:37:37.6 Driver goes home
# [ 2] 17:00:00.0 Parcel 119 for cust 1 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 120 for cust 4 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 121 for cust 6 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 122 for cust 7 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 123 for cust 8 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 124 for cust 13 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 125 for cust 13 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 126 for cust 14 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 127 for cust 16 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 128 for cust 17 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 129 for cust 20 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 130 for cust 23 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 131 for cust 23 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 132 for cust 24 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 133 for cust 28 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 134 for cust 32 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 135 for cust 35 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 136 for cust 35 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 137 for cust 36 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 138 for cust 37 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 139 for cust 37 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 140 for cust 41 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 141 for cust 45 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 142 for cust 49 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 143 for cust 51 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 144 for cust 52 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 145 for cust 56 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 146 for cust 59 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 147 for cust 59 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 148 for cust 60 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 149 for cust 61 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 150 for cust 61 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 151 for cust 62 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 152 for cust 63 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 153 for cust 64 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 154 for cust 68 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 155 for cust 69 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 156 for cust 70 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 157 for cust 75 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 158 for cust 76 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 159 for cust 79 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 160 for cust 81 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 161 for cust 82 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 162 for cust 83 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 163 for cust 83 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 164 for cust 85 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 165 for cust 86 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 166 for cust 86 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 167 for cust 91 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 168 for cust 93 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 169 for cust 95 arr at delivery centre
# [ 2] 18:00:00.0 Driver arrives for work
# [ 2] 18:00:00.0 Parcel 11 for cust 38 out for delivery
# [ 2] 18:00:00.0 Parcel 12 for cust 39 out for delivery
# [ 2] 18:00:00.0 Parcel 81 for cust 39 out for delivery
# [ 2] 18:00:00.0 Parcel 82 for cust 40 out for delivery
# [ 2] 18:00:00.0 Parcel 83 for cust 41 out for delivery
# [ 2] 18:00:00.0 Parcel 140 for cust 41 out for delivery
# [ 2] 18:00:00.0 Parcel 137 for cust 36 out for delivery
# [ 2] 18:00:00.0 Parcel 78 for cust 28 out for delivery
# [ 2] 18:00:00.0 Parcel 133 for cust 28 out for delivery
# [ 2] 18:00:00.0 Parcel 8 for cust 23 out for delivery
# [ 2] 18:00:00.0 Parcel 130 for cust 23 out for delivery
# [ 2] 18:00:00.0 Parcel 131 for cust 23 out for delivery
# [ 2] 18:00:00.0 Parcel 76 for cust 22 out for delivery
# [ 2] 18:00:00.0 Parcel 68 for cust 9 out for delivery
# [ 2] 18:00:00.0 Parcel 67 for cust 8 out for delivery
# [ 2] 18:00:00.0 Parcel 123 for cust 8 out for delivery
# [ 2] 18:00:00.0 Parcel 122 for cust 7 out for delivery
# [ 2] 18:00:00.0 Parcel 121 for cust 6 out for delivery
# [ 2] 18:00:00.0 Parcel 66 for cust 4 out for delivery
# [ 2] 18:00:00.0 Parcel 120 for cust 4 out for delivery
# [ 2] 18:00:00.0 Parcel 64 for cust 3 out for delivery
# [ 2] 18:00:00.0 Parcel 65 for cust 3 out for delivery
# [ 2] 18:00:00.0 Parcel 1 for cust 2 out for delivery
# [ 2] 18:00:00.0 Parcel 63 for cust 2 out for delivery
# [ 2] 18:00:00.0 Parcel 0 for cust 1 out for delivery
# [ 2] 18:00:00.0 Parcel 62 for cust 1 out for delivery
# [ 2] 18:00:00.0 Parcel 119 for cust 1 out for delivery
# [ 2] 18:00:00.0 Parcel 69 for cust 11 out for delivery
# [ 2] 18:00:00.0 Parcel 3 for cust 12 out for delivery
# [ 2] 18:00:00.0 Parcel 4 for cust 13 out for delivery
# [ 2] 18:00:00.0 Parcel 124 for cust 13 out for delivery
# [ 2] 18:00:00.0 Parcel 125 for cust 13 out for delivery
# [ 2] 18:00:00.0 Parcel 128 for cust 17 out for delivery
# [ 2] 18:00:00.0 Parcel 74 for cust 18 out for delivery
# [ 2] 18:00:00.0 Parcel 7 for cust 19 out for delivery
# [ 2] 18:00:00.0 Parcel 75 for cust 19 out for delivery
# [ 2] 18:00:00.0 Parcel 129 for cust 20 out for delivery
# [ 2] 18:00:00.0 Parcel 9 for cust 29 out for delivery
# [ 2] 18:00:00.0 Parcel 79 for cust 32 out for delivery
# [ 2] 18:00:00.0 Parcel 134 for cust 32 out for delivery
# [ 2] 18:00:00.0 Parcel 10 for cust 37 out for delivery
# [ 2] 18:00:00.0 Parcel 138 for cust 37 out for delivery
# [ 2] 18:00:00.0 Parcel 139 for cust 37 out for delivery
# [ 2] 18:00:00.0 Parcel 15 for cust 44 out for delivery
# [ 2] 18:00:00.0 Parcel 16 for cust 44 out for delivery
# [ 2] 18:00:00.0 Parcel 17 for cust 44 out for delivery
# [ 2] 18:00:00.0 Parcel 18 for cust 45 out for delivery
# [ 2] 18:00:00.0 Parcel 19 for cust 45 out for delivery
# [ 2] 18:00:00.0 Parcel 84 for cust 45 out for delivery
# [ 2] 18:00:00.0 Parcel 85 for cust 45 out for delivery
# [ 2] 18:00:00.0 Parcel 141 for cust 45 out for delivery
# [ 2] 18:00:00.0 Parcel 21 for cust 47 out for delivery
# [ 2] 18:00:00.0 Parcel 89 for cust 47 out for delivery
# [ 2] 18:00:00.0 Parcel 94 for cust 55 out for delivery
# [ 2] 18:00:00.0 Parcel 29 for cust 56 out for delivery
# [ 2] 18:00:00.0 Parcel 95 for cust 56 out for delivery
# [ 2] 18:00:00.0 Parcel 145 for cust 56 out for delivery
# [ 2] 18:00:00.0 Parcel 96 for cust 57 out for delivery
# [ 2] 18:00:00.0 Parcel 30 for cust 58 out for delivery
# [ 2] 18:00:00.0 Parcel 97 for cust 58 out for delivery
# [ 2] 18:00:00.0 Parcel 31 for cust 59 out for delivery
# [ 2] 18:00:00.0 Parcel 146 for cust 59 out for delivery
# [ 2] 18:00:00.0 Parcel 147 for cust 59 out for delivery
# [ 2] 18:00:00.0 Parcel 98 for cust 60 out for delivery
# [ 2] 18:00:00.0 Parcel 148 for cust 60 out for delivery
# [ 2] 18:00:00.0 Parcel 149 for cust 61 out for delivery
# [ 2] 18:00:00.0 Parcel 150 for cust 61 out for delivery
# [ 2] 18:00:00.0 Parcel 33 for cust 62 out for delivery
# [ 2] 18:00:00.0 Parcel 99 for cust 62 out for delivery
# [ 2] 18:00:00.0 Parcel 151 for cust 62 out for delivery
# [ 2] 18:00:00.0 Parcel 152 for cust 63 out for delivery
# [ 2] 18:00:00.0 Parcel 34 for cust 66 out for delivery
# [ 2] 18:00:00.0 Parcel 35 for cust 68 out for delivery
# [ 2] 18:00:00.0 Parcel 154 for cust 68 out for delivery
# [ 2] 18:00:00.0 Parcel 37 for cust 70 out for delivery
# [ 2] 18:00:00.0 Parcel 38 for cust 70 out for delivery
# [ 2] 18:00:00.0 Parcel 156 for cust 70 out for delivery
# [ 2] 18:00:00.0 Parcel 40 for cust 72 out for delivery
# [ 2] 18:00:00.0 Parcel 43 for cust 76 out for delivery
# [ 2] 18:00:00.0 Parcel 44 for cust 76 out for delivery
# [ 2] 18:00:00.0 Parcel 45 for cust 76 out for delivery
# [ 2] 18:00:00.0 Parcel 158 for cust 76 out for delivery
# [ 2] 18:00:00.0 Parcel 105 for cust 75 out for delivery
# [ 2] 18:00:00.0 Parcel 157 for cust 75 out for delivery
# [ 2] 18:00:00.0 Parcel 41 for cust 73 out for delivery
# [ 2] 18:00:00.0 Parcel 42 for cust 73 out for delivery
# [ 2] 18:00:00.0 Parcel 104 for cust 73 out for delivery
# [ 2] 19:12:30.0 Driver leaves for delivery of 87 parcels to 45 customers
# [ 2] 19:12:30.0 Length of delivery tour: 39,822m
# [ 2] 19:12:30.0 Driver drives to Customer 38 at (4500, 4765)
# [ 2] 19:13:33.6 Driver arrived at Customer 38 at (4500, 4765)
# [ 2] 19:14:33.6 Customer 38 at (4500, 4765) not at home
# [ 2] 19:14:33.6 Driver drives to Customer 39 at (4500, 4910)
# [ 2] 19:15:08.4 Driver arrived at Customer 39 at (4500, 4910)
# [ 2] 19:15:10.1 Customer 39 at (4500, 4910) answers door
# [ 2] 19:15:10.1 Customer 39 at (4500, 4910) accepts Parcel 12 for cust 39
# [ 2] 19:15:19.8 Customer 39 at (4500, 4910) accepts Parcel 81 for cust 39
# [ 2] 19:16:40.4 Customer 39 at (4500, 4910) signs off
# [ 2] 19:17:01.1 Driver drives to Customer 40 at (4500, 5107)
# [ 2] 19:17:48.3 Driver arrived at Customer 40 at (4500, 5107)
# [ 2] 21:16:23.9 Driver drives to Customer 73 at (6620, 1802)
# [ 2] 21:17:18.9 Driver arrived at Customer 73 at (6620, 1802)
# [ 2] 21:18:18.9 Customer 73 at (6620, 1802) not at home
# [ 2] 21:18:18.9 Driver returns to delivery centre
# [ 2] 22:37:57.5 Driver arrived at delivery centre
# [ 2] 22:37:57.5 Parcel 11 for cust 38 return from delivery
# [ 2] 22:38:27.5 Parcel 82 for cust 40 return from delivery
# [ 2] 22:38:57.5 Parcel 83 for cust 41 return from delivery
# [ 2] 22:39:27.5 Parcel 140 for cust 41 return from delivery
# [ 2] 22:39:57.5 Parcel 137 for cust 36 return from delivery
# [ 2] 22:40:27.5 Parcel 8 for cust 23 return from delivery
# [ 2] 22:40:57.5 Parcel 130 for cust 23 return from delivery
# [ 2] 22:41:27.5 Parcel 131 for cust 23 return from delivery
# [ 2] 22:41:57.5 Parcel 76 for cust 22 return from delivery
# [ 2] 22:42:27.5 Parcel 68 for cust 9 return from delivery
# [ 2] 22:42:57.5 Parcel 67 for cust 8 return from delivery
# [ 2] 22:43:27.5 Parcel 123 for cust 8 return from delivery
# [ 2] 22:43:57.5 Parcel 122 for cust 7 return from delivery
# [ 2] 22:44:27.5 Parcel 121 for cust 6 return from delivery
# [ 2] 22:44:57.5 Parcel 66 for cust 4 return from delivery
# [ 2] 22:45:27.5 Parcel 120 for cust 4 return from delivery
# [ 2] 22:45:57.5 Parcel 64 for cust 3 return from delivery
# [ 2] 22:46:27.5 Parcel 65 for cust 3 return from delivery
# [ 2] 22:46:57.5 Parcel 1 for cust 2 return from delivery
# [ 2] 22:47:27.5 Parcel 63 for cust 2 return from delivery
# [ 2] 22:47:57.5 Parcel 0 for cust 1 return from delivery
# [ 2] 22:48:27.5 Parcel 62 for cust 1 return from delivery
# [ 2] 22:48:57.5 Parcel 119 for cust 1 return from delivery
# [ 2] 22:49:27.5 Parcel 69 for cust 11 return from delivery
# [ 2] 22:49:57.5 Parcel 3 for cust 12 return from delivery
# [ 2] 22:50:27.5 Parcel 4 for cust 13 return from delivery
# [ 2] 22:50:57.5 Parcel 124 for cust 13 return from delivery
# [ 2] 22:51:27.5 Parcel 125 for cust 13 return from delivery
# [ 2] 22:51:57.5 Parcel 128 for cust 17 return from delivery
# ...
# [ 3] 19:59:53.2 Driver arrived at Customer 30 at (3068, 6620)
# [ 3] 20:00:53.2 Customer 30 at (3068, 6620) not at home
# [ 3] 20:00:53.2 Driver drives to Customer 23 at (2106, 6620)
# [ 3] 20:04:44.1 Driver arrived at Customer 23 at (2106, 6620)
# [ 3] 20:05:44.1 Customer 23 at (2106, 6620) not at home
# [ 3] 20:05:44.1 Driver drives to Customer 22 at (1969, 6620)
# [ 3] 20:06:17.0 Driver arrived at Customer 22 at (1969, 6620)
# [ 3] 20:06:18.6 Customer 22 at (1969, 6620) answers door
# [ 3] 20:06:18.6 Customer 22 at (1969, 6620) accepts Parcel 76 for cust 22
# [ 3] 20:06:20.6 Customer 22 at (1969, 6620) accepts Parcel 178 for cust 22
# [ 3] 20:06:27.3 Customer 22 at (1969, 6620) accepts Parcel 179 for cust 22
# [ 3] 20:06:28.7 Customer 22 at (1969, 6620) signs off
# [ 3] 20:06:49.1 Driver drives to Customer 9 at (260, 6204)
# [ 3] 20:15:19.1 Driver arrived at Customer 9 at (260, 6204)
# [ 3] 20:16:19.1 Customer 9 at (260, 6204) not at home
# [ 3] 20:16:19.1 Driver drives to Customer 8 at (260, 5437)
# [ 3] 20:19:23.2 Driver arrived at Customer 8 at (260, 5437)
# [ 3] 20:20:23.2 Customer 8 at (260, 5437) not at home
# [ 3] 20:20:23.2 Driver drives to Customer 7 at (260, 5340)
# [ 3] 20:20:46.5 Driver arrived at Customer 7 at (260, 5340)
# [ 3] 20:21:46.5 Customer 7 at (260, 5340) not at home
# [ 3] 20:21:46.5 Driver drives to Customer 6 at (260, 5225)
# [ 3] 20:22:14.1 Driver arrived at Customer 6 at (260, 5225)
# [ 3] 20:23:14.1 Customer 6 at (260, 5225) not at home
# [ 3] 20:23:14.1 Driver drives to Customer 4 at (260, 4991)
# [ 3] 20:24:10.3 Driver arrived at Customer 4 at (260, 4991)
# [ 3] 20:25:10.3 Customer 4 at (260, 4991) not at home
# [ 3] 20:25:10.3 Driver drives to Customer 3 at (260, 4918)
# [ 3] 20:25:27.8 Driver arrived at Customer 3 at (260, 4918)
# [ 3] 20:26:27.8 Customer 3 at (260, 4918) not at home
# [ 3] 20:26:27.8 Driver drives to Customer 2 at (260, 4756)
# [ 3] 20:27:06.7 Driver arrived at Customer 2 at (260, 4756)
# [ 3] 20:28:06.7 Customer 2 at (260, 4756) not at home
# [ 3] 20:28:06.7 Driver drives to Customer 1 at (260, 4584)
# [ 3] 20:28:47.9 Driver arrived at Customer 1 at (260, 4584)
# [ 3] 20:29:47.9 Customer 1 at (260, 4584) not at home
# [ 3] 20:29:47.9 Driver drives to Customer 0 at (260, 4455)
# [ 3] 20:30:18.9 Driver arrived at Customer 0 at (260, 4455)
# [ 3] 20:31:18.9 Customer 0 at (260, 4455) to slow to answer the door
# [ 3] 20:31:18.9 Driver drives to Customer 11 at (703, 2996)
# [ 3] 20:37:53.0 Driver arrived at Customer 11 at (703, 2996)
# [ 3] 20:38:53.0 Customer 11 at (703, 2996) not at home
# [ 3] 20:38:53.0 Driver drives to Customer 12 at (1104, 2594)
# [ 3] 20:41:09.1 Driver arrived at Customer 12 at (1104, 2594)
# [ 3] 20:42:09.1 Customer 12 at (1104, 2594) not at home
# [ 3] 20:42:09.1 Driver drives to Customer 13 at (1320, 1929)
# [ 3] 20:45:10.3 Driver arrived at Customer 13 at (1320, 1929)
# [ 3] 20:45:25.7 Customer 13 at (1320, 1929) answers door
# [ 3] 20:45:25.7 Customer 13 at (1320, 1929) accepts Parcel 4 for cust 13
# [ 3] 20:45:31.4 Customer 13 at (1320, 1929) accepts Parcel 124 for cust 13
# [ 3] 20:45:39.5 Customer 13 at (1320, 1929) accepts Parcel 125 for cust 13
# [ 3] 20:45:42.9 Customer 13 at (1320, 1929) signs off
# [ 3] 20:45:50.7 Driver drives to Customer 17 at (1420, 1218)
# [ 3] 20:48:50.9 Driver arrived at Customer 17 at (1420, 1218)
# [ 3] 20:48:59.9 Customer 17 at (1420, 1218) answers door
# [ 3] 20:48:59.9 Customer 17 at (1420, 1218) accepts Parcel 128 for cust 17
# [ 3] 20:49:03.4 Customer 17 at (1420, 1218) accepts Parcel 175 for cust 17
# [ 3] 20:49:09.2 Customer 17 at (1420, 1218) accepts Parcel 176 for cust 17
# [ 3] 20:49:18.5 Customer 17 at (1420, 1218) signs off
# [ 3] 20:49:26.2 Driver drives to Customer 18 at (1577, 1061)
# [ 3] 20:50:19.5 Driver arrived at Customer 18 at (1577, 1061)
# [ 3] 20:51:19.5 Customer 18 at (1577, 1061) not at home
# [ 3] 20:51:19.5 Driver drives to Customer 19 at (1677, 960)
# [ 3] 20:51:53.6 Driver arrived at Customer 19 at (1677, 960)
# [ 3] 20:52:53.6 Customer 19 at (1677, 960) not at home
# [ 3] 20:52:53.6 Driver drives to Customer 20 at (1739, 900)
# [ 3] 20:53:14.2 Driver arrived at Customer 20 at (1739, 900)
# [ 3] 20:53:26.3 Customer 20 at (1739, 900) answers door
# [ 3] 20:53:26.3 Customer 20 at (1739, 900) accepts Parcel 129 for cust 20
# [ 3] 20:53:28.9 Customer 20 at (1739, 900) signs off
# [ 3] 20:53:30.2 Driver drives to Customer 29 at (2994, 260)
# [ 3] 20:59:34.8 Driver arrived at Customer 29 at (2994, 260)
# [ 3] 21:00:34.8 Customer 29 at (2994, 260) not at home
# [ 3] 21:00:34.8 Driver drives to Customer 32 at (3248, 260)
# [ 3] 21:01:35.7 Driver arrived at Customer 32 at (3248, 260)
# [ 3] 21:02:35.7 Customer 32 at (3248, 260) not at home
# [ 3] 21:02:35.7 Driver drives to Customer 37 at (4138, 260)
# [ 3] 21:06:09.3 Driver arrived at Customer 37 at (4138, 260)
# [ 3] 21:07:09.3 Customer 37 at (4138, 260) not at home
# [ 3] 21:07:09.3 Driver drives to Customer 44 at (4609, 260)
# [ 3] 21:09:02.4 Driver arrived at Customer 44 at (4609, 260)
# [ 3] 21:10:02.4 Customer 44 at (4609, 260) not at home
# [ 3] 21:10:02.4 Driver drives to Customer 45 at (4679, 260)
# [ 3] 21:10:19.2 Driver arrived at Customer 45 at (4679, 260)
# [ 3] 21:11:19.2 Customer 45 at (4679, 260) not at home
# [ 3] 21:11:19.2 Driver drives to Customer 47 at (4825, 260)
# [ 3] 21:11:54.2 Driver arrived at Customer 47 at (4825, 260)
# [ 3] 21:12:54.2 Customer 47 at (4825, 260) not at home
# [ 3] 21:12:54.2 Driver drives to Customer 55 at (5560, 463)
# [ 3] 21:16:39.3 Driver arrived at Customer 55 at (5560, 463)
# [ 3] 21:17:39.3 Customer 55 at (5560, 463) not at home
# [ 3] 21:17:39.3 Driver drives to Customer 56 at (5560, 604)
# [ 3] 21:18:13.2 Driver arrived at Customer 56 at (5560, 604)
# [ 3] 21:19:13.2 Customer 56 at (5560, 604) not at home
# [ 3] 21:49:12.9 Driver drives to Customer 74 at (6620, 1882)
# [ 3] 21:49:48.7 Driver arrived at Customer 74 at (6620, 1882)
# [ 3] 21:50:48.7 Customer 74 at (6620, 1882) to slow to answer the door
# [ 3] 21:50:48.7 Driver drives to Customer 73 at (6620, 1802)
# [ 3] 21:51:07.9 Driver arrived at Customer 73 at (6620, 1802)
# [ 3] 21:52:07.9 Customer 73 at (6620, 1802) not at home
# [ 3] 21:52:07.9 Driver drives to Customer 90 at (6864, 1320)
# [ 3] 21:55:02.1 Driver arrived at Customer 90 at (6864, 1320)
# [ 3] 21:56:02.1 Customer 90 at (6864, 1320) not at home
# [ 3] 21:56:02.1 Driver drives to Customer 65 at (5895, 1320)
# [ 3] 21:59:54.7 Driver arrived at Customer 65 at (5895, 1320)
# [ 3] 22:00:54.7 Customer 65 at (5895, 1320) not at home
# [ 3] 22:00:54.7 Driver returns to delivery centre
# [ 3] 23:11:06.2 Driver arrived at delivery centre
# [ 3] 23:11:06.2 Parcel 11 for cust 38 return from delivery
# [ 3] 23:11:36.2 Parcel 188 for cust 38 return from delivery
# [ 3] 23:12:06.2 Parcel 189 for cust 38 return from delivery
# [ 3] 23:12:36.2 Parcel 190 for cust 38 return from delivery
# [ 3] 23:13:06.2 Parcel 82 for cust 40 return from delivery
# [ 3] 23:13:36.2 Parcel 191 for cust 40 return from delivery
# [ 3] 23:14:06.2 Parcel 192 for cust 40 return from delivery
# [ 3] 23:14:36.2 Parcel 83 for cust 41 return from delivery
# [ 3] 23:15:06.2 Parcel 140 for cust 41 return from delivery
# [ 3] 23:15:36.2 Parcel 193 for cust 41 return from delivery
# [ 3] 23:16:06.2 Parcel 137 for cust 36 return from delivery
# [ 3] 23:16:36.2 Parcel 186 for cust 30 return from delivery
# [ 3] 23:17:06.2 Parcel 8 for cust 23 return from delivery
# [ 3] 23:17:36.2 Parcel 130 for cust 23 return from delivery
# [ 3] 23:18:06.2 Parcel 131 for cust 23 return from delivery
# [ 3] 23:18:36.2 Parcel 180 for cust 23 return from delivery
# [ 3] 23:19:06.2 Parcel 181 for cust 23 return from delivery
# [ 3] 23:19:36.2 Parcel 68 for cust 9 return from delivery
# [ 3] 23:20:06.2 Parcel 67 for cust 8 return from delivery
# [ 3] 23:20:36.2 Parcel 123 for cust 8 return from delivery
# [ 3] 23:21:06.2 Parcel 173 for cust 8 return from delivery
# [ 3] 23:21:36.2 Parcel 122 for cust 7 return from delivery
# [ 3] 23:22:06.2 Parcel 121 for cust 6 return from delivery
# [ 3] 23:22:36.2 Parcel 66 for cust 4 return from delivery
# [ 3] 23:23:06.2 Parcel 120 for cust 4 return from delivery
# [ 3] 23:23:36.2 Parcel 64 for cust 3 return from delivery
# [ 3] 23:24:06.2 Parcel 65 for cust 3 return from delivery
# [ 3] 23:24:36.2 Parcel 1 for cust 2 return from delivery
# [ 3] 23:25:06.2 Parcel 63 for cust 2 return from delivery
# [ 3] 23:25:36.2 Parcel 172 for cust 2 return from delivery
# [ 3] 23:26:06.2 Parcel 0 for cust 1 return from delivery
# [ 3] 23:26:36.2 Parcel 62 for cust 1 return from delivery
# [ 3] 23:27:06.2 Parcel 119 for cust 1 return from delivery
# [ 3] 23:27:36.2 Parcel 171 for cust 1 return from delivery
# [ 3] 23:28:06.2 Parcel 170 for cust 0 return from delivery
# [ 3] 23:28:36.2 Parcel 69 for cust 11 return from delivery
# [ 3] 23:29:06.2 Parcel 3 for cust 12 return from delivery
# [ 3] 23:29:36.2 Parcel 174 for cust 12 return from delivery
# [ 3] 23:30:06.2 Parcel 74 for cust 18 return from delivery
# [ 3] 23:30:36.2 Parcel 7 for cust 19 return from delivery
# [ 3] 23:31:06.2 Parcel 75 for cust 19 return from delivery
# [ 3] 23:31:36.2 Parcel 177 for cust 19 return from delivery
# [ 3] 23:32:06.2 Parcel 9 for cust 29 return from delivery
# [ 3] 23:32:36.2 Parcel 185 for cust 29 return from delivery
# [ 3] 23:33:06.2 Parcel 79 for cust 32 return from delivery
# [ 3] 23:33:36.2 Parcel 134 for cust 32 return from delivery
# [ 3] 23:34:06.2 Parcel 10 for cust 37 return from delivery
# [ 3] 23:34:36.2 Parcel 138 for cust 37 return from delivery
# [ 3] 23:35:06.2 Parcel 139 for cust 37 return from delivery
# [ 3] 23:35:36.2 Parcel 187 for cust 37 return from delivery
# [ 3] 23:36:06.2 Parcel 15 for cust 44 return from delivery
# [ 3] 23:36:36.2 Parcel 16 for cust 44 return from delivery
# [ 3] 23:37:06.2 Parcel 17 for cust 44 return from delivery
# [ 3] 23:37:36.2 Parcel 194 for cust 44 return from delivery
# [ 3] 23:38:06.2 Parcel 18 for cust 45 return from delivery
# [ 3] 23:38:36.2 Parcel 19 for cust 45 return from delivery
# [ 3] 23:39:06.2 Parcel 84 for cust 45 return from delivery
# [ 3] 23:39:36.2 Parcel 85 for cust 45 return from delivery
# [ 3] 23:40:06.2 Parcel 141 for cust 45 return from delivery
# [ 3] 23:40:36.2 Parcel 195 for cust 45 return from delivery
# [ 3] 23:41:06.2 Parcel 21 for cust 47 return from delivery
# [ 3] 23:41:36.2 Parcel 89 for cust 47 return from delivery
# [ 3] 23:42:06.2 Parcel 196 for cust 47 return from delivery
# [ 3] 23:42:36.2 Parcel 94 for cust 55 return from delivery
# [ 3] 23:43:06.2 Parcel 29 for cust 56 return from delivery
# [ 3] 23:43:36.2 Parcel 95 for cust 56 return from delivery
# [ 3] 23:44:06.2 Parcel 145 for cust 56 return from delivery
# [ 3] 23:44:36.2 Parcel 96 for cust 57 return from delivery
# [ 3] 23:45:06.2 Parcel 202 for cust 57 return from delivery
# [ 3] 23:45:36.2 Parcel 30 for cust 58 return from delivery
# [ 3] 23:46:06.2 Parcel 97 for cust 58 return from delivery
# [ 3] 23:46:36.2 Parcel 203 for cust 58 return from delivery
# [ 3] 23:47:06.2 Parcel 204 for cust 58 return from delivery
# [ 3] 23:47:36.2 Parcel 205 for cust 58 return from delivery
# [ 3] 23:48:06.2 Parcel 31 for cust 59 return from delivery
# [ 3] 23:48:36.2 Parcel 146 for cust 59 return from delivery
# [ 3] 23:49:06.2 Parcel 147 for cust 59 return from delivery
# [ 3] 23:49:36.2 Parcel 98 for cust 60 return from delivery
# [ 3] 23:50:06.2 Parcel 148 for cust 60 return from delivery
# [ 3] 23:50:36.2 Parcel 206 for cust 60 return from delivery
# [ 3] 23:51:06.2 Parcel 149 for cust 61 return from delivery
# [ 3] 23:51:36.2 Parcel 150 for cust 61 return from delivery
# [ 3] 23:52:06.2 Parcel 207 for cust 61 return from delivery
# [ 3] 23:52:36.2 Parcel 33 for cust 62 return from delivery
# [ 3] 23:53:06.2 Parcel 99 for cust 62 return from delivery
# [ 3] 23:53:36.2 Parcel 151 for cust 62 return from delivery
# [ 3] 23:54:06.2 Parcel 152 for cust 63 return from delivery
# [ 3] 23:54:36.2 Parcel 34 for cust 66 return from delivery
# [ 3] 23:55:06.2 Parcel 35 for cust 68 return from delivery
# [ 3] 23:55:36.2 Parcel 154 for cust 68 return from delivery
# [ 3] 23:56:06.2 Parcel 210 for cust 68 return from delivery
# [ 3] 23:56:36.2 Parcel 211 for cust 68 return from delivery
# [ 3] 23:57:06.2 Parcel 37 for cust 70 return from delivery
# [ 3] 23:57:36.2 Parcel 38 for cust 70 return from delivery
# [ 3] 23:58:06.2 Parcel 156 for cust 70 return from delivery
# [ 3] 23:58:36.2 Parcel 40 for cust 72 return from delivery
# [ 3] 23:59:06.2 Parcel 212 for cust 72 return from delivery
# [ 3] 23:59:36.2 Parcel 46 for cust 79 return from delivery
# [ 4] 00:00:06.2 Parcel 159 for cust 79 return from delivery
# [ 4] 00:00:36.2 Parcel 43 for cust 76 return from delivery
# [ 4] 00:01:06.2 Parcel 44 for cust 76 return from delivery
# [ 4] 00:01:36.2 Parcel 45 for cust 76 return from delivery
# [ 4] 00:02:06.2 Parcel 158 for cust 76 return from delivery
# [ 4] 00:02:36.2 Parcel 215 for cust 76 return from delivery
# [ 4] 00:03:06.2 Parcel 105 for cust 75 return from delivery
# [ 4] 00:03:36.2 Parcel 157 for cust 75 return from delivery
# [ 4] 00:04:06.2 Parcel 213 for cust 74 return from delivery
# [ 4] 00:04:36.2 Parcel 214 for cust 74 return from delivery
# [ 4] 00:05:06.2 Parcel 41 for cust 73 return from delivery
# [ 4] 00:05:36.2 Parcel 42 for cust 73 return from delivery
# [ 4] 00:06:06.2 Parcel 104 for cust 73 return from delivery
# [ 4] 00:06:36.2 Parcel 54 for cust 90 return from delivery
# [ 4] 00:07:06.2 Parcel 113 for cust 90 return from delivery
# [ 4] 00:07:36.2 Parcel 221 for cust 90 return from delivery
# [ 4] 00:08:06.2 Parcel 208 for cust 65 return from delivery
# [ 4] 00:08:36.2 196 parcels left for next day
# [ 4] 00:18:36.2 Driver goes home
# Delivery Centre Inventory: 196 parcels

# %%
import pickle
with open('testData.pickled', 'rb') as f:
    MX, CX = pickle.load(f)

# %%
WX = generateWarehouseLocation(MX)

# %%
rec4 = simulation(MX, WX, CX, p=0.15, days=7, log=True)
# Out:
# Simulating delivery of 14 parcels over 7 days to 20 customers
# [ 0] 18:00:00.0 Driver arrives for work
# [ 0] 18:00:00.0 Nothing to do today
# [ 0] 18:10:00.0 Driver goes home
# [ 1] 18:00:00.0 Driver arrives for work
# [ 1] 18:00:00.0 Nothing to do today
# [ 1] 18:10:00.0 Driver goes home
# [ 2] 17:00:00.0 Parcel 0 for cust 4 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 1 for cust 12 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 2 for cust 19 arr at delivery centre
# [ 2] 18:00:00.0 Driver arrives for work
# [ 2] 18:00:00.0 Parcel 0 for cust 4 out for delivery
# [ 2] 18:00:00.0 Parcel 2 for cust 19 out for delivery
# [ 2] 18:00:00.0 Parcel 1 for cust 12 out for delivery
# [ 2] 18:02:30.0 Driver leaves for delivery of 3 parcels to 3 customers
# [ 2] 18:02:30.0 Length of delivery tour: 15,426m
# [ 2] 18:02:30.0 Driver drives to Customer 4 at (4606, 1050)
# [ 2] 18:16:43.4 Driver arrived at Customer 4 at (4606, 1050)
# [ 2] 18:17:43.4 Customer 4 at (4606, 1050) not at home
# [ 2] 18:17:43.4 Driver drives to Customer 19 at (7950, 5463)
# [ 2] 18:46:03.4 Driver arrived at Customer 19 at (7950, 5463)
# [ 2] 18:47:03.4 Customer 19 at (7950, 5463) not at home
# [ 2] 18:47:03.4 Driver drives to Customer 12 at (6227, 5650)
# [ 2] 18:54:41.8 Driver arrived at Customer 12 at (6227, 5650)
# [ 2] 18:55:41.8 Customer 12 at (6227, 5650) not at home
# [ 2] 18:55:41.8 Driver returns to delivery centre
# [ 2] 19:07:12.2 Driver arrived at delivery centre
# [ 2] 19:07:12.2 Parcel 0 for cust 4 return from delivery
# [ 2] 19:07:42.2 Parcel 2 for cust 19 return from delivery
# [ 2] 19:08:12.2 Parcel 1 for cust 12 return from delivery
# [ 2] 19:08:42.2 3 parcels left for next day
# [ 2] 19:18:42.2 Driver goes home
# [ 3] 17:00:00.0 Parcel 3 for cust 2 arr at delivery centre
# [ 3] 17:00:00.0 Parcel 4 for cust 3 arr at delivery centre
# [ 3] 18:00:00.0 Driver arrives for work
# [ 3] 18:00:00.0 Parcel 4 for cust 3 out for delivery
# [ 3] 18:00:00.0 Parcel 0 for cust 4 out for delivery
# [ 3] 18:00:00.0 Parcel 2 for cust 19 out for delivery
# [ 3] 18:00:00.0 Parcel 1 for cust 12 out for delivery
# [ 3] 18:00:00.0 Parcel 3 for cust 2 out for delivery
# [ 3] 18:04:10.0 Driver leaves for delivery of 5 parcels to 5 customers
# [ 3] 18:04:10.0 Length of delivery tour: 21,618m
# [ 3] 18:04:10.0 Driver drives to Customer 3 at (4500, 4058)
# [ 3] 18:05:56.1 Driver arrived at Customer 3 at (4500, 4058)
# [ 3] 18:06:56.1 Customer 3 at (4500, 4058) not at home
# [ 3] 18:06:56.1 Driver drives to Customer 4 at (4606, 1050)
# [ 3] 18:19:23.4 Driver arrived at Customer 4 at (4606, 1050)
# [ 3] 18:20:23.4 Customer 4 at (4606, 1050) not at home
# [ 3] 18:20:23.4 Driver drives to Customer 19 at (7950, 5463)
# [ 3] 18:48:43.4 Driver arrived at Customer 19 at (7950, 5463)
# [ 3] 18:49:43.4 Customer 19 at (7950, 5463) not at home
# [ 3] 18:49:43.4 Driver drives to Customer 12 at (6227, 5650)
# [ 3] 18:57:21.8 Driver arrived at Customer 12 at (6227, 5650)
# [ 3] 18:58:21.8 Customer 12 at (6227, 5650) not at home
# [ 3] 18:58:21.8 Driver drives to Customer 2 at (3913, 7363)
# [ 3] 19:17:39.3 Driver arrived at Customer 2 at (3913, 7363)
# [ 3] 19:18:39.3 Customer 2 at (3913, 7363) to slow to answer the door
# [ 3] 19:18:39.3 Driver returns to delivery centre
# [ 3] 19:35:38.3 Driver arrived at delivery centre
# [ 3] 19:35:38.3 Parcel 4 for cust 3 return from delivery
# [ 3] 19:36:08.3 Parcel 0 for cust 4 return from delivery
# [ 3] 19:36:38.3 Parcel 2 for cust 19 return from delivery
# [ 3] 19:37:08.3 Parcel 1 for cust 12 return from delivery
# [ 3] 19:37:38.3 Parcel 3 for cust 2 return from delivery
# [ 3] 19:38:08.3 5 parcels left for next day
# [ 3] 19:48:08.3 Driver goes home
# [ 4] 17:00:00.0 Parcel 5 for cust 6 arr at delivery centre
# [ 4] 17:00:00.0 Parcel 6 for cust 15 arr at delivery centre
# [ 4] 17:00:00.0 Parcel 7 for cust 15 arr at delivery centre
# [ 4] 17:00:00.0 Parcel 8 for cust 18 arr at delivery centre
# [ 4] 18:00:00.0 Driver arrives for work
# [ 4] 18:00:00.0 Parcel 4 for cust 3 out for delivery
# [ 4] 18:00:00.0 Parcel 0 for cust 4 out for delivery
# [ 4] 18:00:00.0 Parcel 5 for cust 6 out for delivery
# [ 4] 18:00:00.0 Parcel 3 for cust 2 out for delivery
# [ 4] 18:00:00.0 Parcel 1 for cust 12 out for delivery
# [ 4] 18:00:00.0 Parcel 2 for cust 19 out for delivery
# [ 4] 18:00:00.0 Parcel 8 for cust 18 out for delivery
# [ 4] 18:00:00.0 Parcel 6 for cust 15 out for delivery
# [ 4] 18:00:00.0 Parcel 7 for cust 15 out for delivery
# [ 4] 18:07:30.0 Driver leaves for delivery of 9 parcels to 8 customers
# [ 4] 18:07:30.0 Length of delivery tour: 22,726m
# [ 4] 18:07:30.0 Driver drives to Customer 3 at (4500, 4058)
# [ 4] 18:09:16.1 Driver arrived at Customer 3 at (4500, 4058)
# [ 4] 18:10:16.1 Customer 3 at (4500, 4058) not at home
# [ 4] 18:10:16.1 Driver drives to Customer 4 at (4606, 1050)
# [ 4] 18:22:43.4 Driver arrived at Customer 4 at (4606, 1050)
# [ 4] 18:22:55.5 Customer 4 at (4606, 1050) answers door
# [ 4] 18:22:55.5 Customer 4 at (4606, 1050) accepts Parcel 0 for cust 4
# [ 4] 18:22:58.0 Customer 4 at (4606, 1050) signs off
# [ 4] 18:23:08.4 Driver drives to Customer 6 at (4717, 1050)
# [ 4] 18:23:35.0 Driver arrived at Customer 6 at (4717, 1050)
# [ 4] 18:24:35.0 Customer 6 at (4717, 1050) not at home
# [ 4] 18:24:35.0 Driver drives to Customer 2 at (3913, 7363)
# [ 4] 18:56:14.1 Driver arrived at Customer 2 at (3913, 7363)
# [ 4] 18:57:14.1 Customer 2 at (3913, 7363) not at home
# [ 4] 18:57:14.1 Driver drives to Customer 12 at (6227, 5650)
# [ 4] 19:16:31.7 Driver arrived at Customer 12 at (6227, 5650)
# [ 4] 19:17:31.7 Customer 12 at (6227, 5650) not at home
# [ 4] 19:17:31.7 Driver drives to Customer 19 at (7950, 5463)
# [ 4] 19:25:10.1 Driver arrived at Customer 19 at (7950, 5463)
# [ 4] 19:26:10.1 Customer 19 at (7950, 5463) not at home
# [ 4] 19:26:10.1 Driver drives to Customer 18 at (7950, 5034)
# [ 4] 19:27:53.0 Driver arrived at Customer 18 at (7950, 5034)
# [ 4] 19:28:53.0 Customer 18 at (7950, 5034) not at home
# [ 4] 19:28:53.0 Driver drives to Customer 15 at (7336, 4500)
# [ 4] 19:33:28.5 Driver arrived at Customer 15 at (7336, 4500)
# [ 4] 19:34:28.5 Customer 15 at (7336, 4500) not at home
# [ 4] 19:34:28.5 Driver returns to delivery centre
# [ 4] 19:45:49.2 Driver arrived at delivery centre
# [ 4] 19:45:49.2 Parcel 4 for cust 3 return from delivery
# [ 4] 19:46:19.2 Parcel 5 for cust 6 return from delivery
# [ 4] 19:46:49.2 Parcel 3 for cust 2 return from delivery
# [ 4] 19:47:19.2 Parcel 1 for cust 12 return from delivery
# [ 4] 19:47:49.2 Parcel 2 for cust 19 return from delivery
# [ 4] 19:48:19.2 Parcel 8 for cust 18 return from delivery
# [ 4] 19:48:49.2 Parcel 6 for cust 15 return from delivery
# [ 4] 19:49:19.2 Parcel 7 for cust 15 return from delivery
# [ 4] 19:49:49.2 8 parcels left for next day
# [ 4] 19:59:49.2 Driver goes home
# [ 5] 17:00:00.0 Parcel 9 for cust 2 arr at delivery centre
# [ 5] 18:00:00.0 Driver arrives for work
# [ 5] 18:00:00.0 Parcel 4 for cust 3 out for delivery
# [
 18:00:00.0 Parcel 8 for cust 18 out for delivery
# [ 6] 18:00:00.0 Parcel 2 for cust 19 out for delivery
# [ 6] 18:00:00.0 Parcel 1 for cust 12 out for delivery
# [ 6] 18:00:00.0 Parcel 3 for cust 2 out for delivery
# [ 6] 18:00:00.0 Parcel 9 for cust 2 out for delivery
# [ 6] 18:10:00.0 Driver leaves for delivery of 12 parcels to 9 customers
# [ 6] 18:10:00.0 Length of delivery tour: 23,270m
# [ 6] 18:10:00.0 Driver drives to Customer 7 at (4868, 2200)
# [ 6] 18:20:40.3 Driver arrived at Customer 7 at (4868, 2200)
# [ 6] 18:21:40.3 Customer 7 at (4868, 2200) not at home
# [ 6] 18:21:40.3 Driver drives to Customer 4 at (4606, 1050)
# [ 6] 18:28:10.1 Driver arrived at Customer 4 at (4606, 1050)
# [ 6] 18:29:10.1 Customer 4 at (4606, 1050) not at home
# [ 6] 18:29:10.1 Driver drives to Customer 6 at (4717, 1050)
# [ 6] 18:29:36.7 Driver arrived at Customer 6 at (4717, 1050)
# [ 6] 18:30:36.7 Customer 6 at (4717, 1050) not at home
# [ 6] 18:30:36.7 Driver drives to Customer 15 at (7336, 4500)
# [ 6] 18:54:53.3 Driver arrived at Customer 15 at (7336, 4500)
# [ 6] 18:55:53.3 Customer 15 at (7336, 4500) not at home
# [ 6] 18:55:53.3 Driver drives to Customer 16 at (7457, 4500)
# [ 6] 18:56:22.3 Driver arrived at Customer 16 at (7457, 4500)
# [ 6] 18:57:22.3 Customer 16 at (7457, 4500) not at home
# [ 6] 18:57:22.3 Driver drives to Customer 18 at (7950, 5034)
# [ 6] 19:02:26.9 Driver arrived at Customer 18 at (7950, 5034)
# [ 6] 19:03:05.7 Customer 18 at (7950, 5034) answers door
# [ 6] 19:03:05.7 Customer 18 at (7950, 5034) accepts Parcel 8 for cust 18
# [ 6] 19:03:18.3 Customer 18 at (7950, 5034) signs off
# [ 6] 19:03:23.2 Driver drives to Customer 19 at (7950, 5463)
# [ 6] 19:05:06.1 Driver arrived at Customer 19 at (7950, 5463)
# [ 6] 19:06:06.1 Customer 19 at (7950, 5463) not at home
# [ 6] 19:06:06.1 Driver drives to Customer 12 at (6227, 5650)
# [ 6] 19:13:44.5 Driver arrived at Customer 12 at (6227, 5650)
# [ 6] 19:14:44.5 Customer 12 at (6227, 5650) not at home
# [ 6] 19:14:44.5 Driver drives to Customer 2 at (3913, 7363)
# [ 6] 19:34:02.1 Driver arrived at Customer 2 at (3913, 7363)
# [ 6] 19:35:02.1 Customer 2 at (3913, 7363) not at home
# [ 6] 19:35:02.1 Driver returns to delivery centre
# [ 6] 19:52:01.1 Driver arrived at delivery centre
# [ 6] 19:52:01.1 Parcel 12 for cust 7 return from delivery
# [ 6] 19:52:31.1 Parcel 10 for cust 4 return from delivery
# [ 6] 19:53:01.1 Parcel 5 for cust 6 return from delivery
# [ 6] 19:53:31.1 Parcel 11 for cust 6 return from delivery
# [ 6] 19:54:01.1 Parcel 6 for cust 15 return from delivery
# [ 6] 19:54:31.1 Parcel 7 for cust 15 return from delivery
# [ 6] 19:55:01.1 Parcel 13 for cust 16 return from delivery
# [ 6] 19:55:31.1 Parcel 2 for cust 19 return from delivery
# [ 6] 19:56:01.1 Parcel 1 for cust 12 return from delivery
# [ 6] 19:56:31.1 Parcel 3 for cust 2 return from delivery
# [ 6] 19:57:01.1 Parcel 9 for cust 2 return from delivery
# [ 6] 19:57:31.1 11 parcels left for next day
# [ 6] 20:07:31.1 Driver goes home
# Delivery Centre Inventory: 11 parcels

# %%
rec5 = simulation(MX, WX, CX, p=1.2, days=7, log=True)
# Out:
# Simulating delivery of 151 parcels over 7 days to 20 customers
# [ 0] 17:00:00.0 Parcel 0 for cust 5 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 1 for cust 6 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 2 for cust 6 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 3 for cust 7 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 4 for cust 7 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 5 for cust 8 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 6 for cust 13 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 7 for cust 13 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 8 for cust 15 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 9 for cust 16 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 10 for cust 16 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 11 for cust 16 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 12 for cust 17 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 13 for cust 17 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 14 for cust 18 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 15 for cust 19 arr at delivery centre
# [ 0] 18:00:00.0 Driver arrives for work
# [ 0] 18:00:00.0 Parcel 6 for cust 13 out for delivery
# [ 0] 18:00:00.0 Parcel 7 for cust 13 out for delivery
# [ 0] 18:00:00.0 Parcel 8 for cust 15 out for delivery
# [ 0] 18:00:00.0 Parcel 9 for cust 16 out for delivery
# [ 0] 18:00:00.0 Parcel 10 for cust 16 out for delivery
# [ 0] 18:00:00.0 Parcel 11 for cust 16 out for delivery
# [ 0] 18:00:00.0 Parcel 12 for cust 17 out for delivery
# [ 0] 18:00:00.0 Parcel 13 for cust 17 out for delivery
# [ 0] 18:00:00.0 Parcel 14 for cust 18 out for delivery
# [ 0] 18:00:00.0 Parcel 15 for cust 19 out for delivery
# [ 0] 18:00:00.0 Parcel 3 for cust 7 out for delivery
# [ 0] 18:00:00.0 Parcel 4 for cust 7 out for delivery
# [ 0] 18:00:00.0 Parcel 0 for cust 5 out for delivery
# [ 0] 18:00:00.0 Parcel 1 for cust 6 out for delivery
# [ 0] 18:00:00.0 Parcel 2 for cust 6 out for delivery
# [ 0] 18:00:00.0 Parcel 5 for cust 8 out for delivery
# [ 0] 18:13:20.0 Driver leaves for delivery of 16 parcels to 10 customers
# [ 0] 18:13:20.0 Length of delivery tour: 16,764m
# [ 0] 18:13:20.0 Driver drives to Customer 13 at (7134, 4500)
# [ 0] 18:23:52.2 Driver arrived at Customer 13 at (7134, 4500)
# [ 0] 18:24:52.2 Customer 13 at (7134, 4500) not at home
# [ 0] 18:24:52.2 Driver drives to Customer 15 at (7336, 4500)
# [ 0] 18:25:40.6 Driver arrived at Customer 15 at (7336, 4500)
# [ 0] 18:26:40.6 Customer 15 at (7336, 4500) not at home
# [ 0] 18:26:40.6 Driver drives to Customer 16 at (7457, 4500)
# [ 0] 18:27:09.7 Driver arrived at Customer 16 at (7457, 4500)
# [ 0] 18:28:09.7 Customer 16 at (7457, 4500) not at home
# [ 0] 18:28:09.7 Driver drives to Customer 17 at (7691, 4500)
# [ 0] 18:29:05.8 Driver arrived at Customer 17 at (7691, 4500)
# [ 0] 18:30:05.8 Customer 17 at (7691, 4500) not at home
# [ 0] 18:30:05.8 Driver drives to Customer 18 at (7950, 5034)
# [ 0] 18:33:16.2 Driver arrived at Customer 18 at (7950, 5034)
# [ 0] 18:34:16.2 Customer 18 at (7950, 5034) not at home
# [ 0] 18:34:16.2 Driver drives to Customer 19 at (7950, 5463)
# [ 0] 18:35:59.1 Driver arrived at Customer 19 at (7950, 5463)
# [ 0] 18:36:59.1 Customer 19 at (7950, 5463) not at home
# [ 0] 18:36:59.1 Driver drives to Customer 7 at (4868, 2200)
# [ 0] 19:02:21.9 Driver arrived at Customer 7 at (4868, 2200)
# [ 0] 19:03:21.9 Customer 7 at (4868, 2200) not at home
# [ 0] 19:03:21.9 Driver drives to Customer 5 at (4626, 2200)
# [ 0] 19:04:20.0 Driver arrived at Customer 5 at (4626, 2200)
# [ 0] 19:05:20.0 Customer 5 at (4626, 2200) not at home
# [ 0] 19:05:20.0 Driver drives to Customer 6 at (4717, 1050)
# [ 0] 19:11:18.3 Driver arrived at Customer 6 at (4717, 1050)
# [ 0] 19:12:18.3 Customer 6 at (4717, 1050) not at home
# [ 0] 19:12:18.3 Driver drives to Customer 8 at (5019, 1050)
# [ 0] 19:13:30.8 Driver arrived at Customer 8 at (5019, 1050)
# [ 0] 19:13:49.8 Customer 8 at (5019, 1050) answers door
# [ 0] 19:13:49.8 Customer 8 at (5019, 1050) accepts Parcel 5 for cust 8
# [ 0] 19:14:10.7 Customer 8 at (5019, 1050) signs off
# [ 0] 19:14:19.1 Driver returns to delivery centre
# [ 0] 19:30:11.6 Driver arrived at delivery centre
# [ 0] 19:30:11.6 Parcel 6 for cust 13 return from delivery
# [ 0] 19:30:41.6 Parcel 7 for cust 13 return from delivery
# [ 0] 19:31:11.6 Parcel 8 for cust 15 return from delivery
# [ 0] 19:31:41.6 Parcel 9 for cust 16 return from delivery
# [ 0] 19:32:11.6 Parcel 10 for cust 16 return from delivery
# [ 0] 19:32:41.6 Parcel 11 for cust 16 return from delivery
# [ 0] 19:33:11.6 Parcel 12 for cust 17 return from delivery
# [ 0] 19:33:41.6 Parcel 13 for cust 17 return from delivery
# [ 0] 19:34:11.6 Parcel 14 for cust 18 return from delivery
# [ 0] 19:34:41.6 Parcel 15 for cust 19 return from delivery
# [ 0] 19:35:11.6 Parcel 3 for cust 7 return from delivery
# [ 0] 19:35:41.6 Parcel 4 for cust 7 return from delivery
# [ 0] 19:36:11.6 Parcel 0 for cust 5 return from delivery
# [ 0] 19:36:41.6 Parcel 1 for cust 6 return from delivery
# [ 0] 19:37:11.6 Parcel 2 for cust 6 return from delivery
# [ 0] 19:37:41.6 15 parcels left for next day
# [ 0] 19:47:41.6 Driver goes home
# [ 1] 17:00:00.0 Parcel 16 for cust 0 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 17 for cust 1 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 18 for cust 3 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 19 for cust 5 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 20 for cust 5 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 21 for cust 6 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 22 for cust 7 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 23 for cust 8 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 24 for cust 8 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 25 for cust 9 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 26 for cust 11 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 27 for cust 13 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 28 for cust 14 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 29 for cust 14 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 30 for cust 14 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 31 for cust 15 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 32 for cust 15 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 33 for cust 16 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 34 for cust 18 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 35 for cust 19 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 36 for cust 19 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 37 for cust 19 arr at delivery centre
# [ 1] 18:00:00.0 Driver arrives for work
# [ 1] 18:00:00.0 Parcel 18 for cust 3 out for delivery
# [ 1] 18:00:00.0 Parcel 1 for cust 6 out for delivery
# [ 1] 18:00:00.0 Parcel 2 for cust 6 out for delivery
# [ 1] 18:00:00.0 Parcel 21 for cust 6 out for delivery
# [ 1] 18:00:00.0 Parcel 23 for cust 8 out for delivery
# [ 1] 18:00:00.0 Parcel 24 for cust 8 out for delivery
# [ 1] 18:00:00.0 Parcel 0 for cust 5 out for delivery
# [ 1] 18:00:00.0 Parcel 19 for cust 5 out for delivery
# [ 1] 18:00:00.0 Parcel 20 for cust 5 out for delivery
# [ 1] 18:00:00.0 Parcel 3 for cust 7 out for delivery
# [ 1] 18:00:00.0 Parcel 4 for cust 7 out for delivery
# [ 1] 18:00:00.0 Parcel 22 for cust 7 out for delivery
# [ 1] 18:00:00.0 Parcel 16 for cust 0 out for delivery
# [ 1] 18:00:00.0 Parcel 17 for cust 1 out for delivery
# [ 1] 18:00:00.0 Parcel 25 for cust 9 out for delivery
# [ 1] 18:00:00.0 Parcel 26 for cust 11 out for delivery
# [ 1] 18:00:00.0 Parcel 6 for cust 13 out for delivery
# [ 1] 18:00:00.0 Parcel 7 for cust 13 out for delivery
# [ 1] 18:00:00.0 Parcel 27 for cust 13 out for delivery
# [ 1] 18:00:00.0 Parcel 28 for cust 14 out for delivery
# [ 1] 18:00:00.0 Parcel 29 for cust 14 out for delivery
# [ 1] 18:00:00.0 Parcel 30 for cust 14 out for delivery
# [ 1] 18:00:00.0 Parcel 8 for cust 15 out for delivery
# [ 1] 18:00:00.0 Parcel 31 for cust 15 out for delivery
# [ 1] 18:00:00.0 Parcel 32 for cust 15 out for delivery
# [ 1] 18:00:00.0 Parcel 9 for cust 16 out for delivery
# [ 1] 18:00:00.0 Parcel 10 for cust 16 out for delivery
# [ 1] 18:00:00.0 Parcel 11 for cust 16 out for delivery
# [ 1] 18:00:00.0 Parcel 33 for cust 16 out for delivery
# [ 1] 18:00:00.0 Parcel 12 for cust 17 out for delivery
# [ 1] 18:00:00.0 Parcel 13 for cust 17 out for delivery
# [ 1] 18:00:00.0 Parcel 14 for cust 18 out for delivery
# [ 1] 18:00:00.0 Parcel 34 for cust 18 out for delivery
# [ 1] 18:00:00.0 Parcel 15 for cust 19 out for delivery
# [ 1] 18:00:00.0 Parcel 35 for cust 19 out for delivery
# [ 1] 18:00:00.0 Parcel 36 for cust 19 out for delivery
# [ 1] 18:00:00.0 Parcel 37 for cust 19 out for delivery
# [ 1] 18:30:50.0 Driver leaves for delivery of 37 parcels to 16 customers
# [ 1] 18:30:50.0 Length of delivery tour: 27,548m
# [ 1] 18:30:50.0 Driver drives to Customer 3 at (4500, 4058)
# [ 1] 18:32:36.1 Driver arrived at Customer 3 at (4500, 4058)
# [ 1] 18:33:36.1 Customer 3 at (4500, 4058) not at home
# [ 1] 18:33:36.1 Driver drives to Customer 6 at (4717, 1050)
# [ 1] 18:46:30.1 Driver arrived at Customer 6 at (4717, 1050)
# [ 1] 18:47:30.1 Customer 6 at (4717, 1050) not at home
# [ 1] 18:47:30.1 Driver drives to Customer 8 at (5019, 1050)
# [ 1] 18:48:42.6 Driver arrived at Customer 8 at (5019, 1050)
# [ 1] 18:49:42.6 Customer 8 at (5019, 1050) not at home
# [ 1] 18:49:42.6 Driver drives to Customer 5 at (4626, 2200)
# [ 1] 18:56:53.4 Driver arrived at Customer 5 at (4626, 2200)
# [ 1] 18:57:53.4 Customer 5 at (4626, 2200) not at home
# [ 1] 18:57:53.4 Driver drives to Customer 7 at (4868, 2200)
# [ 1] 18:58:51.4 Driver arrived at Customer 7 at (4868, 2200)
# [ 1] 18:59:51.4 Customer 7 at (4868, 2200) not at home
# [ 1] 18:59:51.4 Driver drives to Customer 0 at (1687, 3350)
# [ 1] 19:22:50.7 Driver arrived at Customer 0 at (1687, 3350)
# [ 1] 19:23:50.7 Customer 0 at (1687, 3350) not at home
# [ 1] 19:23:50.7 Driver drives to Customer 1 at (3350, 6003)
# [ 1] 19:41:06.6 Driver arrived at Customer 1 at (3350, 6003)
# [ 1] 19:42:06.6 Customer 1 at (3350, 6003) not at home
# [ 1] 19:42:06.6 Driver drives to Customer 9 at (5261, 5650)
# [ 1] 19:51:09.9 Driver arrived at Customer 9 at (5261, 5650)
# [ 1] 19:52:09.9 Customer 9 at (5261, 5650) not at home
# [ 1] 19:52:09.9 Driver drives to Customer 11 at (5650, 4903)
# [ 1] 19:56:42.6 Driver arrived at Customer 11 at (5650, 4903)
# [ 1] 19:57:42.6 Customer 11 at (5650, 4903) not at home
# [ 1] 19:57:42.6 Driver drives to Customer 13 at (7134, 4500)
# [ 1] 20:05:15.4 Driver arrived at Customer 13 at (7134, 4500)
# [ 1] 20:06:15.4 Customer 13 at (7134, 4500) not at home
# [ 1] 20:06:15.4 Driver drives to Customer 14 at (7244, 4500)
# [ 1] 20:06:41.8 Driver arrived at Customer 14 at (7244, 4500)
# [ 1] 20:07:41.8 Customer 14 at (7244, 4500) not at home
# [ 1] 20:07:41.8 Driver drives to Customer 15 at (7336, 4500)
# [ 1] 20:08:03.9 Driver arrived at Customer 15 at (7336, 4500)
# [ 1] 20:09:03.9 Customer 15 at (7336, 4500) not at home
# [ 1] 20:09:03.9 Driver drives to Customer 16 at (7457, 4500)
# [ 1] 20:09:33.0 Driver arrived at Customer 16 at (7457, 4500)
# [ 1] 20:10:33.0 Customer 16 at (7457, 4500) not at home
# [ 1] 20:10:33.0 Driver drives to Customer 17 at (7691, 4500)
# [ 1] 20:11:29.1 Driver arrived at Customer 17 at (7691, 4500)
# [ 1] 20:12:29.1 Customer 17 at (7691, 4500) not at home
# [ 1] 20:12:29.1 Driver drives to Customer 18 at (7950, 5034)
# [ 1] 20:15:39.4 Driver arrived at Customer 18 at (7950, 5034)
# [ 1] 20:16:39.4 Customer 18 at (7950, 5034) not at home
# [ 1] 20:16:39.4 Driver drives to Customer 19 at (7950, 5463)
# [ 1] 20:18:22.4 Driver arrived at Customer 19 at (7950, 5463)
# [ 1] 20:19:22.4 Customer 19 at (7950, 5463) not at home
# [ 1] 20:19:22.4 Driver returns to delivery centre
# [ 1] 20:37:01.5 Driver arrived at delivery centre
# [ 1] 20:37:01.5 Parcel 18 for cust 3 return from delivery
# [ 1] 20:37:31.5 Parcel 1 for cust 6 return from delivery
# [ 1] 20:38:01.5 Parcel 2 for cust 6 return from delivery
# [ 1] 20:38:31.5 Parcel 21 for cust 6 return from delivery
# [ 1] 20:39:01.5 Parcel 23 for cust 8 return from delivery
# [ 1] 20:39:31.5 Parcel 24 for cust 8 return from delivery
# [ 1] 20:40:01.5 Parcel 0 for cust 5 return from delivery
# [ 1] 20:40:31.5 Parcel 19 for cust 5 return from delivery
# [ 1] 20:41:01.5 Parcel 20 for cust 5 return from delivery
# [ 1] 20:41:31.5 Parcel 3 for cust 7 return from delivery
# [ 1] 20:42:01.5 Parcel 4 for cust 7 return from delivery
# [ 1] 20:42:31.5 Parcel 22 for cust 7 return from delivery
# [ 1] 20:43:01.5 Parcel 16 for cust 0 return from delivery
# [ 1] 20:43:31.5 Parcel 17 for cust 1 return from delivery
# [ 1] 20:44:01.5 Parcel 25 for cust 9 return from delivery
# [ 1] 20:44:31.5 Parcel 26 for cust 11 return from delivery
# [ 1] 20:45:01.5 Parcel 6 for cust 13 return from delivery
# [ 1] 20:45:31.5 Parcel 7 for cust 13 return from delivery
# [ 1] 20:46:01.5 Parcel 27 for cust 13 return from delivery
# [ 1] 20:46:31.5 Parcel 28 for cust 14 return from delivery
# [ 1] 20:47:01.5 Parcel 29 for cust 14 return from delivery
# [ 1] 20:47:31.5 Parcel 30 for cust 14 return from delivery
# [ 1] 20:48:01.5 Parcel 8 for cust 15 return from delivery
# [ 1] 20:48:31.5 Parcel 31 for cust 15 return from delivery
# [ 1] 20:49:01.5 Parcel 32 for cust 15 return from delivery
# [ 1] 20:49:31.5 Parcel 9 for cust 16 return from delivery
# [ 1] 20:50:01.5 Parcel 10 for cust 16 return from delivery
# [ 1] 20:50:31.5 Parcel 11 for cust 16 return from delivery
# [ 1] 20:51:01.5 Parcel 33 for cust 16 return from delivery
# [ 1] 20:51:31.5 Parcel 12 for cust 17 return from delivery
# [ 1] 20:52:01.5 Parcel 13 for cust 17 return from delivery
# [ 1] 20:52:31.5 Parcel 14 for cust 18 return from delivery
# [ 1] 20:53:01.5 Parcel 34 for cust 18 return from delivery
# [ 1] 20:53:31.5 Parcel 15 for cust 19 return from delivery
# [ 1] 20:54:01.5 Parcel 35 for cust 19 return from delivery
# [ 1] 20:54:31.5 Parcel 36 for cust 19 return from delivery
# [ 1] 20:55:01.5 Parcel 37 for cust 19 return from delivery
# [ 1] 20:55:31.5 37 parcels left for next day
# [ 1] 21:05:31.5 Driver goes home
# [ 2] 17:00:00.0 Parcel 38 for cust 0 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 39 for cust 1 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 40 for cust 1 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 41 for cust 3 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 42 for cust 4 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 43 for cust 5 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 44 for cust 7 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 45 for cust 8 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 46 for cust 10 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 47 for cust 10 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 48 for cust 11 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 49 for cust 13 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 50 for cust 14 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 51 for cust 14 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 52 for cust 15 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 53 for cust 19 arr at delivery centre
# [ 2] 18:00:00.0 Driver arrives for work
# [ 2] 18:00:00.0 Parcel 18 for cust 3 out for delivery
# [ 2] 18:00:00.0 Parcel 41 for cust 3 out for delivery
# [ 2] 18:00:00.0 Parcel 0 for cust 5 out for delivery
# [ 2] 18:00:00.0 Parcel 19 for cust 5 out for delivery
# [ 2] 18:00:00.0 Parcel 20 for cust 5 out for delivery
# [ 2] 18:00:00.0 Parcel 43 for cust 5 out for delivery
# [ 2] 18:00:00.0 Parcel 3 for cust 7 out for delivery
# [ 2] 18:00:00.0 Parcel 4 for cust 7 out for delivery
# [ 2] 18:00:00.0 Parcel 22 for cust 7 out for delivery
# [ 2] 18:00:00.0 Parcel 44 for cust 7 out for delivery
# [ 2] 18:00:00.0 Parcel 42 for cust 4 out for delivery
# [ 2] 18:00:00.0 Parcel 1 for cust 6 out for delivery
# [ 2] 18:00:00.0 Parcel 2 for cust 6 out for delivery
# [ 2] 18:00:00.0 Parcel 21 for cust 6 out for delivery
# [ 2] 18:00:00.0 Parcel 23 for cust 8 out for delivery
# [ 2] 18:00:00.0 Parcel 24 for cust 8 out for delivery
# [ 2] 18:00:00.0 Parcel 45 for cust 8 out for delivery
# [ 2] 18:00:00.0 Parcel 16 for cust 0 out for delivery
# [ 2] 18:00:00.0 Parcel 38 for cust 0 out for delivery
# [ 2] 18:00:00.0 Parcel 17 for cust 1 out for delivery
# [ 2] 18:00:00.0 Parcel 39 for cust 1 out for delivery
# [ 2] 18:00:00.0 Parcel 40 for cust 1 out for delivery
# [ 2] 18:00:00.0 Parcel 25 for cust 9 out for delivery
# [ 2] 18:00:00.0 Parcel 26 for cust 11 out for delivery
# [ 2] 18:00:00.0 Parcel 48 for cust 11 out for delivery
# [ 2] 18:00:00.0 Parcel 46 for cust 10 out for delivery
# [ 2] 18:00:00.0 Parcel 47 for cust 10 out for delivery
# [ 2] 18:00:00.0 Parcel 6 for cust 13 out for delivery
# [ 2] 18:00:00.0 Parcel 7 for cust 13 out for delivery
# [ 2] 18:00:00.0 Parcel 27 for cust 13 out for delivery
# [ 2] 18:00:00.0 Parcel 49 for cust 13 out for delivery
# [ 2] 18:00:00.0 Parcel 28 for cust 14 out for delivery
# [ 2] 18:00:00.0 Parcel 29 for cust 14 out for delivery
# [ 2] 18:00:00.0 Parcel 30 for cust 14 out for delivery
# [ 2] 18:00:00.0 Parcel 50 for cust 14 out for delivery
# [ 2] 18:00:00.0 Parcel 51 for cust 14 out for delivery
# [ 2] 18:00:00.0 Parcel 8 for cust 15 out for delivery
# [ 2] 18:00:00.0 Parcel 31 for cust 15 out for delivery
# [ 2] 18:00:00.0 Parcel 32 for cust 15 out for delivery
# [ 2] 18:00:00.0 Parcel 52 for cust 15 out for delivery
# [ 2] 18:00:00.0 Parcel 9 for cust 16 out for delivery
# [ 2] 18:00:00.0 Parcel 10 for cust 16 out for delivery
# [ 2] 18:00:00.0 Parcel 11 for cust 16 out for delivery
# [ 2] 18:00:00.0 Parcel 33 for cust 16 out for delivery
# [ 2] 18:00:00.0 Parcel 12 for cust 17 out for delivery
# [ 2] 18:00:00.0 Parcel 13 for cust 17 out for delivery
# [ 2] 18:00:00.0 Parcel 14 for cust 18 out for delivery
# [ 2] 18:00:00.0 Parcel 34 for cust 18 out for delivery
# [ 2] 18:00:00.0 Parcel 15 for cust 19 out for delivery
# [ 2] 18:00:00.0 Parcel 35 for cust 19 out for delivery
# [ 2] 18:00:00.0 Parcel 36 for cust 19 out for delivery
# [ 2] 18:00:00.0 Parcel 37 for cust 19 out for delivery
# [ 2] 18:00:00.0 Parcel 53 for cust 19 out for delivery
# [ 2] 18:44:10.0 Driver leaves for delivery of 53 parcels to 18 customers
# [ 2] 18:44:10.0 Length of delivery tour: 25,458m
# [ 2] 18:44:10.0 Driver drives to Customer 3 at (4500, 4058)
# [ 2] 18:45:56.1 Driver arrived at Customer 3 at (4500, 4058)
# [ 2] 18:46:00.3 Customer 3 at (4500, 4058) answers door
# [ 2] 18:46:00.3 Customer 3 at (4500, 4058) accepts Parcel 18 for cust 3
# [ 2] 18:46:19.5 Customer 3 at (4500, 4058) accepts Parcel 41 for cust 3
# [ 2] 18:46:24.6 Customer 3 at (4500, 4058) signs off
# [ 2] 18:46:25.4 Driver drives to Customer 5 at (4626, 2200)
# [ 2] 18:54:21.6 Driver arrived at Customer 5 at (4626, 2200)
# [ 2] 18:55:21.6 Customer 5 at (4626, 2200) not at home
# [ 2] 18:55:21.6 Driver drives to Customer 7 at (4868, 2200)
# [ 2] 18:56:19.7 Driver arrived at Customer 7 at (4868, 2200)
# [ 2] 18:57:19.7 Customer 7 at (4868, 2200) not at home
# [ 2] 18:57:19.7 Driver drives to Customer 4 at (4606, 1050)
# [ 2] 19:03:49.4 Driver arrived at Customer 4 at (4606, 1050)
# [ 2] 19:04:49.4 Customer 4 at (4606, 1050) not at home
# [ 2] 19:04:49.4 Driver drives to Customer 6 at (4717, 1050)
# [ 2] 20:23:03.0 Customer 18 at (7950, 5034) not at home
# [ 2] 20:23:03.0 Driver drives to Customer 19 at (7950, 5463)
# [ 2] 20:24:46.0 Driver arrived at Customer 19 at (7950, 5463)
# [ 2] 20:25:15.4 Customer 19 at (7950, 5463) answers door
# [ 2] 20:25:15.4 Customer 19 at (7950, 5463) accepts Parcel 15 for cust 19
# [ 2] 20:25:25.9 Customer 19 at (7950, 5463) accepts Parcel 35 for cust 19
# [ 2] 20:25:30.2 Customer 19 at (7950, 5463) accepts Parcel 36 for cust 19
# [ 2] 20:25:50.7 Customer 19 at (7950, 5463) accepts Parcel 37 for cust 19
# [ 2] 20:25:54.0 Customer 19 at (7950, 5463) accepts Parcel 53 for cust 19
# [ 2] 20:25:54.2 Customer 19 at (7950, 5463) signs off
# [ 2] 20:25:54.6 Driver returns to delivery centre
# [ 2] 20:43:33.7 Driver arrived at delivery centre
# [ 2] 20:43:33.7 Parcel 0 for cust 5 return from delivery
# [ 2] 20:44:03.7 Parcel 19 for cust 5 return from delivery
# [ 2] 20:44:33.7 Parcel 20 for cust 5 return from delivery
# [ 2] 20:45:03.7 Parcel 43 for cust 5 return from delivery
# [ 2] 20:45:33.7 Parcel 3 for cust 7 return from delivery
# [ 2] 20:46:03.7 Parcel 4 for cust 7 return from delivery
# [ 2] 20:46:33.7 Parcel 22 for cust 7 return from delivery
# [ 2] 20:47:03.7 Parcel 44 for cust 7 return from delivery
# [ 2] 20:47:33.7 Parcel 42 for cust 4 return from delivery
# [ 2] 20:48:03.7 Parcel 1 for cust 6 return from delivery
# [ 2] 20:48:33.7 Parcel 2 for cust 6 return from delivery
# [ 2] 20:49:03.7 Parcel 21 for cust 6 return from delivery
# [ 2] 20:49:33.7 Parcel 16 for cust 0 return from delivery
# [ 2] 20:50:03.7 Parcel 38 for cust 0 return from delivery
# [ 2] 20:50:33.7 Parcel 17 for cust 1 return from delivery
# [ 2] 20:51:03.7 Parcel 39 for cust 1 return from delivery
# [ 2] 20:51:33.7 Parcel 40 for cust 1 return from delivery
# [ 2] 20:52:03.7 Parcel 25 for cust 9 return from delivery
# [ 2] 20:52:33.7 Parcel 26 for cust 11 return from delivery
# [ 2] 20:53:03.7 Parcel 48 for cust 11 return from delivery
# [ 2] 20:53:33.7 Parcel 46 for cust 10 return from delivery
# [ 2] 20:54:03.7 Parcel 47 for cust 10 return from delivery
# [ 2] 20:54:33.7 Parcel 6 for cust 13 return from delivery
# [ 2] 20:55:03.7 Parcel 7 for cust 13 return from delivery
# [ 2] 20:55:33.7 Parcel 27 for cust 13 return from delivery
# [ 2] 20:56:03.7 Parcel 49 for cust 13 return from delivery
# [ 2] 20:56:33.7 Parcel 28 for cust 14 return from delivery
# [ 2] 20:57:03.7 Parcel 29 for cust 14 return from delivery
# [ 2] 20:57:33.7 Parcel 30 for cust 14 return from delivery
# [ 2] 20:58:03.7 Parcel 50 for cust 14 return from delivery
# [ 2] 20:58:33.7 Parcel 51 for cust 14 return from delivery
# [ 2] 20:59:03.7 Parcel 8 for cust 15 return from delivery
# [ 2] 20:59:33.7 Parcel 31 for cust 15 return from delivery
# [ 2] 21:00:03.7 Parcel 32 for cust 15 return from delivery
# [ 2] 21:00:33.7 Parcel 52 for cust 15 return from delivery
# [ 2] 21:01:03.7 Parcel 9 for cust 16 return from delivery
# [ 2] 21:01:33.7 Parcel 10 for cust 16 return from delivery
# [ 2] 21:02:03.7 Parcel 11 for cust 16 return from delivery
# [ 2] 21:02:33.7 Parcel 33 for cust 16 return from delivery
# [ 2] 21:03:03.7 Parcel 12 for cust 17 return from delivery
# [ 2] 21:03:33.7 Parcel 13 for cust 17 return from delivery
# [ 2] 21:04:03.7 Parcel 14 for cust 18 return from delivery
# [ 2] 21:04:33.7 Parcel 34 for cust 18 return from delivery
# [ 2] 21:05:03.7 43 parcels left for next day
# [ 2] 21:15:03.7 Driver goes home
# [ 3] 17:00:00.0 Parcel 54 for cust 0 arr at delivery centre
# [ 3] 17:00:00.0 Parcel 55 for cust 0 arr at delivery centre
# [ 3] 17:00:00.0 Parcel 56 for cust 2 arr at delivery centre
# [ 3] 17:00:00.0 Parcel 57 for cust 3 arr at delivery centre
# [ 3] 17:00:00.0 Parcel 58 for cust 4 arr at delivery centre
# [ 3] 17:00:00.0 Parcel 59 for cust 5 arr at delivery centre
# [ 3] 17:00:00.0 Parcel 60 for cust 5 arr at delivery centre
# [ 3] 17:00:00.0 Parcel 61 for cust 6 arr at delivery centre
# [ 3] 17:00:00.0 Parcel 62 for cust 7 arr at delivery centre
# [ 3] 17:00:00.0 Parcel 63 for cust 8 arr at delivery centre
# [ 3] 17:00:00.0 Parcel 64 for cust 8 arr at delivery centre
# [ 3] 17:00:00.0 Parcel 65 for cust 9 arr at delivery centre
# [ 3] 17:00:00.0 Parcel 66 for cust 10 arr at delivery centre
# [ 3] 17:00:00.0 Parcel 67 for cust 13 arr at delivery centre
# [ 3] 17:00:00.0 Parcel 68 for cust 14 arr at delivery centre
# [ 3] 17:00:00.0 Parcel 69 for cust 17 arr at delivery centre
# [ 3] 17:00:00.0 Parcel 70 for cust 18 arr at delivery centre
# [ 3] 17:00:00.0 Parcel 71 for cust 18 arr at delivery centre
# [ 3] 17:00:00.0 Parcel 72 for cust 19 arr at delivery centre
# [ 3] 17:00:00.0 Parcel 73 for cust 19 arr at delivery centre
# [ 3] 17:00:00.0 Parcel 74 for cust 19 arr at delivery centre
# [ 3] 18:00:00.0 Driver arrives for work
# [ 3] 18:00:00.0 Parcel 57 for cust 3 out for delivery
# [ 3] 18:00:00.0 Parcel 16 for cust 0 out for delivery
# [ 3] 18:00:00.0 Parcel 38 for cust 0 out for delivery
# [ 3] 18:00:00.0 Parcel 54 for cust 0 out for delivery
# [ 3] 18:00:00.0 Parcel 55 for cust 0 out for delivery
# [ 3] 18:00:00.0 Parcel 42 for cust 4 out for delivery
# [ 3] 18:00:00.0 Parcel 58 for cust 4 out for delivery
# [ 3] 18:00:00.0 Parcel 1 for cust 6 out for delivery
# [ 3] 18:00:00.0 Parcel 2 for cust 6 out for delivery
# [ 3] 18:00:00.0 Parcel 21 for cust 6 out for delivery
# [ 3] 18:00:00.0 Parcel 61 for cust 6 out for delivery
# [ 3] 18:00:00.0 Parcel 63 for cust 8 out for delivery
# [ 3] 18:00:00.0 Parcel 64 for cust 8 out for delivery
# [ 3] 18:00:00.0 Parcel 0 for cust 5 out for delivery
# [ 3] 18:00:00.0 Parcel 19 for cust 5 out for delivery
# [ 3] 18:00:00.0 Parcel 20 for cust 5 out for delivery
# [ 3] 18:00:00.0 Parcel 43 for cust 5 out for delivery
# [ 3] 18:00:00.0 Parcel 59 for cust 5 out for delivery
# [ 3] 18:00:00.0 Parcel 60 for cust 5 out for delivery
# [ 3] 18:00:00.0 Parcel 3 for cust 7 out for delivery
# [ 3] 18:00:00.0 Parcel 4 for cust 7 out for delivery
# [ 3] 18:00:00.0 Parcel 22 for cust 7 out for delivery
# [ 3] 18:00:00.0 Parcel 44 for cust 7 out for delivery
# [ 3] 18:00:00.0 Parcel 62 for cust 7 out for delivery
# [ 3] 18:00:00.0 Parcel 14 for cust 18 out for delivery
# [ 3] 18:00:00.0 Parcel 34 for cust 18 out for delivery
# [ 3] 18:00:00.0 Parcel 70 for cust 18 out for delivery
# [ 3] 18:00:00.0 Parcel 71 for cust 18 out for delivery
# [ 3] 18:00:00.0 Parcel 72 for cust 19 out for delivery
# [ 3] 18:00:00.0 Parcel 73 for cust 19 out for delivery
# [ 3] 18:00:00.0 Parcel 74 for cust 19 out for delivery
# [ 3] 18:00:00.0 Parcel 12 for cust 17 out for delivery
# [ 3] 18:00:00.0 Parcel 13 for cust 17 out for delivery
# [ 3] 18:00:00.0 Parcel 69 for cust 17 out for delivery
# [ 3] 18:00:00.0 Parcel 9 for cust 16 out for delivery
# [ 3] 18:00:00.0 Parcel 10 for cust 16 out for delivery
# [ 3] 18:00:00.0 Parcel 11 for cust 16 out for delivery
# [ 3] 18:00:00.0 Parcel 33 for cust 16 out for delivery
# [ 3] 18:00:00.0 Parcel 8 for cust 15 out for delivery
# [ 3] 18:00:00.0 Parcel 31 for cust 15 out for delivery
# [ 3] 18:00:00.0 Parcel 32 for cust 15 out for delivery
# [ 3] 18:00:00.0 Parcel 52 for cust 15 out for delivery
# [ 3] 18:00:00.0 Parcel 28 for cust 14 out for delivery
# [ 3] 18:00:00.0 Parcel 29 for cust 14 out for delivery
# [ 3] 18:00:00.0 Parcel 30 for cust 14 out for delivery
# [ 3] 18:00:00.0 Parcel 50 for cust 14 out for delivery
# [ 3] 18:00:00.0 Parcel 51 for cust 14 out for delivery
# [ 3] 18:00:00.0 Parcel 68 for cust 14 out for delivery
# [ 3] 18:00:00.0 Parcel 6 for cust 13 out for delivery
# [ 3] 18:00:00.0 Parcel 7 for cust 13 out for delivery
# [ 3] 18:00:00.0 Parcel 27 for cust 13 out for delivery
# [ 3] 18:00:00.0 Parcel 49 for cust 13 out for delivery
# [ 3] 18:00:00.0 Parcel 67 for cust 13 out for delivery
# [ 3] 18:00:00.0 Parcel 46 for cust 10 out for delivery
# [ 3] 18:00:00.0 Parcel 47 for cust 10 out for delivery
# [ 3] 18:00:00.0 Parcel 66 for cust 10 out for delivery
# [ 3] 18:00:00.0 Parcel 26 for cust 11 out for delivery
# [ 3] 18:00:00.0 Parcel 48 for cust 11 out for delivery
# [ 3] 18:00:00.0 Parcel 25 for cust 9 out for delivery
# [ 3] 18:00:00.0 Parcel 65 for cust 9 out for delivery
# [ 3] 18:00:00.0 Parcel 17 for cust 1 out for delivery
# [ 3] 18:00:00.0 Parcel 39 for cust 1 out for delivery
# [ 3] 18:00:00.0 Parcel 40 for cust 1 out for delivery
# [ 3] 18:00:00.0 Parcel 56 for cust 2 out for delivery
# [ 3] 18:53:20.0 Driver leaves for delivery of 64 parcels to 19 customers
# [ 3] 18:53:20.0 Length of delivery tour: 30,044m
# [ 3] 18:53:20.0 Driver drives to Customer 3 at (4500, 4058)
# [ 3] 18:55:06.1 Driver arrived at Customer 3 at (4500, 4058)
# [ 3] 18:56:06.1 Customer 3 at (4500, 4058) not at home
# [ 3] 18:56:06.1 Driver drives to Customer 0 at (1687, 3350)
# [ 3] 19:10:11.1 Driver arrived at Customer 0 at (1687, 3350)
# [ 3] 19:11:01.8 Customer 0 at (1687, 3350) answers door
# [ 3] 19:11:01.8 Customer 0 at (1687, 3350) accepts Parcel 16 for cust 0
# [ 3] 19:11:06.0 Customer 0 at (1687, 3350) accepts Parcel 38 for cust 0
# [ 3] 19:11:15.6 Customer 0 at (1687, 3350) accepts Parcel 54 for cust 0
# [ 3] 19:11:16.1 Customer 0 at (1687, 3350) accepts Parcel 55 for cust 0
# [ 3] 19:11:17.9 Customer 0 at (1687, 3350) signs off
# [ 3] 19:11:58.0 Driver drives to Customer 4 at (4606, 1050)
# [ 3] 19:30:08.8 Driver arrived at Customer 4 at (4606, 1050)
# [ 3] 19:30:22.5 Customer 4 at (4606, 1050) answers door
# [ 3] 19:30:22.5 Customer 4 at (4606, 1050) accepts Parcel 42 for cust 4
# [ 3] 19:30:27.5 Customer 4 at (4606, 1050) accepts Parcel 58 for cust 4
# [ 3] 19:30:35.4 Customer 4 at (4606, 1050) signs off
# [ 3] 19:30:38.9 Driver drives to Customer 6 at (4717, 1050)
# [ 3] 19:31:05.5 Driver arrived at Customer 6 at (4717, 1050)
# [ 3] 19:32:05.5 Customer 6 at (4717, 1050) not at home
# [ 3] 19:32:05.5 Driver drives to Customer 8 at (5019, 1050)
# [ 3] 19:33:18.0 Driver arrived at Customer 8 at (5019, 1050)
# [ 3] 19:34:18.0 Customer 8 at (5019, 1050) not at home
# [ 3] 19:34:18.0 Driver drives to Customer 5 at (4626, 2200)
# [ 3] 19:41:28.8 Driver arrived at Customer 5 at (4626, 2200)
# [ 3] 19:42:28.8 Customer 5 at (4626, 2200) not at home
# [ 3] 19:42:28.8 Driver drives to Customer 7 at (4868, 2200)
# [ 3] 19:43:26.9 Driver arrived at Customer 7 at (4868, 2200)
# [ 3] 19:44:26.9 Customer 7 at (4868, 2200) not at home
# [ 3] 19:44:26.9 Driver drives to Customer 18 at (7950, 5034)
# [ 3] 20:05:25.0 Driver arrived at Customer 18 at (7950, 5034)
# [ 3] 20:06:25.0 Customer 18 at (7950, 5034) not at home
# [ 3] 20:06:25.0 Driver drives to Customer 19 at (7950, 5463)
# [ 3] 20:08:07.9 Driver arrived at Customer 19 at (7950, 5463)
# [ 3] 20:08:33.9 Customer 19 at (7950, 5463) answers door
# [ 3] 20:08:33.9 Customer 19 at (7950, 5463) accepts Parcel 72 for cust 19
# [ 3] 20:08:36.7 Customer 19 at (7950, 5463) accepts Parcel 73 for cust 19
# [ 3] 20:08:37.2 Customer 19 at (7950, 5463) accepts Parcel 74 for cust 19
# [ 3] 20:08:39.2 Customer 19 at (7950, 5463) signs off
# [ 3] 20:08:46.6 Driver drives to Customer 17 at (7691, 4500)
# [ 3] 20:13:39.8 Driver arrived at Customer 17 at (7691, 4500)
# [ 3] 20:14:39.8 Customer 17 at (7691, 4500) not at home
# [ 3] 20:14:39.8 Driver drives to Customer 16 at (7457, 4500)
# [ 3] 20:15:36.0 Driver arrived at Customer 16 at (7457, 4500)
# [ 3] 20:16:36.0 Customer 16 at (7457, 4500) not at home
# [ 3] 20:16:36.0 Driver drives to Customer 15 at (7336, 4500)
# [ 3] 20:17:05.0 Driver arrived at Customer 15 at (7336, 4500)
# [ 3] 20:18:05.0 Customer 15 at (7336, 4500) not at home
# [ 3] 20:18:05.0 Driver drives to Customer 14 at (7244, 4500)
# [ 3] 20:18:27.1 Driver arrived at Customer 14 at (7244, 4500)
# [ 3] 20:19:27.1 Customer 14 at (7244, 4500) not at home
# [ 3] 20:19:27.1 Driver drives to Customer 13 at (7134, 4500)
# [ 3] 20:19:53.5 Driver arrived at Customer 13 at (7134, 4500)
# [ 3] 20:20:53.5 Customer 13 at (7134, 4500) not at home
# [ 3] 20:20:53.5 Driver drives to Customer 10 at (5650, 4648)
# [ 3] 20:27:25.2 Driver arrived at Customer 10 at (5650, 4648)
# [ 3] 20:28:25.2 Customer 10 at (5650, 4648) not at home
# [ 3] 20:28:25.2 Driver drives to Customer 11 at (5650, 4903)
# [ 3] 20:29:26.4 Driver arrived at Customer 11 at (5650, 4903)
# [ 3] 20:30:26.4 Customer 11 at (5650, 4903) not at home
# [ 3] 20:30:26.4 Driver drives to Customer 9 at (5261, 5650)
# [ 3] 20:37:01.4 Driver arrived at Customer 9 at (5261, 5650)
# [ 3] 20:37:04.4 Customer 9 at (5261, 5650) answers door
# [ 3] 20:37:04.4 Customer 9 at (5261, 5650) accepts Parcel 25 for cust 9
# [ 3] 20:37:09.5 Customer 9 at (5261, 5650) accepts Parcel 65 for cust 9
# [ 3] 20:37:13.5 Customer 9 at (5261, 5650) signs off
# [ 3] 20:37:18.9 Driver drives to Customer 1 at (3350, 6003)
# [ 3] 20:46:22.2 Driver arrived at Customer 1 at (3350, 6003)
# [ 3] 20:47:22.2 Customer 1 at (3350, 6003) not at home
# [ 3] 20:47:22.2 Driver drives to Customer 2 at (3913, 7363)
# [ 3] 20:53:44.6 Driver arrived at Customer 2 at (3913, 7363)
# [ 3] 20:54:44.6 Customer 2 at (3913, 7363) not at home
# [ 3] 20:54:44.6 Driver returns to delivery centre
# [ 3] 21:11:43.6 Driver arrived at delivery centre
# [ 3] 21:11:43.6 Parcel 57 for cust 3 return from delivery
# [ 3] 21:12:13.6 Parcel 1 for cust 6 return from delivery
# [ 3] 21:12:43.6 Parcel 2 for cust 6 return from delivery
# [ 3] 21:13:13.6 Parcel 21 for cust 6 return from delivery
# [ 3] 21:13:43.6 Parcel 61 for cust 6 return from delivery
# [ 3] 21:14:13.6 Parcel 63 for cust 8 return from delivery
# [ 3] 21:14:43.6 Parcel 64 for cust 8 return from delivery
# [ 3] 21:15:13.6 Parcel 0 for cust 5 return from delivery
# [ 3] 21:15:43.6 Parcel 19 for cust 5 return from delivery
# [ 3] 21:16:13.6 Parcel 20 for cust 5 return from delivery
# [ 3] 21:16:43.6 Parcel 43 for cust 5 return from delivery
# [ 3] 21:17:13.6 Parcel 59 for cust 5 return from delivery
# [ 3] 21:17:43.6 Parcel 60 for cust 5 return from delivery
# [ 3] 21:18:13.6 Parcel 3 for cust 7 return from delivery
# [ 3] 21:18:43.6 Parcel 4 for cust 7 return from delivery
# [ 3] 21:19:13.6 Parcel 22 for cust 7 return from delivery
# [ 3] 21:19:43.6 Parcel 44 for cust 7 return from delivery
# [ 3] 21:20:13.6 Parcel 62 for cust 7 return from delivery
# [ 3] 21:20:43.6 Parcel 14 for cust 18 return from delivery
# [ 3] 21:21:13.6 Parcel 34 for cust 18 return from delivery
# [ 3] 21:21:43.6 Parcel 70 for cust 18 return from delivery
# [ 3] 21:22:13.6 Parcel 71 for cust 18 return from delivery
# [ 3] 21:22:43.6 Parcel 12 for cust 17 return from delivery
# [ 3] 21:23:13.6 Parcel 13 for cust 17 return from delivery
# [ 3] 21:23:43.6 Parcel 69 for cust 17 return from delivery
# [ 3] 21:24:13.6 Parcel 9 for cust 16 return from delivery
# [ 3] 21:24:43.6 Parcel 10 for cust 16 return from delivery
# [ 3] 21:25:13.6 Parcel 11 for cust 16 return from delivery
# [ 3] 21:25:43.6 Parcel 33 for cust 16 return from delivery
# [ 3] 21:26:13.6 Parcel 8 for cust 15 return from delivery
# [ 3] 21:26:43.6 Parcel 31 for cust 15 return from delivery
# [ 3] 21:27:13.6 Parcel 32 for cust 15 return from delivery
# [ 3] 21:27:43.6 Parcel 52 for cust 15 return from delivery
# [ 3] 21:28:13.6 Parcel 28 for cust 14 return from delivery
# [ 3] 21:28:43.6 Parcel 29 for cust 14 return from delivery
# [ 3] 21:29:13.6 Parcel 30 for cust 14 return from delivery
# [ 3] 21:29:43.6 Parcel 50 for cust 14 return from delivery
# [ 3] 21:30:13.6 Parcel 51 for cust 14 return from delivery
# [ 3] 21:30:43.6 Parcel 68 for cust 14 return from delivery
# [ 3] 21:31:13.6 Parcel 6 for cust 13 return from delivery
# [ 3] 21:31:43.6 Parcel 7 for cust 13 return from delivery
# [ 3] 21:32:13.6 Parcel 27 for cust 13 return from delivery
# [ 3] 21:32:43.6 Parcel 49 for cust 13 return from delivery
# [ 3] 21:33:13.6 Parcel 67 for cust 13 return from delivery
# [ 3] 21:33:43.6 Parcel 46 for cust 10 return from delivery
# [ 3] 21:34:13.6 Parcel 47 for cust 10 return from delivery
# [ 3] 21:34:43.6 Parcel 66 for cust 10 return from delivery
# [ 3] 21:35:13.6 Parcel 26 for cust 11 return from delivery
# [ 3] 21:35:43.6 Parcel 48 for cust 11 return from delivery
# [ 3] 21:36:13.6 Parcel 17 for cust 1 return from delivery
# [ 3] 21:36:43.6 Parcel 39 for cust 1 return from delivery
# [ 3] 21:37:13.6 Parcel 40 for cust 1 return from delivery
# [ 3] 21:37:43.6 Parcel 56 for cust 2 return from delivery
# [ 3] 21:38:13.6 53 parcels left for next day
# [ 3] 21:48:13.6 Driver goes home
# [ 4] 17:00:00.0 Parcel 75 for cust 0 arr at delivery centre
# [ 4] 17:00:00.0 Parcel 76 for cust 0 arr at delivery centre
# [ 4] 17:00:00.0 Parcel 77 for cust 1 arr at delivery centre
# [ 4] 17:00:00.0 Parcel 78 for cust 1 arr at delivery centre
# [ 4] 17:00:00.0 Parcel 79 for cust 2 arr at delivery centre
# [ 4] 17:00:00.0 Parcel 80 for cust 3 arr at delivery centre
# [ 4] 17:00:00.0 Parcel 81 for cust 3 arr at delivery centre
# [ 4] 17:00:00.0 Parcel 82 for cust 5 arr at delivery centre
# [ 4] 17:00:00.0 Parcel 83 for cust 7 arr at delivery centre
# [ 4] 17:00:00.0 Parcel 84 for cust 8 arr at delivery centre
# [ 4] 17:00:00.0 Parcel 85 for cust 8 arr at delivery centre
# [ 4] 17:00:00.0 Parcel 86 for cust 8 arr at delivery centre
# [ 4] 17:00:00.0 Parcel 87 for cust 10 arr at delivery centre
# [ 4] 17:00:00.0 Parcel 88 for cust 10 arr at delivery centre
# [ 4] 17:00:00.0 Parcel 89 for cust 12 arr at delivery centre
# [ 4] 17:00:00.0 Parcel 90 for cust 13 arr at delivery centre
# [ 4] 17:00:00.0 Parcel 91 for cust 16 arr at delivery centre
# [ 4] 17:00:00.0 Parcel 92 for cust 16 arr at delivery centre
# [ 4] 17:00:00.0 Parcel 93 for cust 16 arr at delivery centre
# [ 4] 17:00:00.0 Parcel 94 for cust 16 arr at delivery centre
# [ 4] 17:00:00.0 Parcel 95 for cust 16 arr at delivery centre
# [ 4] 17:00:00.0 Parcel 96 for cust 17 arr at delivery centre
# [ 4] 17:00:00.0 Parcel 97 for cust 17 arr at delivery centre
# [ 4] 17:00:00.0 Parcel 98 for cust 18 arr at delivery centre
# [ 4] 17:00:00.0 Parcel 99 for cust 19 arr at delivery centre
# [ 4] 18:00:00.0 Driver arrives for work
# [ 4] 18:00:00.0 Parcel 57 for cust 3 out for delivery
# [ 4] 18:00:00.0 Parcel 80 for cust 3 out for delivery
# [ 4] 18:00:00.0 Parcel 81 for cust 3 out for delivery
# [ 4] 18:00:00.0 Parcel 0 for cust 5 out for delivery
# [ 4] 18:00:00.0 Parcel 19 for cust 5 out for delivery
# [ 4] 18:00:00.0 Parcel 20 for cust 5 out for delivery
# [ 4] 18:00:00.0 Parcel 43 for cust 5 out for delivery
# [ 4] 18:00:00.0 Parcel 59 for cust 5 out for delivery
# [ 4] 18:00:00.0 Parcel 60 for cust 5 out for delivery
# [ 4] 18:00:00.0 Parcel 82 for cust 5 out for delivery
# [ 4] 18:00:00.0 Parcel 3 for cust 7 out for delivery
# [ 4] 18:00:00.0 Parcel 4 for cust 7 out for delivery
# [ 4] 18:00:00.0 Parcel 22 for cust 7 out for delivery
# [ 4] 18:00:00.0 Parcel 44 for cust 7 out for delivery
# [ 4] 18:00:00.0 Parcel 62 for cust 7 out for delivery
# [ 4] 18:00:00.0 Parcel 83 for cust 7 out for delivery
# [ 4] 18:00:00.0 Parcel 1 for cust 6 out for delivery
# [ 4] 18:00:00.0 Parcel 2 for cust 6 out for delivery
# [ 4] 18:00:00.0 Parcel 21 for cust 6 out for delivery
# [ 4] 18:00:00.0 Parcel 61 for cust 6 out for delivery
# [ 4] 18:00:00.0 Parcel 63 for cust 8 out for delivery
# [ 4] 18:00:00.0 Parcel 64 for cust 8 out for delivery
# [ 4] 18:00:00.0 Parcel 84 for cust 8 out for delivery
# [ 4] 18:00:00.0 Parcel 85 for cust 8 out for delivery
# [ 4] 18:00:00.0 Parcel 86 for cust 8 out for delivery
# [ 4] 18:00:00.0 Parcel 75 for cust 0 out for delivery
# [ 4] 18:00:00.0 Parcel 76 for cust 0 out for delivery
# [ 4] 18:00:00.0 Parcel 17 for cust 1 out for delivery
# [ 4] 18:00:00.0 Parcel 39 for cust 1 out for delivery
# [ 4] 18:00:00.0 Parcel 40 for cust 1 out for delivery
# [ 4] 18:00:00.0 Parcel 77 for cust 1 out for delivery
# [ 4] 18:00:00.0 Parcel 78 for cust 1 out for delivery
# [ 4] 18:00:00.0 Parcel 56 for cust 2 out for delivery
# [ 4] 18:00:00.0 Parcel 79 for cust 2 out for delivery
# [ 4] 18:00:00.0 Parcel 89 for cust 12 out for delivery
# [ 4] 18:00:00.0 Parcel 99 for cust 19 out for delivery
# [ 4] 18:00:00.0 Parcel 14 for cust 18 out for delivery
# [ 4] 18:00:00.0 Parcel 34 for cust 18 out for delivery
# [ 4] 18:00:00.0 Parcel 70 for cust 18 out for delivery
# [ 4] 18:00:00.0 Parcel 71 for cust 18 out for delivery
# [ 4] 18:00:00.0 Parcel 98 for cust 18 out for delivery
# [ 4] 18:00:00.0 Parcel 12 for cust 17 out for delivery
# [ 4] 18:00:00.0 Parcel 13 for cust 17 out for delivery
# [ 4] 18:00:00.0 Parcel 69 for cust 17 out for delivery
# [ 4] 18:00:00.0 Parcel 96 for cust 17 out for delivery
# [ 4] 18:00:00.0 Parcel 97 for cust 17 out for delivery
# [ 4] 18:00:00.0 Parcel 9 for cust 16 out for delivery
# [ 4] 18:00:00.0 Parcel 10 for cust 16 out for delivery
# [ 4] 18:00:00.0 Parcel 11 for cust 16 out for delivery
# [ 4] 18:00:00.0 Parcel 33 for cust 16 out for delivery
# [ 4] 18:00:00.0 Parcel 91 for cust 16 out for delivery
# [ 4] 18:00:00.0 Parcel 92 for cust 16 out for delivery
# [ 4] 18:00:00.0 Parcel 93 for cust 16 out for delivery
# [ 4] 18:00:00.0 Parcel 94 for cust 16 out for delivery
# [ 4] 18:00:00.0 Parcel 95 for cust 16 out for delivery
# [ 4] 18:00:00.0 Parcel 8 for cust 15 out for delivery
# [ 4] 18:00:00.0 Parcel 31 for cust 15 out for delivery
# [ 4] 18:00:00.0 Parcel 32 for cust 15 out for delivery
# [ 4] 18:00:00.0 Parcel 52 for cust 15 out for delivery
# [ 4] 18:00:00.0 Parcel 28 for cust 14 out for delivery
# [ 4] 18:00:00.0 Parcel 29 for cust 14 out for delivery
# [ 4] 18:00:00.0 Parcel 30 for cust 14 out for delivery
# [ 4] 18:00:00.0 Parcel 50 for cust 14 out for delivery
# [ 4] 18:00:00.0 Parcel 51 for cust 14 out for delivery
# [ 4] 18:00:00.0 Parcel 68 for cust 14 out for delivery
# [ 4] 18:00:00.0 Parcel 6 for cust 13 out for delivery
# [ 4] 18:00:00.0 Parcel 7 for cust 13 out for delivery
# [ 4] 18:00:00.0 Parcel 27 for cust 13 out for delivery
# [ 4] 18:00:00.0 Parcel 49 for cust 13 out for delivery
# [ 4] 18:00:00.0 Parcel 67 for cust 13 out for delivery
# [ 4] 18:00:00.0 Parcel 90 for cust 13 out for delivery
# [ 4] 18:00:00.0 Parcel 26 for cust 11 out for delivery
# [ 4] 18:00:00.0 Parcel 48 for cust 11 out for delivery
# [ 4] 18:00:00.0 Parcel 46 for cust 10 out for delivery
# [ 4] 18:00:00.0 Parcel 47 for cust 10 out for delivery
# [ 4] 18:00:00.0 Parcel 66 for cust 10 out for delivery
# [ 4] 18:00:00.0 Parcel 87 for cust 10 out for delivery
# [ 4] 18:00:00.0 Parcel 88 for cust 10 out for delivery
# [ 4] 19:05:00.0 Driver leaves for delivery of 78 parcels to 18 customers
# [ 4] 19:05:00.0 Length of delivery tour: 29,018m
# [ 4] 19:05:00.0 Driver drives to Customer 3 at (4500, 4058)
# [ 4] 19:06:46.1 Driver arrived at Customer 3 at (4500, 4058)
# [ 4] 19:07:46.1 Customer 3 at (4500, 4058) not at home
# [ 4] 19:07:46.1 Driver drives to Customer 5 at (4626, 2200)
# [ 4] 19:15:42.2 Driver arrived at Customer 5 at (4626, 2200)
# [ 4] 19:16:42.2 Customer 5 at (4626, 2200) not at home
# [ 4] 19:16:42.2 Driver drives to Customer 7 at (4868, 2200)
# [ 4] 19:17:40.3 Driver arrived at Customer 7 at (4868, 2200)
# [ 4] 19:18:40.3 Customer 7 at (4868, 2200) not at home
# [ 4] 19:18:40.3 Driver drives to Customer 6 at (4717, 1050)
# [ 4] 19:25:36.7 Driver arrived at Customer 6 at (4717, 1050)
# [ 4] 19:26:36.7 Customer 6 at (4717, 1050) not at home
# [ 4] 19:26:36.7 Driver drives to Customer 8 at (5019, 1050)
# [ 4] 19:27:49.2 Driver arrived at Customer 8 at (5019, 1050)
# [ 4] 19:27:51.7 Customer 8 at (5019, 1050) answers door
# [ 4] 19:27:51.7 Customer 8 at (5019, 1050) accepts Parcel 63 for cust 8
# [ 4] 19:27:51.8 Customer 8 at (5019, 1050) accepts Parcel 64 for cust 8
# [ 4] 19:27:56.8 Customer 8 at (5019, 1050) accepts Parcel 84 for cust 8
# [ 4] 19:28:04.1 Customer 8 at (5019, 1050) accepts Parcel 85 for cust 8
# [ 4] 19:28:10.1 Customer 8 at (5019, 1050) accepts Parcel 86 for cust 8
# [ 4] 19:28:16.8 Customer 8 at (5019, 1050) signs off
# [ 4] 19:28:25.6 Driver drives to Customer 0 at (1687, 3350)
# [ 4] 19:48:15.5 Driver arrived at Customer 0 at (1687, 3350)
# [ 4] 19:49:15.5 Customer 0 at (1687, 3350) not at home
# [ 4] 19:49:15.5 Driver drives to Customer 1 at (3350, 6003)
# [ 4] 20:06:31.3 Driver arrived at Customer 1 at (3350, 6003)
# [ 4] 20:07:31.3 Customer 1 at (3350, 6003) not at home
# [ 4] 20:07:31.3 Driver drives to Customer 2 at (3913, 7363)
# [ 4] 20:13:53.7 Driver arrived at Customer 2 at (3913, 7363)
# [ 4] 20:14:53.7 Customer 2 at (3913, 7363) not at home
# [ 4] 20:14:53.7 Driver drives to Customer 12 at (6227, 5650)
# [ 4] 20:34:11.2 Driver arrived at Customer 12 at (6227, 5650)
# [ 4] 20:35:11.2 Customer 12 at (6227, 5650) not at home
# [ 4] 20:35:11.2 Driver drives to Customer 19 at (7950, 5463)
# [ 4] 20:42:49.6 Driver arrived at Customer 19 at (7950, 5463)
# [ 4] 20:43:49.6 Customer 19 at (7950, 5463) not at home
# [ 4] 20:43:49.6 Driver drives to Customer 18 at (7950, 5034)
# [ 4] 20:45:32.5 Driver arrived at Customer 18 at (7950, 5034)
# [ 4] 20:46:32.5 Customer 18 at (7950, 5034) not at home
# [ 4] 20:46:32.5 Driver drives to Customer 17 at (7691, 4500)
# [ 4] 20:49:42.9 Driver arrived at Customer 17 at (7691, 4500)
# [ 4] 20:50:42.9 Customer 17 at (7691, 4500) not at home
# [ 4] 20:50:42.9 Driver drives to Customer 16 at (7457, 4500)
# [ 4] 20:51:39.0 Driver arrived at Customer 16 at (7457, 4500)
# [ 4] 20:52:39.0 Customer 16 at (7457, 4500) not at home
# [ 4] 20:52:39.0 Driver drives to Customer 15 at (7336, 4500)
# [ 4] 20:53:08.1 Driver arrived at Customer 15 at (7336, 4500)
# [ 4] 20:54:08.1 Customer 15 at (7336, 4500) not at home
# [ 4] 20:54:08.1 Driver drives to Customer 14 at (7244, 4500)
# [ 4] 20:54:30.1 Driver arrived at Customer 14 at (7244, 4500)
# [ 4] 20:55:15.6 Customer 14 at (7244, 4500) answers door
# [ 4] 20:55:15.6 Customer 14 at (7244, 4500) accepts Parcel 28 for cust 14
# [ 4] 20:55:21.1 Customer 14 at (7244, 4500) accepts Parcel 29 for cust 14
# [ 4] 20:55:25.7 Customer 14 at (7244, 4500) accepts Parcel 30 for cust 14
# [ 4] 20:56:10.3 Customer 14 at (7244, 4500) accepts Parcel 50 for cust 14
# [ 4] 20:56:13.4 Customer 14 at (7244, 4500) accepts Parcel 51 for cust 14
# [ 4] 20:56:28.4 Customer 14 at (7244, 4500) accepts Parcel 68 for cust 14
# [ 4] 20:56:34.0 Customer 14 at (7244, 4500) signs off
# [ 4] 20:56:38.5 Driver drives to Customer 13 at (7134, 4500)
# [ 4] 20:57:04.9 Driver arrived at Customer 13 at (7134, 4500)
# [ 4] 20:58:04.9 Customer 13 at (7134, 4500) not at home
# [ 4] 20:58:04.9 Driver drives to Customer 11 at (5650, 4903)
# [ 4] 21:11:36.3 Driver arrived at Customer 11 at (5650, 4903)
# [ 4] 21:11:38.9 Customer 11 at (5650, 4903) answers door
# [ 4] 21:11:38.9 Customer 11 at (5650, 4903) accepts Parcel 26 for cust 11
# [ 4] 21:11:58.9 Customer 11 at (5650, 4903) accepts Parcel 48 for cust 11
# [ 4] 21:12:11.0 Customer 11 at (5650, 4903) signs off
# [ 4] 21:12:34.3 Driver drives to Customer 10 at (5650, 4648)
# [ 4] 21:13:35.5 Driver arrived at Customer 10 at (5650, 4648)
# [ 4] 21:14:35.5 Customer 10 at (5650, 4648) not at home
# [ 4] 21:14:35.5 Driver returns to delivery centre
# [ 4] 21:19:47.0 Driver arrived at delivery centre
# [ 4] 21:19:47.0 Parcel 57 for cust 3 return from delivery
# [ 4] 21:20:17.0 Parcel 80 for cust 3 return from delivery
# [ 4] 21:20:47.0 Parcel 81 for cust 3 return from delivery
# [ 4] 21:21:17.0 Parcel 0 for cust 5 return from delivery
# [ 4] 21:21:47.0 Parcel 19 for cust 5 return from delivery
# [ 4] 21:22:17.0 Parcel 20 for cust 5 return from delivery
# [ 4] 21:22:47.0 Parcel 43 for cust 5 return from delivery
# [ 4] 21:23:17.0 Parcel 59 for cust 5 return from delivery
# [ 4] 21:23:47.0 Parcel 60 for cust 5 return from delivery
# [ 4] 21:24:17.0 Parcel 82 for cust 5 return from delivery
# ...
# [ 6] 18:00:00.0 Parcel 102 for cust 3 out for delivery
# [ 6] 18:00:00.0 Parcel 103 for cust 3 out for delivery
# [ 6] 18:00:00.0 Parcel 0 for cust 5 out for delivery
# [ 6] 18:00:00.0 Parcel 19 for cust 5 out for delivery
# [ 6] 18:00:00.0 Parcel 20 for cust 5 out for delivery
# [ 6] 18:00:00.0 Parcel 43 for cust 5 out for delivery
# [ 6] 18:00:00.0 Parcel 59 for cust 5 out for delivery
# [ 6] 18:00:00.0 Parcel 60 for cust 5 out for delivery
# [ 6] 18:00:00.0 Parcel 82 for cust 5 out for delivery
# [ 6] 18:00:00.0 Parcel 128 for cust 5 out for delivery
# [ 6] 18:00:00.0 Parcel 129 for cust 5 out for delivery
# [ 6] 18:00:00.0 Parcel 130 for cust 5 out for delivery
# [ 6] 18:00:00.0 Parcel 3 for cust 7 out for delivery
# [ 6] 18:00:00.0 Parcel 4 for cust 7 out for delivery
# [ 6] 18:00:00.0 Parcel 22 for cust 7 out for delivery
# [ 6] 18:00:00.0 Parcel 44 for cust 7 out for delivery
# [ 6] 18:00:00.0 Parcel 62 for cust 7 out for delivery
# [ 6] 18:00:00.0 Parcel 83 for cust 7 out for delivery
# [ 6] 18:00:00.0 Parcel 104 for cust 4 out for delivery
# [ 6] 18:00:00.0 Parcel 105 for cust 4 out for delivery
# [ 6] 18:00:00.0 Parcel 127 for cust 4 out for delivery
# [ 6] 18:00:00.0 Parcel 1 for cust 6 out for delivery
# [ 6] 18:00:00.0 Parcel 2 for cust 6 out for delivery
# [ 6] 18:00:00.0 Parcel 21 for cust 6 out for delivery
# [ 6] 18:00:00.0 Parcel 61 for cust 6 out for delivery
# [ 6] 18:00:00.0 Parcel 106 for cust 6 out for delivery
# [ 6] 18:00:00.0 Parcel 107 for cust 6 out for delivery
# [ 6] 18:00:00.0 Parcel 108 for cust 6 out for delivery
# [ 6] 18:00:00.0 Parcel 131 for cust 6 out for delivery
# [ 6] 18:00:00.0 Parcel 132 for cust 6 out for delivery
# [ 6] 18:00:00.0 Parcel 109 for cust 8 out for delivery
# [ 6] 18:00:00.0 Parcel 133 for cust 8 out for delivery
# [ 6] 18:00:00.0 Parcel 134 for cust 8 out for delivery
# [ 6] 18:00:00.0 Parcel 135 for cust 8 out for delivery
# [ 6] 18:00:00.0 Parcel 75 for cust 0 out for delivery
# [ 6] 18:00:00.0 Parcel 76 for cust 0 out for delivery
# [ 6] 18:00:00.0 Parcel 100 for cust 0 out for delivery
# [ 6] 18:00:00.0 Parcel 124 for cust 0 out for delivery
# [ 6] 18:00:00.0 Parcel 125 for cust 0 out for delivery
# [ 6] 18:00:00.0 Parcel 112 for cust 11 out for delivery
# [ 6] 18:00:00.0 Parcel 113 for cust 11 out for delivery
# [ 6] 18:00:00.0 Parcel 136 for cust 11 out for delivery
# [ 6] 18:00:00.0 Parcel 137 for cust 12 out for delivery
# [ 6] 18:00:00.0 Parcel 99 for cust 19 out for delivery
# [ 6] 18:00:00.0 Parcel 123 for cust 19 out for delivery
# [ 6] 18:00:00.0 Parcel 148 for cust 19 out for delivery
# [ 6] 18:00:00.0 Parcel 149 for cust 19 out for delivery
# [ 6] 18:00:00.0 Parcel 150 for cust 19 out for delivery
# [ 6] 18:00:00.0 Parcel 14 for cust 18 out for delivery
# [ 6] 18:00:00.0 Parcel 34 for cust 18 out for delivery
# [ 6] 18:00:00.0 Parcel 70 for cust 18 out for delivery
# [ 6] 18:00:00.0 Parcel 71 for cust 18 out for delivery
# [ 6] 18:00:00.0 Parcel 98 for cust 18 out for delivery
# [ 6] 18:00:00.0 Parcel 146 for cust 18 out for delivery
# [ 6] 18:00:00.0 Parcel 147 for cust 18 out for delivery
# [ 6] 18:00:00.0 Parcel 12 for cust 17 out for delivery
# [ 6] 18:00:00.0 Parcel 13 for cust 17 out for delivery
# [ 6] 18:00:00.0 Parcel 69 for cust 17 out for delivery
# [ 6] 18:00:00.0 Parcel 96 for cust 17 out for delivery
# [ 6] 18:00:00.0 Parcel 97 for cust 17 out for delivery
# [ 6] 18:00:00.0 Parcel 122 for cust 17 out for delivery
# [ 6] 18:00:00.0 Parcel 145 for cust 17 out for delivery
# [ 6] 18:00:00.0 Parcel 9 for cust 16 out for delivery
# [ 6] 18:00:00.0 Parcel 10 for cust 16 out for delivery
# [ 6] 18:00:00.0 Parcel 11 for cust 16 out for delivery
# [ 6] 18:00:00.0 Parcel 33 for cust 16 out for delivery
# [ 6] 18:00:00.0 Parcel 91 for cust 16 out for delivery
# [ 6] 18:00:00.0 Parcel 92 for cust 16 out for delivery
# [ 6] 18:00:00.0 Parcel 93 for cust 16 out for delivery
# [ 6] 18:00:00.0 Parcel 94 for cust 16 out for delivery
# [ 6] 18:00:00.0 Parcel 95 for cust 16 out for delivery
# [ 6] 18:00:00.0 Parcel 121 for cust 16 out for delivery
# [ 6] 18:00:00.0 Parcel 142 for cust 16 out for delivery
# [ 6] 18:00:00.0 Parcel 143 for cust 16 out for delivery
# [ 6] 18:00:00.0 Parcel 144 for cust 16 out for delivery
# [ 6] 18:00:00.0 Parcel 8 for cust 15 out for delivery
# [ 6] 18:00:00.0 Parcel 31 for cust 15 out for delivery
# [ 6] 18:00:00.0 Parcel 32 for cust 15 out for delivery
# [ 6] 18:00:00.0 Parcel 52 for cust 15 out for delivery
# [ 6] 18:00:00.0 Parcel 118 for cust 15 out for delivery
# [ 6] 18:00:00.0 Parcel 119 for cust 15 out for delivery
# [ 6] 18:00:00.0 Parcel 120 for cust 15 out for delivery
# [ 6] 18:00:00.0 Parcel 117 for cust 14 out for delivery
# [ 6] 18:00:00.0 Parcel 139 for cust 14 out for delivery
# [ 6] 18:00:00.0 Parcel 140 for cust 14 out for delivery
# [ 6] 18:00:00.0 Parcel 141 for cust 14 out for delivery
# [ 6] 18:00:00.0 Parcel 6 for cust 13 out for delivery
# [ 6] 18:00:00.0 Parcel 7 for cust 13 out for delivery
# [ 6] 18:00:00.0 Parcel 27 for cust 13 out for delivery
# [ 6] 18:00:00.0 Parcel 49 for cust 13 out for delivery
# [ 6] 18:00:00.0 Parcel 67 for cust 13 out for delivery
# [ 6] 18:00:00.0 Parcel 90 for cust 13 out for delivery
# [ 6] 18:00:00.0 Parcel 114 for cust 13 out for delivery
# [ 6] 18:00:00.0 Parcel 115 for cust 13 out for delivery
# [ 6] 18:00:00.0 Parcel 116 for cust 13 out for delivery
# [ 6] 18:00:00.0 Parcel 138 for cust 13 out for delivery
# [ 6] 18:00:00.0 Parcel 110 for cust 9 out for delivery
# [ 6] 18:00:00.0 Parcel 17 for cust 1 out for delivery
# [ 6] 18:00:00.0 Parcel 39 for cust 1 out for delivery
# [ 6] 18:00:00.0 Parcel 40 for cust 1 out for delivery
# [ 6] 18:00:00.0 Parcel 77 for cust 1 out for delivery
# [ 6] 18:00:00.0 Parcel 78 for cust 1 out for delivery
# [ 6] 18:00:00.0 Parcel 101 for cust 1 out for delivery
# [ 6] 18:00:00.0 Parcel 56 for cust 2 out for delivery
# [ 6] 18:00:00.0 Parcel 79 for cust 2 out for delivery
# [ 6] 18:00:00.0 Parcel 126 for cust 2 out for delivery
# [ 6] 19:30:50.0 Driver leaves for delivery of 109 parcels to 19 customers
# [ 6] 19:30:50.0 Length of delivery tour: 31,318m
# [ 6] 19:30:50.0 Driver drives to Customer 3 at (4500, 4058)
# [ 6] 19:32:36.1 Driver arrived at Customer 3 at (4500, 4058)
# [ 6] 19:33:36.1 Customer 3 at (4500, 4058) not at home
# [ 6] 19:33:36.1 Driver drives to Customer 5 at (4626, 2200)
# [ 6] 19:41:32.2 Driver arrived at Customer 5 at (4626, 2200)
# [ 6] 19:42:32.2 Customer 5 at (4626, 2200) not at home
# [ 6] 19:42:32.2 Driver drives to Customer 7 at (4868, 2200)
# [ 6] 19:43:30.3 Driver arrived at Customer 7 at (4868, 2200)
# [ 6] 19:44:30.3 Customer 7 at (4868, 2200) not at home
# [ 6] 19:44:30.3 Driver drives to Customer 4 at (4606, 1050)
# [ 6] 19:51:00.1 Driver arrived at Customer 4 at (4606, 1050)
# [ 6] 19:52:00.1 Customer 4 at (4606, 1050) not at home
# [ 6] 19:52:00.1 Driver drives to Customer 6 at (4717, 1050)
# [ 6] 19:52:26.7 Driver arrived at Customer 6 at (4717, 1050)
# [ 6] 19:53:26.7 Customer 6 at (4717, 1050) not at home
# [ 6] 19:53:26.7 Driver drives to Customer 8 at (5019, 1050)
# [ 6] 19:54:39.2 Driver arrived at Customer 8 at (5019, 1050)
# [ 6] 19:55:39.2 Customer 8 at (5019, 1050) not at home
# [ 6] 19:55:39.2 Driver drives to Customer 0 at (1687, 3350)
# [ 6] 20:15:29.1 Driver arrived at Customer 0 at (1687, 3350)
# [ 6] 20:16:29.1 Customer 0 at (1687, 3350) not at home
# [ 6] 20:16:29.1 Driver drives to Customer 11 at (5650, 4903)
# [ 6] 20:38:33.0 Driver arrived at Customer 11 at (5650, 4903)
# [ 6] 20:39:33.0 Customer 11 at (5650, 4903) not at home
# [ 6] 20:39:33.0 Driver drives to Customer 12 at (6227, 5650)
# [ 6] 20:44:50.7 Driver arrived at Customer 12 at (6227, 5650)
# [ 6] 20:45:50.7 Customer 12 at (6227, 5650) not at home
# [ 6] 20:45:50.7 Driver drives to Customer 19 at (7950, 5463)
# [ 6] 20:53:29.1 Driver arrived at Customer 19 at (7950, 5463)
# [ 6] 20:54:29.1 Customer 19 at (7950, 5463) not at home
# [ 6] 20:54:29.1 Driver drives to Customer 18 at (7950, 5034)
# [ 6] 20:56:12.1 Driver arrived at Customer 18 at (7950, 5034)
# [ 6] 20:57:12.1 Customer 18 at (7950, 5034) not at home
# [ 6] 20:57:12.1 Driver drives to Customer 17 at (7691, 4500)
# [ 6] 21:00:22.4 Driver arrived at Customer 17 at (7691, 4500)
# [ 6] 21:01:22.4 Customer 17 at (7691, 4500) not at home
# [ 6] 21:01:22.4 Driver drives to Customer 16 at (7457, 4500)
# [ 6] 21:02:18.6 Driver arrived at Customer 16 at (7457, 4500)
# [ 6] 21:03:18.6 Customer 16 at (7457, 4500) not at home
# [ 6] 21:03:18.6 Driver drives to Customer 15 at (7336, 4500)
# [ 6] 21:03:47.6 Driver arrived at Customer 15 at (7336, 4500)
# [ 6] 21:04:47.6 Customer 15 at (7336, 4500) not at home
# [ 6] 21:04:47.6 Driver drives to Customer 14 at (7244, 4500)
# [ 6] 21:05:09.7 Driver arrived at Customer 14 at (7244, 4500)
# [ 6] 21:06:09.7 Customer 14 at (7244, 4500) not at home
# [ 6] 21:06:09.7 Driver drives to Customer 13 at (7134, 4500)
# [ 6] 21:06:36.1 Driver arrived at Customer 13 at (7134, 4500)
# [ 6] 21:07:36.1 Customer 13 at (7134, 4500) not at home
# [ 6] 21:07:36.1 Driver drives to Customer 9 at (5261, 5650)
# [ 6] 21:19:41.6 Driver arrived at Customer 9 at (5261, 5650)
# [ 6] 21:20:41.6 Customer 9 at (5261, 5650) not at home
# [ 6] 21:20:41.6 Driver drives to Customer 1 at (3350, 6003)
# [ 6] 21:29:45.0 Driver arrived at Customer 1 at (3350, 6003)
# [ 6] 21:30:45.0 Customer 1 at (3350, 6003) not at home
# [ 6] 21:30:45.0 Driver drives to Customer 2 at (3913, 7363)
# [ 6] 21:37:07.3 Driver arrived at Customer 2 at (3913, 7363)
# [ 6] 21:38:07.3 Customer 2 at (3913, 7363) not at home
# [ 6] 21:38:07.3 Driver returns to delivery centre
# [ 6] 21:55:06.3 Driver arrived at delivery centre
# [ 6] 21:55:06.3 Parcel 57 for cust 3 return from delivery
# [ 6] 21:55:36.3 Parcel 80 for cust 3 return from delivery
# [ 6] 21:56:06.3 Parcel 81 for cust 3 return from delivery
# [ 6] 21:56:36.3 Parcel 102 for cust 3 return from delivery
# [ 6] 21:57:06.3 Parcel 103 for cust 3 return from delivery
# [ 6] 21:57:36.3 Parcel 0 for cust 5 return from delivery
# [ 6] 21:58:06.3 Parcel 19 for cust 5 return from delivery
# [ 6] 21:58:36.3 Parcel 20 for cust 5 return from delivery
# [ 6] 21:59:06.3 Parcel 43 for cust 5 return from delivery
# [ 6] 21:59:36.3 Parcel 59 for cust 5 return from delivery
# [ 6] 22:00:06.3 Parcel 60 for cust 5 return from delivery
# [ 6] 22:00:36.3 Parcel 82 for cust 5 return from delivery
# [ 6] 22:01:06.3 Parcel 128 for cust 5 return from delivery
# [ 6] 22:01:36.3 Parcel 129 for cust 5 return from delivery
# [ 6] 22:02:06.3 Parcel 130 for cust 5 return from delivery
# [ 6] 22:02:36.3 Parcel 3 for cust 7 return from delivery
# [ 6] 22:03:06.3 Parcel 4 for cust 7 return from delivery
# [ 6] 22:03:36.3 Parcel 22 for cust 7 return from delivery
# [ 6] 22:04:06.3 Parcel 44 for cust 7 return from delivery
# [ 6] 22:04:36.3 Parcel 62 for cust 7 return from delivery
# [ 6] 22:05:06.3 Parcel 83 for cust 7 return from delivery
# [ 6] 22:05:36.3 Parcel 104 for cust 4 return from delivery
# [ 6] 22:06:06.3 Parcel 105 for cust 4 return from delivery
# [ 6] 22:06:36.3 Parcel 127 for cust 4 return from delivery
# [ 6] 22:07:06.3 Parcel 1 for cust 6 return from delivery
# [ 6] 22:07:36.3 Parcel 2 for cust 6 return from delivery
# [ 6] 22:08:06.3 Parcel 21 for cust 6 return from delivery
# [ 6] 22:08:36.3 Parcel 61 for cust 6 return from delivery
# [ 6] 22:09:06.3 Parcel 106 for cust 6 return from delivery
# [ 6] 22:09:36.3 Parcel 107 for cust 6 return from delivery
# [ 6] 22:10:06.3 Parcel 108 for cust 6 return from delivery
# [ 6] 22:10:36.3 Parcel 131 for cust 6 return from delivery
# [ 6] 22:11:06.3 Parcel 132 for cust 6 return from delivery
# [ 6] 22:11:36.3 Parcel 109 for cust 8 return from delivery
# [ 6] 22:12:06.3 Parcel 133 for cust 8 return from delivery
# [ 6] 22:12:36.3 Parcel 134 for cust 8 return from delivery
# [ 6] 22:13:06.3 Parcel 135 for cust 8 return from delivery
# [ 6] 22:13:36.3 Parcel 75 for cust 0 return from delivery
# [ 6] 22:14:06.3 Parcel 76 for cust 0 return from delivery
# [ 6] 22:14:36.3 Parcel 100 for cust 0 return from delivery
# [ 6] 22:15:06.3 Parcel 124 for cust 0 return from delivery
# [ 6] 22:15:36.3 Parcel 125 for cust 0 return from delivery
# [ 6] 22:16:06.3 Parcel 112 for cust 11 return from delivery
# [ 6] 22:16:36.3 Parcel 113 for cust 11 return from delivery
# [ 6] 22:17:06.3 Parcel 136 for cust 11 return from delivery
# [ 6] 22:17:36.3 Parcel 137 for cust 12 return from delivery
# [ 6] 22:18:06.3 Parcel 99 for cust 19 return from delivery
# [ 6] 22:18:36.3 Parcel 123 for cust 19 return from delivery
# [ 6] 22:19:06.3 Parcel 148 for cust 19 return from delivery
# [ 6] 22:19:36.3 Parcel 149 for cust 19 return from delivery
# [ 6] 22:20:06.3 Parcel 150 for cust 19 return from delivery
# [ 6] 22:20:36.3 Parcel 14 for cust 18 return from delivery
# [ 6] 22:21:06.3 Parcel 34 for cust 18 return from delivery
# [ 6] 22:21:36.3 Parcel 70 for cust 18 return from delivery
# [ 6] 22:22:06.3 Parcel 71 for cust 18 return from delivery
# [ 6] 22:22:36.3 Parcel 98 for cust 18 return from delivery
# [ 6] 22:23:06.3 Parcel 146 for cust 18 return from delivery
# [ 6] 22:23:36.3 Parcel 147 for cust 18 return from delivery
# [ 6] 22:24:06.3 Parcel 12 for cust 17 return from delivery
# [ 6] 22:24:36.3 Parcel 13 for cust 17 return from delivery
# [ 6] 22:25:06.3 Parcel 69 for cust 17 return from delivery
# [ 6] 22:25:36.3 Parcel 96 for cust 17 return from delivery
# [ 6] 22:26:06.3 Parcel 97 for cust 17 return from delivery
# [ 6] 22:26:36.3 Parcel 122 for cust 17 return from delivery
# [ 6] 22:27:06.3 Parcel 145 for cust 17 return from delivery
# [ 6] 22:27:36.3 Parcel 9 for cust 16 return from delivery
# [ 6] 22:28:06.3 Parcel 10 for cust 16 return from delivery
# [ 6] 22:28:36.3 Parcel 11 for cust 16 return from delivery
# [ 6] 22:29:06.3 Parcel 33 for cust 16 return from delivery
# [ 6] 22:29:36.3 Parcel 91 for cust 16 return from delivery
# [ 6] 22:30:06.3 Parcel 92 for cust 16 return from delivery
# [ 6] 22:30:36.3 Parcel 93 for cust 16 return from delivery
# [ 6] 22:31:06.3 Parcel 94 for cust 16 return from delivery
# [ 6] 22:31:36.3 Parcel 95 for cust 16 return from delivery
# [ 6] 22:32:06.3 Parcel 121 for cust 16 return from delivery
# [ 6] 22:32:36.3 Parcel 142 for cust 16 return from delivery
# [ 6] 22:33:06.3 Parcel 143 for cust 16 return from delivery
# [ 6] 22:33:36.3 Parcel 144 for cust 16 return from delivery
# [ 6] 22:34:06.3 Parcel 8 for cust 15 return from delivery
# [ 6] 22:34:36.3 Parcel 31 for cust 15 return from delivery
# [ 6] 22:35:06.3 Parcel 32 for cust 15 return from delivery
# [ 6] 22:35:36.3 Parcel 52 for cust 15 return from delivery
# [ 6] 22:36:06.3 Parcel 118 for cust 15 return from delivery
# [ 6] 22:36:36.3 Parcel 119 for cust 15 return from delivery
# [ 6] 22:37:06.3 Parcel 120 for cust 15 return from delivery
# [ 6] 22:37:36.3 Parcel 117 for cust 14 return from delivery
# [ 6] 22:38:06.3 Parcel 139 for cust 14 return from delivery
# [ 6] 22:38:36.3 Parcel 140 for cust 14 return from delivery
# [ 6] 22:39:06.3 Parcel 141 for cust 14 return from delivery
# [ 6] 22:39:36.3 Parcel 6 for cust 13 return from delivery
# [ 6] 22:40:06.3 Parcel 7 for cust 13 return from delivery
# [ 6] 22:40:36.3 Parcel 27 for cust 13 return from delivery
# [ 6] 22:41:06.3 Parcel 49 for cust 13 return from delivery
# [ 6] 22:41:36.3 Parcel 67 for cust 13 return from delivery
# [ 6] 22:42:06.3 Parcel 90 for cust 13 return from delivery
# [ 6] 22:42:36.3 Parcel 114 for cust 13 return from delivery
# [ 6] 22:43:06.3 Parcel 115 for cust 13 return from delivery
# [ 6] 22:43:36.3 Parcel 116 for cust 13 return from delivery
# [ 6] 22:44:06.3 Parcel 138 for cust 13 return from delivery
# [ 6] 22:44:36.3 Parcel 110 for cust 9 return from delivery
# [ 6] 22:45:06.3 Parcel 17 for cust 1 return from delivery
# [ 6] 22:45:36.3 Parcel 39 for cust 1 return from delivery
# [ 6] 22:46:06.3 Parcel 40 for cust 1 return from delivery
# [ 6] 22:46:36.3 Parcel 77 for cust 1 return from delivery
# [ 6] 22:47:06.3 Parcel 78 for cust 1 return from delivery
# [ 6] 22:47:36.3 Parcel 101 for cust 1 return from delivery
# [ 6] 22:48:06.3 Parcel 56 for cust 2 return from delivery
# [ 6] 22:48:36.3 Parcel 79 for cust 2 return from delivery
# [ 6] 22:49:06.3 Parcel 126 for cust 2 return from delivery
# [ 6] 22:49:36.3 109 parcels left for next day
# [ 6] 22:59:36.3 Driver goes home
# Delivery Centre Inventory: 109 parcels
