# %% [markdown]
# # Prelude

# %%
import matplotlib.pyplot as plt
import pulp
import math
import random
import pandas as pd
import numpy as np
import simpy

# %% [markdown]
# # Utilities

# %% [markdown]
# ## Points and Distances

# %%
def dist(p1, p2):
    (x1, y1) = p1
    (x2, y2) = p2
    return int(math.sqrt((x1-x2)**2+(y1-y2)**2))

# %% [markdown]
# ## PlotMap

# %%
def label(i):
    return (label(i//26-1)+chr(65+i%26)) if i>25 else chr(65+i)

# %%
def plotMap(G, T=[], P=[], w=None,
            style='r-o', lw=1, ms=3, 
            styleT='go', msT=3,
            styleP='b-o', lwP=2, msP=3,
            stylePT='go', msPT=7,
            styleW='ro', msW=9,
            text=None, grid=False, labels=False, scale=False):

    V, E = G

    def round_down(x, level): return (x//level)*level
    def round_up(x, level): return (x//level+1)*level
    
    xmin = round_down(min([ x for (x, _) in V ]), 100)
    xmax = round_up(max([ x for (x, _) in V ]), 100)
    ymin = round_down(min([ y for (_, y) in V ]), 100)
    ymax = round_up(max([ y for (_, y) in V ]), 100)
    dx = xmax-xmin
    dy = ymax-ymin
    yoffset = (ymax-ymin)//10
    
    fig = plt.gcf()
    fig.set_size_inches(4, 4)
    plt.xlim(xmin, xmax)
    plt.ylim(ymin-yoffset, ymax)
    
    if not grid:
        plt.axis('off')

    for e in E:
        p1, p2 = e
        plt.plot( [ p1[0], p2[0] ],
                  [ p1[1], p2[1] ], 
                  style, lw=lw, ms=ms)
    if scale:
        # plot 1000m scale
        ybar = ymin-0.9*yoffset
        D = [ (xmin, ybar+50), (xmin, ybar), (xmin+1000, ybar), (xmin+1000, ybar+50) ]
        plt.plot( [ d[0] for d in D ], [ d[1] for d in D ], 'k-', lw=0.5)
        plt.text(xmin+500, ymin-0.7*yoffset, '1000m' , horizontalalignment='center', size=8)
    
    if labels:
        for i in range(len(V)):
            x, y = V[i]
            plt.text(x+0.0150*dx, y-0.0350*dy, label(i), size=8)
        
    for t in T:
        plt.plot( [ t[0] ], [ t[1] ], 
                  styleT, ms=msT)
        
    plt.plot( [ p[0] for p in P ],
              [ p[1] for p in P ], 
              styleP, lw=lwP, ms=msP)
    
    for p in P:
        if p in T:
            plt.plot( [ p[0] ], [ p[1] ], 
                      stylePT, ms=msPT)
    if w is not None:
        plt.plot( [ w[0] ], [ w[1] ], 
                      styleW, ms=msW)
    if text is not None:
        plt.text(xmax, ymin-0.7*yoffset, text, horizontalalignment='right', size=8)
    if grid:
        plt.grid()
    plt.show()

# %% [markdown]
# ## Add Targets

# %%
def addTargets(M, T):
    V, E = M
    E = E.copy()
    V = V.copy()
    for t in T:
        minD = math.inf
        minE = None
        for e in E:
            P, Q = e
            distT = dist(P, t)+dist(t, Q)-dist(P, Q)
            if distT < minD:
                minD = distT
                minE = e
        P, Q = minE
        E.remove( (P, Q) )
        E.append( (P, t) )
        E.append( (t, Q) )
        V.append(t)
    return V, E

# %% [markdown]
# ## Generate Central Warehouse Location

# %%
from statistics import median

def generateWarehouseLocation(M):
    V, _ = M
    xc = median([ x for (x, y) in V ])
    yc = median([ y for (x, y) in V ])
    cloc = (xc, yc)
    minloc = V[0]
    mindist = dist(minloc, cloc)
    for i in range(1, len(V)):
        d = dist(V[i], cloc)
        if d<mindist:
            minloc = V[i]
            mindist = dist(V[i], cloc)
    return minloc

# %% [markdown]
# ## Time Handling

# %% [markdown]
# **Convention:** In this project we measure simulation time in seconds. The simulation will start at 0:00. Time related methods will be added as they are needed.

# %% [markdown]
# `timestamp(t)` generates a timestamp string in the form `[dd] hh:mm:ss.d`

# %%
def timestamp(t):
    t = round(t, 1)
    day = int(t)//(24*3600)
    t = t - day*24*3600
    hour = int(t)//3600
    t = t - hour*3600
    mins = int(t)//60
    t = t - mins*60
    secs = int(t)
    t = int(round((t-secs)*10,1)) 
    return f"[{day:2d}] {hour:02d}:{mins:02d}:{secs:02d}.{t:1d}"

# %%
timestamp(24*3600*3+17*3600+615.1)
# Out:
# '[ 3] 17:10:15.1'

# %%
timestamp(24*3600*12+3*3600+122.1)
# Out:
# '[12] 03:02:02.1'

# %%
def day(now):
    return int(now//(24*3600))

# %%
def nextHour(env, hour):
    beginningOfDay = int(env.now//(24*3600))*24*3600
    timeOfDay = env.now-beginningOfDay
    if hour*3600 > timeOfDay:
        return hour*3600 - timeOfDay
    else:
        return hour*3600 + 24*3600 - timeOfDay

# %% [markdown]
# ## Plotting Routines

# %%
import scipy.stats as stats

def histPlot(data, title="", xlabel="",
             discrete=False, width=None, height=None):
    
    minx = min(data)
    maxx = max(data)
    μ = np.mean(data)
    σ = np.std(data)
    
    fig = plt.figure()
    fig.set_figwidth(width if width is not None else 4)
    fig.set_figheight(height if height is not None else 2.5)
    ax = fig.gca()

    if discrete:
        bins = [ i for i in range(maxx+1) ]
        hist=plt.hist(data, bins=bins, density=True)
    else:
        hist=plt.hist(data, density=True)
    plt.xlabel(xlabel)
    plt.ylabel('Density')
    plt.title(title)

    if discrete:
        poisson=stats.poisson(μ)
        x = [ i for i in range(maxx+1) ]
        y =[ poisson.pmf(i) for i in range(maxx+1) ]
        ax.plot(x, y, lw=1, color='red')
    else:
        x = np.linspace(minx, maxx, 100)
        y = [ stats.norm(loc=μ, scale=σ).pdf(p) for p in x]
        ax.plot(x, y, lw=1, color='red')
        
    ax.axvline(x=μ, color='red')
    maxy = max(max(y), max(hist[0]))
    ax.text(maxx, maxy, 
            f'μ={μ:2.2f}\nσ={σ:2.2f}', 
            ha='right', va='top', 
            color='red', fontsize=12)
    
    ax.grid(True)
    plt.show()

def dailyPlot(data, 
              title="", ylabel="",
              width=None, height=None):
    
    days = len(data)
    
    fig = plt.figure()
    fig.set_figwidth(width if width is not None else 6)
    fig.set_figheight(height if height is not None else 2)
    
    ax = fig.gca()
    diff = (max(data)-min(data))*0.1
    ymin = int(math.floor(min(data)-diff))
    ymax = int(math.ceil(max(data)+diff))
    ax.set_xlim(-0.5, days-1+0.5)
    ax.set_ylim(ymin, ymax)
    ax.grid(True)
    
    ms = 2 if len(data)>=100 else 3
    lw = 0.5 if len(data)>=100 else 1

    x = np.arange(0, len(data))
    y = np.array([ y for y in data ])
    b, m = np.polynomial.polynomial.polyfit(x, y, 1)
    
    plt.plot(x, y, 'bo-', linewidth=lw, markersize=ms)
    plt.plot(x, m*x+b, 'r-')
    
    plt.xlabel('Day')
    plt.ylabel(ylabel)
    plt.title(title)
    plt.show()

# %% [markdown]
# # Finding Shortest Path (as before)

# %%
def pathLength(P):
    return 0 if len(P)<=1 else \
            dist(P[0], P[1])+pathLength(P[1:])

# %%
def shortestPath(M, A, B):

    def h(p): 
        return pathLength(p)+dist(p[-1],B)
    
    # candidates C are pairs of the path so far and 
    # the heuristic function of that path, 
    # sorted by the heuristic function, as maintained by
    # insert function
    def insert(C, p):
        hp = h(p)
        c = (p, hp)
        for i in range(len(C)):
            if C[i][1]>hp:
                return C[:i]+[c]+C[i:]
        return C+[c]   
        
    V, E = M
    assert(A in V and B in V)    
    C = insert([], [A])

    while len(C)>0:
        # take the first candidate out of the list of candidates
        path, _ = C[0]
        C = C[1:]
        if path[-1]==B:
            return path
        else:
            for (x, y) in E:
                if path[-1]==x and y not in path:
                    C = insert(C, path+[y])
                elif path[-1]==y and x not in path:
                    C = insert(C, path+[x])
    return None

# %% [markdown]
# # Finding Short Delivery Route (as before)

# %% [markdown]
# ## Greedy Algorithm

# %%
def FW(M):
    
    V, E = M

    n = len(V)
    d = [ [ math.inf for j in range(n) ] for i in range(n) ]
    p = [ [ None for j in range(n) ] for i in range(n) ]

    for (A, B) in E:
        a = V.index(A)
        b = V.index(B)
        d[a][b] = d[b][a] = dist(A, B)
        p[a][b] = [A, B]
        p[b][a] = [B, A]
    
    for i in range(n):
        d[i][i] = 0
        p[i][i] = [V[i]]
    
    for k in range(n):
        for i in range(n):
            for j in range(n):
                dk = d[i][k] + d[k][j]
                if d[i][j] > dk:
                    d[i][j] = dk
                    p[i][j] = p[i][k][:-1] + p[k][j]
                    
    return d, p

# %%
def createLoopG(M, T, timing=False):
    
    def makeLoop(L, V, P):
        loop = []
        for i in range(len(L)-1):
            A = L[i]
            B = L[i+1]
            a = V.index(A)
            b = V.index(B)
            sub = P[a][b]
            loop += sub if len(loop)==0 else sub[1:]
        return loop
        
    if timing:
        start_time = time.time()
        last_time = time.time()
        
    V, E = M
    D, P = FW(M)   # note these are the distances between all vertices in M (and T)
    W = T[0]
    customers = T[1:]
    if len(T)==1:
        L = T
    elif len(T)<=3:
        L = T + [T[0]]
    else:
        L = T[:3]+[T[0]]
        T = T[3:]
        while len(T)>0:
            minExt = math.inf
            minInd = None
            selInd = None
            for k in range(len(T)):
                C = T[k]
                c = V.index(C)
                for i in range(0, len(L)-1):
                    A = L[i]
                    B = L[i+1]
                    a = V.index(A)
                    b = V.index(B)
                    ext = D[a][c] + D[c][b] - D[a][b]
                    if ext<minExt:
                        minExt, minInd, selInd = ext, i+1, k
            L = L[:minInd]+[T[selInd]]+L[minInd:]
            T = T[:selInd]+T[selInd+1:]
            
    if timing:
        print(f"createLoopG:    {time.time()-start_time:6.2f}s")

    return makeLoop(L, V, P)

# %% [markdown]
# # Finding Optimal Delivery Route

# %% [markdown]
# ## Iterative Integer Programming

# %%
def createTables(M, T):

    def reverse(P):
        return [ P[-i] for i in range(1,len(P)+1) ]
    
    def index(x, L):
        for i in range(len(L)):
            if x==L[i]: 
                return i
        return None

    n = len(T)
    d = [ [ math.inf for t in T ] for t in T ]
    p = [ [ None for t in T ] for t in T ]
    for i in range(n):
        d[i][i] = 0
        p[i][i] = [ T[i] ]
    for i in range(n):
        for j in range(n):
            if p[i][j] is None:
                s = shortestPath(M, T[i], T[j])
                d[i][j] = d[j][i] = pathLength(s)
                p[i][j] = s
                p[j][i] = reverse(s)
                for m in range(len(s)-1):
                    smi = index(s[m], T)
                    if smi is None:
                        continue
                    for l in range(m+1, len(s)):
                        sli = index(s[l], T)
                        if sli is None:
                            continue  
                        sub = s[m:l+1]
                        if p[smi][sli] is None:
                            p[smi][sli] = sub
                            p[sli][smi] = reverse(sub)
                            d[smi][sli] = d[sli][smi] = pathLength(sub)
    return d,p

# %%
def roundtrips(x, n):
    
    def isElem(x, l):
        for i in range(len(l)):
            if l[i]==x:
                return True
        return False

    def startpoint(trips):
        for i in range(n):
            for t in trips:
                if isElem(i, t):
                    break
            else:
                return i
    
    def totalLength(trips):
        s=0
        for i in range(0, len(trips)):
            s += len(trips[i])-1
        return s

    trips = []
    while totalLength(trips)<n:
        start = startpoint(trips)
        trip = [ start ]
        i = start
        while len(trip) < n-totalLength(trips):
            for j in range(0, n):
                if pulp.value(x[i][j])==1:
                    trip.append(j)
                    i=j
                    break        
            if pulp.value(x[trip[-1]][start])==1:
                trip.append(start)
                break
        trips.append(trip)
    return sorted(trips, key=lambda t: len(t), reverse=True)

# %%
import time

def createLoop(M, T, timing=False):
    
    if timing:
        start_time = last_time = time.time()
        
    D, P = createTables(M, T)   # These are the distances between customers and warehouse only
    
    if timing:
        print(f"createTables:   {time.time()-start_time:6.2f}s")
        last_time = time.time()
        
    n = len(T)
    # create variables
    x = pulp.LpVariable.dicts("x", ( range(n), range(n) ),
                            lowBound=0, upBound=1, cat=pulp.LpInteger)
    # create problem
    prob = pulp.LpProblem("Loop",pulp.LpMinimize)
    # add objective function
    prob += pulp.lpSum([ D[i][j]*x[i][j] 
                             for i in range(n) for j in range(n) ])
    # add constraints
    constraints=0
    for j in range(n):
        prob += pulp.lpSum([ x[i][j] for i in range(n) if i!=j ]) ==1
    constraints += n
    for i in range(n):
        prob += pulp.lpSum([ x[i][j] for j in range(n) if i!=j ]) ==1
    constraints += n
    for i in range(n):
        for j in range(n):
            if i!=j:
                prob += x[i][j]+x[j][i] <= 1
                constraints += 1
                
    def cycles(k, n):
        if k==1:
            return [ [i] for i in range(0,n) ]
        else:
            sc=cycles(k-1, n)
            all=[]
            for c in sc:
                for i in range(0,n):
                    if c.count(i)==0:
                        all.append(c+[i])
            return all

    for k in range(3, 4):   
        cycs=cycles(k,n)
        for c in cycs:
            c.append(c[0])
            prob+=pulp.lpSum([ x[c[i]][c[i+1]] for i in range(0,k)]) <= k-1
            constraints += 1    
            
    # initialise solver
    solvers = pulp.listSolvers(onlyAvailable=True)
    solver = pulp.getSolver(solvers[0], msg=0, timeLimit=2)
    res = prob.solve(solver)

    if timing:
        print(f"Solver:         {time.time()-last_time:6.2f}s {constraints:6,d} Constraints")
        last_time = time.time()
        
    trips = roundtrips(x, n)
    while len(trips)>1:
        longest = max([ len(t) for t in trips ])
        for t in trips:
            if len(t)<longest:
                prob += pulp.lpSum([ x[t[i]][t[i+1]] + x[t[i+1]][t[i]]
                                        for i in range(0,len(t)-1) ]) <= len(t)-2
                constraints += 1
            else:
                longest = math.inf
                
        res = prob.solve(solver)
        
        if timing:
            print(f"Solver:         {time.time()-last_time:6.2f}s {constraints:6,d} Constraints")
            last_time = time.time()

        trips = roundtrips(x, n)
    trip = trips[0]
    # print(trip)
    loop = []
    for k in range(len(trip)-1):
        sub = P[trip[k]][trip[k+1]]
        loop += sub if len(loop)==0 else sub[1:]
        
    if timing:
        print(f"createLoop:     {time.time()-start_time:6.2f}s")

    return loop

# %% [markdown]
# # Class Recorder

# %% [markdown]
# We willl use a class Recorder as a reference point for capturing data during the simulation. There will be only one recorder. It will be created at the beginning of every simulation run. Every entity will carry a reference to the Recorder.

# %%
import time

class Recorder:
    
    def __init__(self, env, M, W, C, D, days, 
                 log=False, plot=False, timing=False):
        self.env = env
        self.M = M
        self.W = W
        self.C = C
        self.D = D

        self.parcels = sum([ len(d) for d in D ])
        self.days = days
        self.log = log
        self.plot = plot

        # create a data frame for time records per working day
        self.daily = pd.DataFrame()
        self.daily['begin work at'] = [None]*days
        self.daily['end work at'] = [None]*days
        self.daily['tour length'] = [None]*days
        self.daily['parcels arrived'] = [0]*days
        self.daily['parcels out for delivery'] = [0]*days
        self.daily['parcels returned from delivery'] = [0]*days
        self.daily['parcels delivered'] = [0]*days
        self.daily['parcels left over'] = [None]*days

        
        self.parcel = pd.DataFrame()
        self.parcel['arrived at'] = [None]*self.parcels
        self.parcel['delivered at'] = [None]*self.parcels
     
    def trace(self, event):
        if self.log:
            print(timestamp(self.env.now), event)

    def recordDriverBeginsWork(self):
        self.trace("Driver arrives for work")
        self.daily.at[day(self.env.now), 'begin work at'] = int(round(self.env.now))
        
    def recordDriverEndsWork(self):
        self.trace("Driver goes home")
        self.daily.at[day(self.env.now), 'end work at'] = int(round(self.env.now))
        
    def recordTourLength(self, length):
        self.daily.at[day(self.env.now), 'tour length'] = int(length)

    def recordParcelArrived(self, parcel):
        today = day(self.env.now)
        self.daily.at[today, 'parcels arrived'] += 1
        self.parcel.at[parcel.i, 'arrived at'] = today

    def recordParcelOutForDelivery(self, parcel):
        self.daily.at[day(self.env.now), 'parcels out for delivery'] += 1
   
    def recordParcelReturnedFromDelivery(self, parcel):
        self.daily.at[day(self.env.now), 'parcels returned from delivery'] += 1

    def recordParcelDelivered(self, parcel):
        today = day(self.env.now)
        self.daily.at[today, 'parcels delivered'] += 1
        self.parcel.at[parcel.i, 'delivered at'] = today
        
    def recordParcelsLeftOver(self, n):
        self.trace(f"{n:d} parcels left over for next day")
        self.daily.at[day(self.env.now), 'parcels left over'] = n
        
    def finish(self):
        # simulation is finished for good
        # by removing the simulation environment we can
        # pickle recorder
        self.env = None
        self.daily['working time'] = (self.daily['end work at']-self.daily['begin work at'])//60
        self.daily['cost'] = self.daily['working time'].apply(lambda x: max(60, x*30/60))
        self.daily['cost'] += 0.08/1000*self.daily['tour length']
        self.parcel['delivery time'] = self.parcel['delivered at']-self.parcel['arrived at']

    def histWorkingTime(self):
        histPlot(self.daily['working time'],
                 xlabel='Working Time [min]',
                 title=f'Daily Working Time ({self.days:d} days)')
        
    def plotWorkingTime(self):
        dailyPlot(self.daily['working time'],
                  ylabel='Working Time [min]',
                  title=f'Daily Working Time ({self.days:d} days)')

    def histTourLength(self):
        histPlot(self.daily['tour length'],
                 xlabel='Tour Length [m]',
                 title=f'Daily Tour Length ({self.days:d} days)')
            
    def plotTourLength(self):
        dailyPlot(self.daily['tour length'],
                  ylabel='Tour Length [m]',
                  title=f'Daily Tour Length ({self.days:d} days)')

    def histDailyCost(self):
        histPlot(self.daily['cost'],
                 xlabel='DailyCost [€]',
                 title=f'Daily Cost ({self.days:d} days)')
            
    def plotDailyCost(self):
        dailyPlot(self.daily['cost'],
                  ylabel='Daily Cost [€]',
                  title=f'Daily Cost ({self.days:d} days)')

    def histParcelsArrived(self):
        histPlot(self.daily['parcels arrived'], discrete=True,
                 xlabel='Parcels Arrived',
                 title=f'Parcels Arrived Daily ({self.days:d} Days)')
                
    def plotParcelsArrived(self):
        dailyPlot(self.daily['parcels arrived'],
                  ylabel='Number of Parcels',
                  title=f'Parcels Arrived Daily ({self.days:d} Days)')

    def histParcelsOutForDelivery(self):
        histPlot(self.daily['parcels out for delivery'], discrete=True,
                 xlabel='Parcels Arrived',
                 title=f'Parcels Daily out for Delivery ({self.days:d} Days)')
                
    def plotParcelsOutForDelivery(self):
        dailyPlot(self.daily['parcels out for delivery'],
                  ylabel='Number of Parcels',
                  title=f'Parcels Daily out for Delivery ({self.days:d} Days)')
        
    def histParcelsReturnedFromDelivery(self):
        histPlot(self.daily['parcels returned from delivery'], discrete=True,
                 xlabel='Parcels Arrived',
                 title=f'Parcels Daily Returned From Delivery ({self.days:d} Days)')
                
    def plotParcelsReturnedFromDelivery(self):
        dailyPlot(self.daily['parcels returned from delivery'],
                  ylabel='Number of Parcels',
                  title=f'Parcels Daily Returned From Delivery ({self.days:d} Days)')

    def histParcelsDelivered(self):
        histPlot(self.daily['parcels delivered'], discrete=True,
                 xlabel='Left-Over Parcels',
                 title=f'Parcels Delivered Daily ({self.days:d} Days)')

    def plotParcelsDelivered(self):
        dailyPlot(self.daily['parcels delivered'],
                  ylabel='Number of Parcels',
                  title=f'Parcels Delivered Daily ({self.days:d} Days)')

    def histParcelsLeftOver(self):
        histPlot(self.daily['parcels left over'], discrete=True,
                 xlabel='Left-Over Parcels',
                 title=f'Parcels Daily Left-Overs ({self.days:d} Days)')
                
    def plotParcelsLeftOver(self):
        dailyPlot(self.daily['parcels left over'],
                  ylabel='Number of Parcels',
                  title=f'Parcels Daily Left-Overs ({self.days:d} Days)')

    def histParcelDeliveryTime(self):
        histPlot(self.parcel['delivery time'], discrete=True,
                 xlabel='Days',
                 title=f'Parcel Delivery Delay in Days ({self.parcels:3,d} Parcels)')

# %% [markdown]
# # Class Customer

# %% [markdown]
# <img src='img/EventGraph Customer.png' width=500/>

# %%
class Customer:
    
    def __init__(self, rec, id, location):
        self.rec = rec
        self.id = id
        self.location = location
        self.atHome = True
        self.answersDoor = False
        self.parcelsReceived = []
        rec.env.process(self.process())
        
    def __str__(self):
        return f"Customer {self.id:d} at {str(self.location):s}"
    
    def leaveHouse(self):
        assert(self.atHome and not self.answersDoor)
        # self.rec.trace(str(self)+" leaves house")
        self.atHome = False
     
    def returnHome(self):
        assert(not self.atHome)
        # self.rec.trace(str(self)+" returns home")
        self.atHome = True
        
    def answerDoor(self):
        if self.atHome:
            answerTime = random.expovariate(1/AVERAGE_TIME_ANSWER_DOOR)
            if answerTime < WAIT_TIME_IF_CUSTOMER_DOESNT_ANSWER_DOOR:                            
                yield self.rec.env.timeout(answerTime)
                self.rec.trace(str(self)+" answers door")
                self.answersDoor = True
            else:
                yield self.rec.env.timeout(WAIT_TIME_IF_CUSTOMER_DOESNT_ANSWER_DOOR)
                self.rec.trace(str(self)+" to slow to answer the door")
                self.answersDoor = False
        else:
            yield self.rec.env.timeout(WAIT_TIME_IF_CUSTOMER_DOESNT_ANSWER_DOOR)
            self.rec.trace(str(self)+" not at home")
            self.answersDoot = False
            
    def acceptParcel(self, parcel):
        assert(self.answersDoor)
        self.parcelsReceived += [parcel]
        self.rec.trace(str(self)+" accepts "+str(parcel))
        self.rec.recordParcelDelivered(parcel)
        
    def signOff(self):
        assert(self.answersDoor)
        self.rec.trace(str(self)+" signs off")
        self.answersDoor = False
        
    def process(self):
        yield self.rec.env.timeout(nextHour(self.rec.env, 8))
        while day(self.rec.env.now)<self.rec.days:
            # in a refinement we may use random times
            self.leaveHouse()
            returnTime = 22 if random.random()<CUSTOMER_NOT_AT_HOME else 18
            yield self.rec.env.timeout(nextHour(self.rec.env, returnTime))
            self.returnHome()
            yield self.rec.env.timeout(nextHour(self.rec.env, 8))

# %% [markdown]
# # Class Parcel

# %% [markdown]
# <img src='img/EventGraph Parcel.png' width=500/>

# %% [markdown]
# Parcels follow through a sequence of states:
# - processing
# - in transit (from manufacture to distribution centre)
# - arrived in distribution centre
# - ready for delivery
# - out for delivery
# - customer not present
# - returned to distribution centre
# - delivered

# %%
class Parcel:
    
    def __init__(self, rec, i, day, cust):
        self.rec = rec
        self.i = i  
        self.arrival = day
        self.cust = cust
        self.status = [  ] # status record and
        self.timing = [  ] # timing

    def __str__(self):
        return f"Parcel {self.i:d} for cust {self.cust.id:d}"

    def index(self):
        return self.i
    
    def destination(self):
        return self.cust.location
    
    def __reg(self, state):
        self.status += [ state ]
        self.timing += [ self.rec.env.now ]
        self.rec.trace(str(self)+" "+state)
        
    def arrivedAtDeliveryCentre(self):
        self.__reg('arr at delivery centre')
        self.rec.recordParcelArrived(self)
        
    def outForDelivery(self): 
        self.__reg('out for delivery')
        self.rec.recordParcelOutForDelivery(self)
        
    def returnFromDelivery(self):
        self.__reg('return from delivery')
        self.rec.recordParcelReturnedFromDelivery(self)

# %% [markdown]
# # Class Driver

# %% [markdown]
# <img src='img/EventGraph Driver.png' width=500/>

# %%
class Driver:
    
    def __init__(self, rec, DC):
        self.rec = rec
        self.DC = DC
        self.location = None
        self.parcels = None
        self.tour = None
        self.rec.env.process(self.process())
        
    # activity
    def __drive(self, target):
        assert(self.tour[0] == self.location)
        while self.location!=target:
            d = dist(self.location, self.tour[1])
            yield self.rec.env.timeout(d / AVERAGE_SPEED)
            self.location = self.tour[1]
            self.tour = self.tour[1:]
        assert(self.tour[0] == self.location == target)
    
    def arriveForWork(self):
        self.location = self.DC.W
        self.parcels = []
        self.returns = []
        self.tour = [ self.DC.W ]
        # self.rec.trace("Driver arrives for work")
        self.rec.recordDriverBeginsWork()
    
    def goesHome(self):
        self.location = None
        self.parcels = None
        self.returns = None
        self.tour = None
        # self.rec.trace("Driver goes home")
        self.rec.recordDriverEndsWork()
        
    def leaveForDelivery(self, tour, parcels, addresses):
        self.tour, self.parcels = tour, parcels
        self.rec.trace(f"Driver leaves for delivery " 
                       f"of {len(parcels):d} parcels "
                       f"to {len(addresses):d} customers")
        self.rec.trace(f"Length of delivery tour: {pathLength(tour):,d}m")
        if self.rec.plot:
            plotMap(self.rec.M, T=addresses, P=tour, w=tour[0], 
                    text=f"Day {day(self.rec.env.now):d}:, {pathLength(tour):,d}m")
        
    def process(self):
        yield self.rec.env.timeout(nextHour(self.rec.env, 18))
        while day(self.rec.env.now)<self.rec.days:
            self.arriveForWork()
            tour, parcels, addresses = self.DC.sendForDelivery()
            if len(parcels)==0: 
                self.rec.trace("Nothing to do today")
                self.rec.recordTourLength(0)
            else:
                yield self.rec.env.timeout(PREP_TIME_PER_PARCEL*len(parcels))
                self.rec.recordTourLength(pathLength(tour))
                self.leaveForDelivery(tour, parcels, addresses)        
                while len(self.parcels)>0:
                    # drive to customer
                    custLocation = self.parcels[0].destination()
                    cust = self.parcels[0].cust
                    self.rec.trace("Driver drives to "+str(cust))
                    yield from self.__drive(custLocation)
                    self.rec.trace("Driver arrived at "+str(cust))
                    # call at customer
                    yield from cust.answerDoor()
                    
                    if cust.answersDoor:
                        while len(self.parcels)>0 and \
                                custLocation == self.parcels[0].destination():
                            cust.acceptParcel(self.parcels[0])
                            yield self.rec.env.timeout(random.expovariate(1/10))
                            self.parcels = self.parcels[1:]
                        cust.signOff()
                        yield self.rec.env.timeout(random.expovariate(1/10))
                    else:
                        while len(self.parcels)>0 and  \
                                custLocation == self.parcels[0].destination():
                            self.returns += [self.parcels[0]]
                            self.parcels = self.parcels[1:]

                # return to delivery centre
                self.rec.trace("Driver returns to delivery centre")
                yield from self.__drive(self.DC.W)
                self.rec.trace("Driver arrived at delivery centre")
            
                for parcel in self.returns:
                    self.DC.returnFromDelivery(parcel)
                    yield self.rec.env.timeout(RETURN_TIME_PER_PARCEL)
                            
            self.rec.recordParcelsLeftOver(len(self.DC.parcels)+len(self.DC.leftOver))
            
            yield self.rec.env.timeout(600)

            self.goesHome()
            
            yield self.rec.env.timeout(nextHour(self.rec.env, 18))

# %% [markdown]
# # Class Delivery Centre

# %% [markdown]
# <img src="img/EventGraph Delivery Centre.png" width=300/>

# %%
class DeliveryCentre:
    
    def __init__(self, rec, M, W, limit):
        self.rec = rec
        self.M = M
        self.W = W
        self.limit = limit
        
        self.leftOver = []    # list of parcels
        self.parcels = []     # list of parcels scheduled for delivery
        self.dest = []        # list of unique customer destinations
        self.tour = [self.W]  # tour planned for delivery
    
    def __accept(self, parcel):
        custLoc = parcel.destination()
        if custLoc not in self.dest:
            MT = addTargets(self.M, self.dest + [custLoc])
            SH = createLoopG(MT, [self.W] + self.dest + [custLoc])
            if pathLength(SH)<self.limit:
                self.parcels.append(parcel)
                self.dest += [custLoc]
                self.tour = SH
            else: 
                self.leftOver.append(parcel)
        else:
            self.parcels.append(parcel)
        
    def acceptParcel(self, parcel):
        parcel.arrivedAtDeliveryCentre()
        self.__accept(parcel)
            
    def sendForDelivery(self):
        parcels = []
        tour = self.tour
        addresses = []
        
        # pick parcels in sequence to be delivered
        for i in range(1, len(tour)-1):
            dest = tour[i]
            for p in self.parcels:
                if p.destination() == dest and p not in parcels:
                    parcels += [p]
                    p.outForDelivery()
                    if dest not in addresses:
                        addresses += [dest]
         
        # arrange the left overs for next day
        L = self.leftOver
        self.tour = [self.W]
        self.parcels = []
        self.leftOver = []
        self.dest = []
        for p in L:
            self.__accept(p)

        return tour, parcels, addresses
                 
    def returnFromDelivery(self, parcel):
        parcel.returnFromDelivery()
        self.__accept(parcel)

    def getInventory(self):
        return len(self.parcels)+len(self.leftOver)

# %% [markdown]
# # Simulation

# %% [markdown]
# ## Parameters from Specification

# %% [markdown]
# The proportion of customers that for whatever are not at home or return home late

# %%
CUSTOMER_NOT_AT_HOME = 0.1  # 10%

# %% [markdown]
# The maximum bike range. This is passed as parameter to the Delivery Centre
# and taken into account for the daily tour planning

# %%
BIKE_RANGE = 40000

# %% [markdown]
# The time required for driving is based on the distance between way points at an average speed of 15km/h.

# %%
AVERAGE_SPEED = 15/3.6

# %% [markdown]
# The **cumulative preparation time** (route planning and
# sorting of the parcels in the delivery order and
# packing the cargo-bike) is assumed to be 50 sec per
# parcel to be delivered.

# %%
PREP_TIME_PER_PARCEL = 50

# %% [markdown]
# **Additional assumption:** The time to **process returned parcels** in the delivery centre is 30 sec per parce.

# %%
RETURN_TIME_PER_PARCEL = 30

# %% [markdown]
# The average time to answer the door.

# %%
AVERAGE_TIME_ANSWER_DOOR = 40

# %%
WAIT_TIME_IF_CUSTOMER_DOESNT_ANSWER_DOOR = 60

# %% [markdown]
# ## Generate Input Data

# %%
def generateDeliveries(p, C, days, seed=0):
    ## p is the average number of parcels per day per customer
    ## C is the number of customers to be served
    ## days is the number of days for which data are to be generated.
    random.seed(seed)
    deliveries = [ [ ] for _ in range(days) ]
    for c in range(C):
        arr = 0
        while True:
            arr += random.expovariate(p)
            day = int(arr)
            if day>=days:
                break
            deliveries[day].append(c)
    return deliveries

# %% [markdown]
# ## Simulation Routine

# %%
def simulation(M, W, C, p=0.2, days=10, seed=0, 
               log=False, plot=False, timing=False):

    random.seed(seed)
    D = generateDeliveries(p, len(C), days, seed)
    
    env = simpy.Environment()
    rec = Recorder(env, M, W, C, D, days, 
                   log=log, plot=plot, timing=timing)

    print(f"Simulating delivery of {sum([len(d) for d in D]):d} parcels "
          f"over {len(D):d} days to {len(C):d} customers")

    CUSTOMERS = []
    for i in range(len(C)):
        CUSTOMERS.append(Customer(rec, i, C[i]))

    DC = DeliveryCentre(rec, M, W, BIKE_RANGE)
    Z = Driver(rec, DC)
    PARCELS = []

    def parcelGeneratorProcess(env, rec, D, C):
        for day in range(len(D)):
            yield env.timeout(nextHour(env, 17.00))
            for c in D[day]:
                cust = CUSTOMERS[c]
                parcel = Parcel(rec, len(PARCELS), day, cust)
                PARCELS.append(parcel)
                DC.acceptParcel(parcel)

    env.process(parcelGeneratorProcess(env, rec, D, C))
    env.run()

    rec.finish()

    if DC.getInventory()>0:
        print(f"Delivery Centre Inventory: {DC.getInventory():d} parcels")

    return rec

# %% [markdown]
# ## Test Statistics

# %% [markdown]
# ### Using Simple Data

# %%
import pickle
with open('simpleData.pickled', 'rb') as f:
    M, C = pickle.load(f)

# %%
W = generateWarehouseLocation(M)

# %%
plotMap(M, T=C, w=W, scale=True)

# %%
rec1 = simulation(M, W, C, p=0.15, days=4, log=True)
# Out:
# Simulating delivery of 48 parcels over 4 days to 100 customers
# [ 0] 17:00:00.0 Parcel 0 for cust 19 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 1 for cust 27 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 2 for cust 30 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 3 for cust 40 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 4 for cust 54 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 5 for cust 72 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 6 for cust 77 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 7 for cust 79 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 8 for cust 80 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 9 for cust 84 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 10 for cust 89 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 11 for cust 89 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 12 for cust 92 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 13 for cust 96 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 14 for cust 96 arr at delivery centre
# [ 0] 18:00:00.0 Driver arrives for work
# [ 0] 18:00:00.0 Parcel 3 for cust 40 out for delivery
# [ 0] 18:00:00.0 Parcel 4 for cust 54 out for delivery
# [ 0] 18:00:00.0 Parcel 9 for cust 84 out for delivery
# [ 0] 18:00:00.0 Parcel 10 for cust 89 out for delivery
# [ 0] 18:00:00.0 Parcel 11 for cust 89 out for delivery
# [ 0] 18:00:00.0 Parcel 2 for cust 30 out for delivery
# [ 0] 18:00:00.0 Parcel 0 for cust 19 out for delivery
# [ 0] 18:00:00.0 Parcel 1 for cust 27 out for delivery
# [ 0] 18:06:40.0 Driver leaves for delivery of 8 parcels to 7 customers
# [ 0] 18:06:40.0 Length of delivery tour: 36,414m
# [ 0] 18:06:40.0 Driver drives to Customer 40 at (4500, 5107)
# [ 0] 18:09:05.7 Driver arrived at Customer 40 at (4500, 5107)
# [ 0] 18:09:06.4 Customer 40 at (4500, 5107) answers door
# [ 0] 18:09:06.4 Customer 40 at (4500, 5107) accepts Parcel 3 for cust 40
# [ 0] 18:09:06.8 Customer 40 at (4500, 5107) signs off
# [ 0] 18:09:18.3 Driver drives to Customer 54 at (5416, 5560)
# [ 0] 18:14:46.8 Driver arrived at Customer 54 at (5416, 5560)
# [ 0] 18:15:19.5 Customer 54 at (5416, 5560) answers door
# [ 0] 18:15:19.5 Customer 54 at (5416, 5560) accepts Parcel 4 for cust 54
# [ 0] 18:15:48.8 Customer 54 at (5416, 5560) signs off
# [ 0] 18:16:16.7 Driver drives to Customer 84 at (6620, 6812)
# [ 0] 18:26:06.1 Driver arrived at Customer 84 at (6620, 6812)
# [ 0] 18:27:06.1 Customer 84 at (6620, 6812) to slow to answer the door
# [ 0] 18:27:06.1 Driver drives to Customer 89 at (6620, 8231)
# [ 0] 18:32:46.7 Driver arrived at Customer 89 at (6620, 8231)
# [ 0] 18:33:46.7 Customer 89 at (6620, 8231) not at home
# [ 0] 18:33:46.7 Driver drives to Customer 30 at (3068, 6620)
# [ 0] 19:00:25.6 Driver arrived at Customer 30 at (3068, 6620)
# [ 0] 19:00:27.3 Customer 30 at (3068, 6620) answers door
# [ 0] 19:00:27.3 Customer 30 at (3068, 6620) accepts Parcel 2 for cust 30
# [ 0] 19:00:41.1 Customer 30 at (3068, 6620) signs off
# [ 0] 19:00:53.2 Driver drives to Customer 19 at (1677, 960)
# [ 0] 19:37:06.1 Driver arrived at Customer 19 at (1677, 960)
# [ 0] 19:37:48.8 Customer 19 at (1677, 960) answers door
# [ 0] 19:37:48.8 Customer 19 at (1677, 960) accepts Parcel 0 for cust 19
# [ 0] 19:38:01.2 Customer 19 at (1677, 960) signs off
# [ 0] 19:38:24.5 Driver drives to Customer 27 at (2819, 260)
# [ 0] 19:44:08.0 Driver arrived at Customer 27 at (2819, 260)
# [ 0] 19:44:48.8 Customer 27 at (2819, 260) answers door
# [ 0] 19:44:48.8 Customer 27 at (2819, 260) accepts Parcel 1 for cust 27
# [ 0] 19:44:53.5 Customer 27 at (2819, 260) signs off
# [ 0] 19:45:01.2 Driver returns to delivery centre
# [ 0] 20:38:41.1 Driver arrived at delivery centre
# [ 0] 20:38:41.1 Parcel 9 for cust 84 return from delivery
# [ 0] 20:39:11.1 Parcel 10 for cust 89 return from delivery
# [ 0] 20:39:41.1 Parcel 11 for cust 89 return from delivery
# [ 0] 20:40:11.1 10 parcels left over for next day
# [ 0] 20:50:11.1 Driver goes home
# [ 1] 17:00:00.0 Parcel 15 for cust 11 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 16 for cust 32 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 17 for cust 34 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 18 for cust 35 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 19 for cust 76 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 20 for cust 79 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 21 for cust 90 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 22 for cust 97 arr at delivery centre
# [ 1] 18:00:00.0 Driver arrives for work
# [ 1] 18:00:00.0 Parcel 15 for cust 11 out for delivery
# [ 1] 18:00:00.0 Parcel 16 for cust 32 out for delivery
# [ 1] 18:00:00.0 Parcel 5 for cust 72 out for delivery
# [ 1] 18:00:00.0 Parcel 6 for cust 77 out for delivery
# [ 1] 18:00:00.0 Parcel 7 for cust 79 out for delivery
# [ 1] 18:00:00.0 Parcel 20 for cust 79 out for delivery
# [ 1] 18:00:00.0 Parcel 8 for cust 80 out for delivery
# [ 1] 18:00:00.0 Parcel 19 for cust 76 out for delivery
# [ 1] 18:06:40.0 Driver leaves for delivery of 8 parcels to 7 customers
# [ 1] 18:06:40.0 Length of delivery tour: 39,720m
# [ 1] 18:06:40.0 Driver drives to Customer 11 at (703, 2996)
# [ 1] 18:44:51.0 Driver arrived at Customer 11 at (703, 2996)
# [ 1] 18:45:51.0 Customer 11 at (703, 2996) to slow to answer the door
# [ 1] 18:45:51.0 Driver drives to Customer 32 at (3248, 260)
# [ 1] 19:03:02.6 Driver arrived at Customer 32 at (3248, 260)
# [ 1] 19:03:37.5 Customer 32 at (3248, 260) answers door
# [ 1] 19:03:37.5 Customer 32 at (3248, 260) accepts Parcel 16 for cust 32
# [ 1] 19:03:50.2 Customer 32 at (3248, 260) signs off
# [ 1] 19:04:06.7 Driver drives to Customer 72 at (6424, 2380)
# [ 1] 19:25:17.7 Driver arrived at Customer 72 at (6424, 2380)
# [ 1] 19:25:20.4 Customer 72 at (6424, 2380) answers door
# [ 1] 19:25:20.4 Customer 72 at (6424, 2380) accepts Parcel 5 for cust 72
# [ 1] 19:25:21.3 Customer 72 at (6424, 2380) signs off
# [ 1] 19:25:41.6 Driver drives to Customer 77 at (6620, 2458)
# [ 1] 19:26:47.4 Driver arrived at Customer 77 at (6620, 2458)
# [ 1] 19:26:49.0 Customer 77 at (6620, 2458) answers door
# [ 1] 19:26:49.0 Customer 77 at (6620, 2458) accepts Parcel 6 for cust 77
# [ 1] 19:26:51.6 Customer 77 at (6620, 2458) signs off
# [ 1] 19:26:52.0 Driver drives to Customer 79 at (6620, 2787)
# [ 1] 19:28:10.9 Driver arrived at Customer 79 at (6620, 2787)
# [ 1] 19:28:11.6 Customer 79 at (6620, 2787) answers door
# [ 1] 19:28:11.6 Customer 79 at (6620, 2787) accepts Parcel 7 for cust 79
# [ 1] 19:28:30.1 Customer 79 at (6620, 2787) accepts Parcel 20 for cust 79
# [ 1] 19:28:34.1 Customer 79 at (6620, 2787) signs off
# [ 1] 19:28:35.9 Driver drives to Customer 80 at (6620, 2904)
# [ 1] 19:29:04.0 Driver arrived at Customer 80 at (6620, 2904)
# [ 1] 19:29:10.4 Customer 80 at (6620, 2904) answers door
# [ 1] 19:29:10.4 Customer 80 at (6620, 2904) accepts Parcel 8 for cust 80
# [ 1] 19:29:21.1 Customer 80 at (6620, 2904) signs off
# [ 1] 19:29:55.7 Driver drives to Customer 76 at (6620, 2144)
# [ 1] 19:32:58.1 Driver arrived at Customer 76 at (6620, 2144)
# [ 1] 19:33:26.2 Customer 76 at (6620, 2144) answers door
# [ 1] 19:33:26.2 Customer 76 at (6620, 2144) accepts Parcel 19 for cust 76
# [ 1] 19:33:49.4 Customer 76 at (6620, 2144) signs off
# [ 1] 19:33:56.3 Driver returns to delivery centre
# [ 1] 20:50:20.3 Driver arrived at delivery centre
# [ 1] 20:50:20.3 Parcel 15 for cust 11 return from delivery
# [ 1] 20:50:50.3 11 parcels left over for next day
# [ 1] 21:00:50.3 Driver goes home
# [ 2] 17:00:00.0 Parcel 23 for cust 5 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 24 for cust 9 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 25 for cust 15 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 26 for cust 25 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 27 for cust 38 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 28 for cust 50 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 29 for cust 62 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 30 for cust 77 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 31 for cust 78 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 32 for cust 90 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 33 for cust 93 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 34 for cust 94 arr at delivery centre
# [ 2] 18:00:00.0 Driver arrives for work
# [ 2] 18:00:00.0 Parcel 27 for cust 38 out for delivery
# [ 2] 18:00:00.0 Parcel 26 for cust 25 out for delivery
# [ 2] 18:00:00.0 Parcel 25 for cust 15 out for delivery
# [ 2] 18:00:00.0 Parcel 24 for cust 9 out for delivery
# [ 2] 18:00:00.0 Parcel 23 for cust 5 out for delivery
# [ 2] 18:00:00.0 Parcel 15 for cust 11 out for delivery
# [ 2] 18:00:00.0 Parcel 21 for cust 90 out for delivery
# [ 2] 18:00:00.0 Parcel 32 for cust 90 out for delivery
# [ 2] 18:00:00.0 Parcel 12 for cust 92 out for delivery
# [ 2] 18:07:30.0 Driver leaves for delivery of 9 parcels to 8 customers
# [ 2] 18:07:30.0 Length of delivery tour: 39,628m
# [ 2] 18:07:30.0 Driver drives to Customer 38 at (4500, 4765)
# [ 2] 18:08:33.6 Driver arrived at Customer 38 at (4500, 4765)
# [ 2] 18:09:33.6 Customer 38 at (4500, 4765) to slow to answer the door
# [ 2] 18:09:33.6 Driver drives to Customer 25 at (2380, 5939)
# [ 2] 18:25:42.0 Driver arrived at Customer 25 at (2380, 5939)
# [ 2] 18:26:42.0 Customer 25 at (2380, 5939) not at home
# [ 2] 18:26:42.0 Driver drives to Customer 15 at (1320, 7071)
# [ 2] 18:35:28.1 Driver arrived at Customer 15 at (1320, 7071)
# [ 2] 18:36:28.1 Customer 15 at (1320, 7071) to slow to answer the door
# [ 2] 18:36:28.1 Driver drives to Customer 9 at (260, 6204)
# [ 2] 18:44:10.6 Driver arrived at Customer 9 at (260, 6204)
# [ 2] 18:44:32.0 Customer 9 at (260, 6204) answers door
# [ 2] 18:44:32.0 Customer 9 at (260, 6204) accepts Parcel 24 for cust 9
# [ 2] 18:44:33.1 Customer 9 at (260, 6204) signs off
# [ 2] 18:44:48.0 Driver drives to Customer 5 at (260, 5135)
# [ 2] 18:49:04.5 Driver arrived at Customer 5 at (260, 5135)
# [ 2] 18:49:57.5 Customer 5 at (260, 5135) answers door
# [ 2] 18:49:57.5 Customer 5 at (260, 5135) accepts Parcel 23 for cust 5
# [ 2] 18:49:57.8 Customer 5 at (260, 5135) signs off
# [ 2] 18:50:03.8 Driver drives to Customer 11 at (703, 2996)
# [ 2] 18:59:21.0 Driver arrived at Customer 11 at (703, 2996)
# [ 2] 19:00:07.4 Customer 11 at (703, 2996) answers door
# [ 2] 19:00:07.4 Customer 11 at (703, 2996) accepts Parcel 15 for cust 11
# [ 2] 19:00:07.7 Customer 11 at (703, 2996) signs off
# [ 2] 19:00:32.9 Driver drives to Customer 90 at (6864, 1320)
# [ 2] 19:36:26.7 Driver arrived at Customer 90 at (6864, 1320)
# [ 2] 19:37:26.7 Customer 90 at (6864, 1320) to slow to answer the door
# [ 2] 19:37:26.7 Driver drives to Customer 92 at (7026, 1320)
# [ 2] 19:38:05.5 Driver arrived at Customer 92 at (7026, 1320)
# [ 2] 19:38:56.8 Customer 92 at (7026, 1320) answers door
# [ 2] 19:38:56.8 Customer 92 at (7026, 1320) accepts Parcel 12 for cust 92
# [ 2] 19:38:57.6 Customer 92 at (7026, 1320) signs off
# [ 2] 19:38:58.4 Driver returns to delivery centre
# [ 2] 20:53:42.1 Driver arrived at delivery centre
# [ 2] 20:53:42.1 Parcel 27 for cust 38 return from delivery
# [ 2] 20:54:12.1 Parcel 26 for cust 25 return from delivery
# [ 2] 20:54:42.1 Parcel 25 for cust 15 return from delivery
# [ 2] 20:55:12.1 Parcel 21 for cust 90 return from delivery
# [ 2] 20:55:42.1 Parcel 32 for cust 90 return from delivery
# [ 2] 20:56:12.1 19 parcels left over for next day
# [ 2] 21:06:12.1 Driver goes home
# [ 3] 17:00:00.0 Parcel 35 for cust 2 arr at delivery centre
# [ 3] 17:00:00.0 Parcel 36 for cust 4 arr at delivery centre
# [ 3] 17:00:00.0 Parcel 37 for cust 28 arr at delivery centre
# [ 3] 17:00:00.0 Parcel 38 for cust 37 arr at delivery centre
# [ 3] 17:00:00.0 Parcel 39 for cust 48 arr at delivery centre
# [ 3] 17:00:00.0 Parcel 40 for cust 49 arr at delivery centre
# [ 3] 17:00:00.0 Parcel 41 for cust 50 arr at delivery centre
# [ 3] 17:00:00.0 Parcel 42 for cust 61 arr at delivery centre
# [ 3] 17:00:00.0 Parcel 43 for cust 68 arr at delivery centre
# [ 3] 17:00:00.0 Parcel 44 for cust 87 arr at delivery centre
# [ 3] 17:00:00.0 Parcel 45 for cust 90 arr at delivery centre
# [ 3] 17:00:00.0 Parcel 46 for cust 92 arr at delivery centre
# [ 3] 17:00:00.0 Parcel 47 for cust 93 arr at delivery centre
# [ 3] 18:00:00.0 Driver arrives for work
# [ 3] 18:00:00.0 Parcel 27 for cust 38 out for delivery
# [ 3] 18:00:00.0 Parcel 37 for cust 28 out for delivery
# [ 3] 18:00:00.0 Parcel 36 for cust 4 out for delivery
# [ 3] 18:00:00.0 Parcel 35 for cust 2 out for delivery
# [ 3] 18:00:00.0 Parcel 25 for cust 15 out for delivery
# [ 3] 18:00:00.0 Parcel 26 for cust 25 out for delivery
# [ 3] 18:00:00.0 Parcel 34 for cust 94 out for delivery
# [ 3] 18:00:00.0 Parcel 22 for cust 97 out for delivery
# [ 3] 18:00:00.0 Parcel 9 for cust 84 out for delivery
# [ 3] 18:00:00.0 Parcel 44 for cust 87 out for delivery
# [ 3] 18:00:00.0 Parcel 10 for cust 89 out for delivery
# [ 3] 18:00:00.0 Parcel 11 for cust 89 out for delivery
# [ 3] 18:00:00.0 Parcel 28 for cust 50 out for delivery
# [ 3] 18:00:00.0 Parcel 41 for cust 50 out for delivery
# [ 3] 18:00:00.0 Parcel 40 for cust 49 out for delivery
# [ 3] 18:00:00.0 Parcel 39 for cust 48 out for delivery
# [ 3] 18:13:20.0 Driver leaves for delivery of 16 parcels to 14 customers
# [ 3] 18:13:20.0 Length of delivery tour: 35,110m
# [ 3] 18:13:20.0 Driver drives to Customer 38 at (4500, 4765)
# [ 3] 18:14:23.6 Driver arrived at Customer 38 at (4500, 4765)
# [ 3] 18:15:23.6 Customer 38 at (4500, 4765) to slow to answer the door
# [ 3] 18:15:23.6 Driver drives to Customer 28 at (2879, 6620)
# [ 3] 18:26:48.8 Driver arrived at Customer 28 at (2879, 6620)
# [ 3] 18:26:54.0 Customer 28 at (2879, 6620) answers door
# [ 3] 18:26:54.0 Customer 28 at (2879, 6620) accepts Parcel 37 for cust 28
# [ 3] 18:27:15.5 Customer 28 at (2879, 6620) signs off
# [ 3] 18:27:15.9 Driver drives to Customer 4 at (260, 4991)
# [ 3] 18:44:15.4 Driver arrived at Customer 4 at (260, 4991)
# [ 3] 18:44:27.3 Customer 4 at (260, 4991) answers door
# [ 3] 18:44:27.3 Customer 4 at (260, 4991) accepts Parcel 36 for cust 4
# [ 3] 18:44:34.7 Customer 4 at (260, 4991) signs off
# [ 3] 18:44:43.4 Driver drives to Customer 2 at (260, 4756)
# [ 3] 18:45:39.8 Driver arrived at Customer 2 at (260, 4756)
# [ 3] 18:46:00.0 Customer 2 at (260, 4756) answers door
# [ 3] 18:46:00.0 Customer 2 at (260, 4756) accepts Parcel 35 for cust 2
# [ 3] 18:46:01.1 Customer 2 at (260, 4756) signs off
# [ 3] 18:46:04.0 Driver drives to Customer 15 at (1320, 7071)
# [ 3] 18:59:34.0 Driver arrived at Customer 15 at (1320, 7071)
# [ 3] 18:59:47.3 Customer 15 at (1320, 7071) answers door
# [ 3] 18:59:47.3 Customer 15 at (1320, 7071) accepts Parcel 25 for cust 15
# [ 3] 19:00:01.4 Customer 15 at (1320, 7071) signs off
# [ 3] 19:00:25.4 Driver drives to Customer 25 at (2380, 5939)
# [ 3] 19:09:11.4 Driver arrived at Customer 25 at (2380, 5939)
# [ 3] 19:09:47.6 Customer 25 at (2380, 5939) answers door
# [ 3] 19:09:47.6 Customer 25 at (2380, 5939) accepts Parcel 26 for cust 25
# [ 3] 19:09:48.0 Customer 25 at (2380, 5939) signs off
# [ 3] 19:10:03.7 Driver drives to Customer 94 at (7439, 5560)
# [ 3] 19:34:46.7 Driver arrived at Customer 94 at (7439, 5560)
# [ 3] 19:35:01.3 Customer 94 at (7439, 5560) answers door
# [ 3] 19:35:01.3 Customer 94 at (7439, 5560) accepts Parcel 34 for cust 94
# [ 3] 19:35:05.4 Customer 94 at (7439, 5560) signs off
# [ 3] 19:35:13.0 Driver drives to Customer 97 at (8209, 6089)
# [ 3] 19:39:10.3 Driver arrived at Customer 97 at (8209, 6089)
# [ 3] 19:39:21.8 Customer 97 at (8209, 6089) answers door
# [ 3] 19:39:21.8 Customer 97 at (8209, 6089) accepts Parcel 22 for cust 97
# [ 3] 19:39:47.0 Customer 97 at (8209, 6089) signs off
# [ 3] 19:39:48.8 Driver drives to Customer 84 at (6620, 6812)
# [ 3] 19:52:03.2 Driver arrived at Customer 84 at (6620, 6812)
# [ 3] 19:53:03.2 Customer 84 at (6620, 6812) not at home
# [ 3] 19:53:03.2 Driver drives to Customer 87 at (6620, 7446)
# [ 3] 19:55:35.4 Driver arrived at Customer 87 at (6620, 7446)
# [ 3] 19:55:56.8 Customer 87 at (6620, 7446) answers door
# [ 3] 19:55:56.8 Customer 87 at (6620, 7446) accepts Parcel 44 for cust 87
# [ 3] 19:56:00.2 Customer 87 at (6620, 7446) signs off
# [ 3] 19:56:07.6 Driver drives to Customer 89 at (6620, 8231)
# [ 3] 19:59:16.0 Driver arrived at Customer 89 at (6620, 8231)
# [ 3] 19:59:50.1 Customer 89 at (6620, 8231) answers door
# [ 3] 19:59:50.1 Customer 89 at (6620, 8231) accepts Parcel 10 for cust 89
# [ 3] 20:00:00.0 Customer 89 at (6620, 8231) accepts Parcel 11 for cust 89
# [ 3] 20:00:07.6 Customer 89 at (6620, 8231) signs off
# [ 3] 20:00:12.8 Driver drives to Customer 50 at (5076, 8740)
# [ 3] 20:08:25.6 Driver arrived at Customer 50 at (5076, 8740)
# [ 3] 20:09:05.8 Customer 50 at (5076, 8740) answers door
# [ 3] 20:09:05.8 Customer 50 at (5076, 8740) accepts Parcel 28 for cust 50
# [ 3] 20:09:11.0 Customer 50 at (5076, 8740) accepts Parcel 41 for cust 50
# [ 3] 20:09:26.1 Customer 50 at (5076, 8740) signs off
# [ 3] 20:09:41.6 Driver drives to Customer 49 at (4987, 8740)
# [ 3] 20:10:03.0 Driver arrived at Customer 49 at (4987, 8740)
# [ 3] 20:10:16.8 Customer 49 at (4987, 8740) answers door
# [ 3] 20:10:16.8 Customer 49 at (4987, 8740) accepts Parcel 40 for cust 49
# [ 3] 20:10:21.4 Customer 49 at (4987, 8740) signs off
# [ 3] 20:10:31.3 Driver drives to Customer 48 at (4908, 8740)
# [ 3] 20:10:50.3 Driver arrived at Customer 48 at (4908, 8740)
# [ 3] 20:10:57.1 Customer 48 at (4908, 8740) answers door
# [ 3] 20:10:57.1 Customer 48 at (4908, 8740) accepts Parcel 39 for cust 48
# [ 3] 20:11:09.1 Customer 48 at (4908, 8740) signs off
# [ 3] 20:11:13.9 Driver returns to delivery centre
# [ 3] 20:43:31.2 Driver arrived at delivery centre
# [ 3] 20:43:31.2 Parcel 27 for cust 38 return from delivery
# [ 3] 20:44:01.2 Parcel 9 for cust 84 return from delivery
# [ 3] 20:44:31.2 18 parcels left over for next day
# [ 3] 20:54:31.2 Driver goes home
# Delivery Centre Inventory: 18 parcels

# %%
rec1.histWorkingTime()
rec1.histTourLength()
rec1.histDailyCost()

# %%
rec1.plotWorkingTime()
rec1.plotTourLength()
rec1.plotDailyCost()

# %%
rec2 = simulation(M, W, C, p=0.3, days=4, log=True, plot=True)
# Out:
# Simulating delivery of 112 parcels over 4 days to 100 customers
# [ 0] 17:00:00.0 Parcel 0 for cust 15 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 1 for cust 24 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 2 for cust 25 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 3 for cust 30 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 4 for cust 38 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 5 for cust 54 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 6 for cust 56 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 7 for cust 57 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 8 for cust 59 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 9 for cust 59 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 10 for cust 60 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 11 for cust 62 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 12 for cust 65 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 13 for cust 65 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 14 for cust 66 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 15 for cust 68 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 16 for cust 70 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 17 for cust 71 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 18 for cust 74 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 19 for cust 76 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 20 for cust 82 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 21 for cust 89 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 22 for cust 89 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 23 for cust 94 arr at delivery centre
# [ 0] 18:00:00.0 Driver arrives for work
# [ 0] 18:00:00.0 Parcel 4 for cust 38 out for delivery
# [ 0] 18:00:00.0 Parcel 5 for cust 54 out for delivery
# [ 0] 18:00:00.0 Parcel 3 for cust 30 out for delivery
# [ 0] 18:00:00.0 Parcel 6 for cust 56 out for delivery
# [ 0] 18:00:00.0 Parcel 7 for cust 57 out for delivery
# [ 0] 18:00:00.0 Parcel 0 for cust 15 out for delivery
# [ 0] 18:00:00.0 Parcel 2 for cust 25 out for delivery
# [ 0] 18:00:00.0 Parcel 1 for cust 24 out for delivery
# [ 0] 18:06:40.0 Driver leaves for delivery of 8 parcels to 8 customers
# [ 0] 18:06:40.0 Length of delivery tour: 39,274m
# [ 0] 18:06:40.0 Driver drives to Customer 38 at (4500, 4765)
# [ 0] 18:07:43.6 Driver arrived at Customer 38 at (4500, 4765)
# [ 0] 18:08:12.9 Customer 38 at (4500, 4765) answers door
# [ 0] 18:08:12.9 Customer 38 at (4500, 4765) accepts Parcel 4 for cust 38
# [ 0] 18:08:18.8 Customer 38 at (4500, 4765) signs off
# [ 0] 18:08:25.5 Driver drives to Customer 54 at (5416, 5560)
# [ 0] 18:15:16.2 Driver arrived at Customer 54 at (5416, 5560)
# [ 0] 18:16:16.2 Customer 54 at (5416, 5560) not at home
# [ 0] 18:16:16.2 Driver drives to Customer 30 at (3068, 6620)
# [ 0] 18:27:25.1 Driver arrived at Customer 30 at (3068, 6620)
# [ 0] 18:28:00.2 Customer 30 at (3068, 6620) answers door
# [ 0] 18:28:00.2 Customer 30 at (3068, 6620) accepts Parcel 3 for cust 30
# [ 0] 18:28:11.6 Customer 30 at (3068, 6620) signs off
# [ 0] 18:28:17.1 Driver drives to Customer 56 at (5560, 604)
# [ 0] 19:22:33.9 Driver arrived at Customer 56 at (5560, 604)
# [ 0] 19:22:52.3 Customer 56 at (5560, 604) answers door
# [ 0] 19:22:52.3 Customer 56 at (5560, 604) accepts Parcel 6 for cust 56
# [ 0] 19:23:36.9 Customer 56 at (5560, 604) signs off
# [ 0] 19:23:39.9 Driver drives to Customer 57 at (5560, 779)
# [ 0] 19:24:21.9 Driver arrived at Customer 57 at (5560, 779)
# [ 0] 19:25:21.9 Customer 57 at (5560, 779) to slow to answer the door
# [ 0] 19:25:21.9 Driver drives to Customer 15 at (1320, 7071)
# [ 0] 20:15:09.4 Driver arrived at Customer 15 at (1320, 7071)
# [ 0] 20:15:32.0 Customer 15 at (1320, 7071) answers door
# [ 0] 20:15:32.0 Customer 15 at (1320, 7071) accepts Parcel 0 for cust 15
# [ 0] 20:15:36.4 Customer 15 at (1320, 7071) signs off
# [ 0] 20:15:37.1 Driver drives to Customer 25 at (2380, 5939)
# [ 0] 20:24:23.2 Driver arrived at Customer 25 at (2380, 5939)
# [ 0] 20:25:23.2 Customer 25 at (2380, 5939) not at home
# [ 0] 20:25:23.2 Driver drives to Customer 24 at (2380, 5026)
# [ 0] 20:29:02.3 Driver arrived at Customer 24 at (2380, 5026)
# [ 0] 20:30:02.3 Customer 24 at (2380, 5026) to slow to answer the door
# [ 0] 20:30:02.3 Driver returns to delivery centre
# [ 0] 20:50:53.4 Driver arrived at delivery centre
# [ 0] 20:50:53.4 Parcel 5 for cust 54 return from delivery
# [ 0] 20:51:23.4 Parcel 7 for cust 57 return from delivery
# [ 0] 20:51:53.4 Parcel 2 for cust 25 return from delivery
# [ 0] 20:52:23.4 Parcel 1 for cust 24 return from delivery
# [ 0] 20:52:53.4 20 parcels left over for next day
# [ 0] 21:02:53.4 Driver goes home
# [ 1] 17:00:00.0 Parcel 24 for cust 2 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 25 for cust 3 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 26 for cust 4 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 27 for cust 12 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 28 for cust 19 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 29 for cust 21 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 30 for cust 28 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 31 for cust 34 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 32 for cust 35 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 33 for cust 36 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 34 for cust 36 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 35 for cust 46 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 36 for cust 57 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 37 for cust 58 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 38 for cust 64 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 39 for cust 66 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 40 for cust 66 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 41 for cust 68 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 42 for cust 77 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 43 for cust 78 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 44 for cust 79 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 45 for cust 83 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 46 for cust 83 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 47 for cust 84 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 48 for cust 88 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 49 for cust 90 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 50 for cust 92 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 51 for cust 93 arr at delivery centre
# [ 1] 18:00:00.0 Driver arrives for work
# [ 1] 18:00:00.0 Parcel 33 for cust 36 out for delivery
# [ 1] 18:00:00.0 Parcel 34 for cust 36 out for delivery
# [ 1] 18:00:00.0 Parcel 30 for cust 28 out for delivery
# [ 1] 18:00:00.0 Parcel 29 for cust 21 out for delivery
# [ 1] 18:00:00.0 Parcel 26 for cust 4 out for delivery
# [ 1] 18:00:00.0 Parcel 25 for cust 3 out for delivery
# [ 1] 18:00:00.0 Parcel 24 for cust 2 out for delivery
# [ 1] 18:00:00.0 Parcel 27 for cust 12 out for delivery
# [ 1] 18:00:00.0 Parcel 28 for cust 19 out for delivery
# [ 1] 18:00:00.0 Parcel 7 for cust 57 out for delivery
# [ 1] 18:00:00.0 Parcel 36 for cust 57 out for delivery
# [ 1] 18:00:00.0 Parcel 12 for cust 65 out for delivery
# [ 1] 18:00:00.0 Parcel 13 for cust 65 out for delivery
# [ 1] 18:00:00.0 Parcel 37 for cust 58 out for delivery
# [ 1] 18:00:00.0 Parcel 8 for cust 59 out for delivery
# [ 1] 18:00:00.0 Parcel 9 for cust 59 out for delivery
# [ 1] 18:00:00.0 Parcel 10 for cust 60 out for delivery
# [ 1] 18:00:00.0 Parcel 11 for cust 62 out for delivery
# [ 1] 18:00:00.0 Parcel 14 for cust 66 out for delivery
# [ 1] 18:00:00.0 Parcel 39 for cust 66 out for delivery
# [ 1] 18:00:00.0 Parcel 40 for cust 66 out for delivery
# [ 1] 18:00:00.0 Parcel 15 for cust 68 out for delivery
# [ 1] 18:00:00.0 Parcel 41 for cust 68 out for delivery
# [ 1] 18:00:00.0 Parcel 16 for cust 70 out for delivery
# [ 1] 18:00:00.0 Parcel 19 for cust 76 out for delivery
# [ 1] 18:00:00.0 Parcel 42 for cust 77 out for delivery
# [ 1] 18:21:40.0 Driver leaves for delivery of 26 parcels to 19 customers
# [ 1] 18:21:40.0 Length of delivery tour: 39,970m
# [ 1] 18:21:40.0 Driver drives to Customer 36 at (4043, 6016)
# [ 1] 18:28:29.2 Driver arrived at Customer 36 at (4043, 6016)
# [ 1] 18:28:50.4 Customer 36 at (4043, 6016) answers door
# [ 1] 18:28:50.4 Customer 36 at (4043, 6016) accepts Parcel 33 for cust 36
# [ 1] 18:28:59.8 Customer 36 at (4043, 6016) accepts Parcel 34 for cust 36
# [ 1] 18:29:04.7 Customer 36 at (4043, 6016) signs off
# [ 1] 18:29:05.2 Driver drives to Customer 28 at (2879, 6620)
# [ 1] 18:34:44.6 Driver arrived at Customer 28 at (2879, 6620)
# [ 1] 18:35:10.0 Customer 28 at (2879, 6620) answers door
# [ 1] 18:35:10.0 Customer 28 at (2879, 6620) accepts Parcel 30 for cust 28
# [ 1] 18:35:11.7 Customer 28 at (2879, 6620) signs off
# [ 1] 18:35:12.0 Driver drives to Customer 21 at (1791, 6620)
# [ 1] 18:39:33.1 Driver arrived at Customer 21 at (1791, 6620)
# [ 1] 18:40:11.6 Customer 21 at (1791, 6620) answers door
# [ 1] 18:40:11.6 Customer 21 at (1791, 6620) accepts Parcel 29 for cust 21
# [ 1] 18:40:21.5 Customer 21 at (1791, 6620) signs off
# [ 1] 18:40:22.6 Driver drives to Customer 4 at (260, 4991)
# [ 1] 18:53:01.0 Driver arrived at Customer 4 at (260, 4991)
# [ 1] 18:53:32.9 Customer 4 at (260, 4991) answers door
# [ 1] 18:53:32.9 Customer 4 at (260, 4991) accepts Parcel 26 for cust 4
# [ 1] 18:53:37.1 Customer 4 at (260, 4991) signs off
# [ 1] 18:53:42.0 Driver drives to Customer 3 at (260, 4918)
# [ 1] 18:53:59.5 Driver arrived at Customer 3 at (260, 4918)
# [ 1] 18:54:59.4 Customer 3 at (260, 4918) answers door
# [ 1] 18:54:59.4 Customer 3 at (260, 4918) accepts Parcel 25 for cust 3
# [ 1] 18:55:06.1 Customer 3 at (260, 4918) signs off
# [ 1] 18:55:27.5 Driver drives to Customer 2 at (260, 4756)
# [ 1] 18:56:06.3 Driver arrived at Customer 2 at (260, 4756)
# [ 1] 18:56:44.0 Customer 2 at (260, 4756) answers door
# [ 1] 18:56:44.0 Customer 2 at (260, 4756) accepts Parcel 24 for cust 2
# [ 1] 18:56:50.3 Customer 2 at (260, 4756) signs off
# [ 1] 18:57:00.3 Driver drives to Customer 12 at (1104, 2594)
# [ 1] 19:07:03.0 Driver arrived at Customer 12 at (1104, 2594)
# [ 1] 19:07:19.4 Customer 12 at (1104, 2594) answers door
# [ 1] 19:07:19.4 Customer 12 at (1104, 2594) accepts Parcel 27 for cust 12
# [ 1] 19:07:20.8 Customer 12 at (1104, 2594) signs off
# [ 1] 19:07:32.2 Driver drives to Customer 19 at (1677, 960)
# [ 1] 19:15:01.3 Driver arrived at Customer 19 at (1677, 960)
# [ 1] 19:15:40.2 Customer 19 at (1677, 960) answers door
# [ 1] 19:15:40.2 Customer 19 at (1677, 960) accepts Parcel 28 for cust 19
# [ 1] 19:15:55.7 Customer 19 at (1677, 960) signs off
# [ 1] 19:15:57.1 Driver drives to Customer 57 at (5560, 779)
# [ 1] 19:34:42.9 Driver arrived at Customer 57 at (5560, 779)
# [ 1] 19:35:42.9 Customer 57 at (5560, 779) to slow to answer the door
# [ 1] 19:35:42.9 Driver drives to Customer 65 at (5895, 1320)
# [ 1] 19:39:13.2 Driver arrived at Customer 65 at (5895, 1320)
# [ 1] 19:40:13.2 Customer 65 at (5895, 1320) to slow to answer the door
# [ 1] 19:40:13.2 Driver drives to Customer 58 at (5560, 1479)
# [ 1] 19:42:11.7 Driver arrived at Customer 58 at (5560, 1479)
# [ 1] 19:43:11.7 Customer 58 at (5560, 1479) to slow to answer the door
# [ 1] 19:43:11.7 Driver drives to Customer 59 at (5560, 1672)
# [ 1] 19:43:58.1 Driver arrived at Customer 59 at (5560, 1672)
# [ 1] 19:44:58.1 Customer 59 at (5560, 1672) to slow to answer the door
# [ 1] 19:44:58.1 Driver drives to Customer 60 at (5560, 1879)
# [ 1] 19:45:47.7 Driver arrived at Customer 60 at (5560, 1879)
# [ 1] 19:46:33.4 Customer 60 at (5560, 1879) answers door
# [ 1] 19:46:33.4 Customer 60 at (5560, 1879) accepts Parcel 10 for cust 60
# [ 1] 19:46:50.1 Customer 60 at (5560, 1879) signs off
# [ 1] 19:46:57.4 Driver drives to Customer 62 at (5560, 2149)
# [ 1] 19:48:02.2 Driver arrived at Customer 62 at (5560, 2149)
# [ 1] 19:49:02.2 Customer 62 at (5560, 2149) to slow to answer the door
# [ 1] 19:49:02.2 Driver drives to Customer 66 at (5906, 2380)
# [ 1] 19:51:20.7 Driver arrived at Customer 66 at (5906, 2380)
# [ 1] 19:51:29.1 Customer 66 at (5906, 2380) answers door
# [ 1] 19:51:29.1 Customer 66 at (5906, 2380) accepts Parcel 14 for cust 66
# [ 1] 19:51:44.3 Customer 66 at (5906, 2380) accepts Parcel 39 for cust 66
# [ 1] 19:51:50.2 Customer 66 at (5906, 2380) accepts Parcel 40 for cust 66
# [ 1] 19:52:04.3 Customer 66 at (5906, 2380) signs off
# [ 1] 19:52:10.4 Driver drives to Customer 68 at (6038, 2380)
# [ 1] 19:52:42.1 Driver arrived at Customer 68 at (6038, 2380)
# [ 1] 19:53:42.1 Customer 68 at (6038, 2380) to slow to answer the door
# [ 1] 19:53:42.1 Driver drives to Customer 70 at (6201, 2380)
# [ 1] 19:54:21.2 Driver arrived at Customer 70 at (6201, 2380)
# [ 1] 19:54:24.3 Customer 70 at (6201, 2380) answers door
# [ 1] 19:54:24.3 Customer 70 at (6201, 2380) accepts Parcel 16 for cust 70
# [ 1] 19:54:24.8 Customer 70 at (6201, 2380) signs off
# [ 1] 19:54:52.0 Driver drives to Customer 76 at (6620, 2144)
# [ 1] 19:57:29.2 Driver arrived at Customer 76 at (6620, 2144)
# [ 1] 19:57:55.8 Customer 76 at (6620, 2144) answers door
# [ 1] 19:57:55.8 Customer 76 at (6620, 2144) accepts Parcel 19 for cust 76
# [ 1] 19:58:19.0 Customer 76 at (6620, 2144) signs off
# [ 1] 19:58:47.9 Driver drives to Customer 77 at (6620, 2458)
# [ 1] 20:00:03.3 Driver arrived at Customer 77 at (6620, 2458)
# [ 1] 20:00:47.2 Customer 77 at (6620, 2458) answers door
# [ 1] 20:00:47.2 Customer 77 at (6620, 2458) accepts Parcel 42 for cust 77
# [ 1] 20:00:55.7 Customer 77 at (6620, 2458) signs off
# [ 1] 20:00:58.1 Driver returns to delivery centre
# [ 1] 21:18:37.5 Driver arrived at delivery centre
# [ 1] 21:18:37.5 Parcel 7 for cust 57 return from delivery
# [ 1] 21:19:07.5 Parcel 36 for cust 57 return from delivery
# [ 1] 21:19:37.5 Parcel 12 for cust 65 return from delivery
# [ 1] 21:20:07.5 Parcel 13 for cust 65 return from delivery
# [ 1] 21:20:37.5 Parcel 37 for cust 58 return from delivery
# [ 1] 21:21:07.5 Parcel 8 for cust 59 return from delivery
# [ 1] 21:21:37.5 Parcel 9 for cust 59 return from delivery
# [ 1] 21:22:07.5 Parcel 11 for cust 62 return from delivery
# [ 1] 21:22:37.5 Parcel 15 for cust 68 return from delivery
# [ 1] 21:23:07.5 Parcel 41 for cust 68 return from delivery
# [ 1] 21:23:37.5 32 parcels left over for next day
# [ 1] 21:33:37.5 Driver goes home
# [ 2] 17:00:00.0 Parcel 52 for cust 2 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 53 for cust 6 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 54 for cust 15 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 55 for cust 18 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 56 for cust 20 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 57 for cust 20 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 58 for cust 24 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 59 for cust 28 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 60 for cust 31 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 61 for cust 32 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 62 for cust 36 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 63 for cust 44 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 64 for cust 49 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 65 for cust 50 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 66 for cust 60 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 67 for cust 61 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 68 for cust 63 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 69 for cust 68 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 70 for cust 70 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 71 for cust 71 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 72 for cust 77 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 73 for cust 78 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 74 for cust 80 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 75 for cust 83 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 76 for cust 84 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 77 for cust 89 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 78 for cust 89 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 79 for cust 91 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 80 for cust 94 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 81 for cust 95 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 82 for cust 98 arr at delivery centre
# [ 2] 18:00:00.0 Driver arrives for work
# [ 2] 18:00:00.0 Parcel 62 for cust 36 out for delivery
# [ 2] 18:00:00.0 Parcel 59 for cust 28 out for delivery
# [ 2] 18:00:00.0 Parcel 53 for cust 6 out for delivery
# [ 2] 18:00:00.0 Parcel 52 for cust 2 out for delivery
# [ 2] 18:00:00.0 Parcel 54 for cust 15 out for delivery
# [ 2] 18:00:00.0 Parcel 2 for cust 25 out for delivery
# [ 2] 18:00:00.0 Parcel 1 for cust 24 out for delivery
# [ 2] 18:00:00.0 Parcel 58 for cust 24 out for delivery
# [ 2] 18:00:00.0 Parcel 5 for cust 54 out for delivery
# [ 2] 18:00:00.0 Parcel 38 for cust 64 out for delivery
# [ 2] 18:00:00.0 Parcel 17 for cust 71 out for delivery
# [ 2] 18:00:00.0 Parcel 71 for cust 71 out for delivery
# [ 2] 18:00:00.0 Parcel 79 for cust 91 out for delivery
# [ 2] 18:00:00.0 Parcel 23 for cust 94 out for delivery
# [ 2] 18:00:00.0 Parcel 80 for cust 94 out for delivery
# [ 2] 18:00:00.0 Parcel 45 for cust 83 out for delivery
# [ 2] 18:00:00.0 Parcel 46 for cust 83 out for delivery
# [ 2] 18:00:00.0 Parcel 75 for cust 83 out for delivery
# [ 2] 18:00:00.0 Parcel 47 for cust 84 out for delivery
# [ 2] 18:00:00.0 Parcel 76 for cust 84 out for delivery
# [ 2] 18:00:00.0 Parcel 48 for cust 88 out for delivery
# [ 2] 18:00:00.0 Parcel 21 for cust 89 out for delivery
# [ 2] 18:00:00.0 Parcel 22 for cust 89 out for delivery
# [ 2] 18:00:00.0 Parcel 77 for cust 89 out for delivery
# [ 2] 18:00:00.0 Parcel 78 for cust 89 out for delivery
# [ 2] 18:00:00.0 Parcel 65 for cust 50 out for delivery
# [ 2] 18:00:00.0 Parcel 64 for cust 49 out for delivery
# [ 2] 18:00:00.0 Parcel 35 for cust 46 out for delivery
# [ 2] 18:23:20.0 Driver leaves for delivery of 28 parcels to 19 customers
# [ 2] 18:23:20.0 Length of delivery tour: 35,308m
# [ 2] 18:23:20.0 Driver drives to Customer 36 at (4043, 6016)
# [ 2] 18:30:09.2 Driver arrived at Customer 36 at (4043, 6016)
# [ 2] 18:30:31.8 Customer 36 at (4043, 6016) answers door
# [ 2] 18:30:31.8 Customer 36 at (4043, 6016) accepts Parcel 62 for cust 36
# [ 2] 18:30:34.7 Customer 36 at (4043, 6016) signs off
# [ 2] 18:30:40.7 Driver drives to Customer 28 at (2879, 6620)
# [ 2] 18:36:20.1 Driver arrived at Customer 28 at (2879, 6620)
# [ 2] 18:37:20.1 Customer 28 at (2879, 6620) not at home
# [ 2] 18:37:20.1 Driver drives to Customer 6 at (260, 5225)
# [ 2] 18:53:23.4 Driver arrived at Customer 6 at (260, 5225)
# [ 2] 18:54:23.4 Customer 6 at (260, 5225) to slow to answer the door
# [ 2] 18:54:23.4 Driver drives to Customer 2 at (260, 4756)
# [ 2] 18:56:16.0 Driver arrived at Customer 2 at (260, 4756)
# [ 2] 18:56:22.1 Customer 2 at (260, 4756) answers door
# [ 2] 18:56:22.1 Customer 2 at (260, 4756) accepts Parcel 52 for cust 2
# [ 2] 18:56:28.3 Customer 2 at (260, 4756) signs off
# [ 2] 18:56:38.5 Driver drives to Customer 15 at (1320, 7071)
# [ 2] 19:10:08.5 Driver arrived at Customer 15 at (1320, 7071)
# [ 2] 19:10:34.9 Customer 15 at (1320, 7071) answers door
# [ 2] 19:10:34.9 Customer 15 at (1320, 7071) accepts Parcel 54 for cust 15
# [ 2] 19:10:37.2 Customer 15 at (1320, 7071) signs off
# [ 2] 19:10:37.2 Driver drives to Customer 25 at (2380, 5939)
# [ 2] 19:19:23.3 Driver arrived at Customer 25 at (2380, 5939)
# [ 2] 19:20:11.3 Customer 25 at (2380, 5939) answers door
# [ 2] 19:20:11.3 Customer 25 at (2380, 5939) accepts Parcel 2 for cust 25
# [ 2] 19:20:20.9 Customer 25 at (2380, 5939) signs off
# [ 2] 19:20:21.0 Driver drives to Customer 24 at (2380, 5026)
# [ 2] 19:24:00.1 Driver arrived at Customer 24 at (2380, 5026)
# [ 2] 19:24:14.3 Customer 24 at (2380, 5026) answers door
# [ 2] 19:24:14.3 Customer 24 at (2380, 5026) accepts Parcel 1 for cust 24
# [ 2] 19:24:29.0 Customer 24 at (2380, 5026) accepts Parcel 58 for cust 24
# [ 2] 19:24:38.9 Customer 24 at (2380, 5026) signs off
# [ 2] 19:24:46.7 Driver drives to Customer 54 at (5416, 5560)
# [ 2] 19:45:03.1 Driver arrived at Customer 54 at (5416, 5560)
# [ 2] 19:45:09.9 Customer 54 at (5416, 5560) answers door
# [ 2] 19:45:09.9 Customer 54 at (5416, 5560) accepts Parcel 5 for cust 54
# [ 2] 19:45:22.1 Customer 54 at (5416, 5560) signs off
# [ 2] 19:45:28.5 Driver drives to Customer 64 at (5846, 5560)
# [ 2] 19:47:11.7 Driver arrived at Customer 64 at (5846, 5560)
# [ 2] 19:47:57.0 Customer 64 at (5846, 5560) answers door
# [ 2] 19:47:57.0 Customer 64 at (5846, 5560) accepts Parcel 38 for cust 64
# [ 2] 19:48:11.3 Customer 64 at (5846, 5560) signs off
# [ 2] 19:48:14.0 Driver drives to Customer 71 at (6408, 5560)
# [ 2] 19:50:28.8 Driver arrived at Customer 71 at (6408, 5560)
# [ 2] 19:51:26.3 Customer 71 at (6408, 5560) answers door
# [ 2] 19:51:26.3 Customer 71 at (6408, 5560) accepts Parcel 17 for cust 71
# [ 2] 19:51:29.5 Customer 71 at (6408, 5560) accepts Parcel 71 for cust 71
# [ 2] 19:52:10.9 Customer 71 at (6408, 5560) signs off
# [ 2] 19:52:12.2 Driver drives to Customer 91 at (6956, 5560)
# [ 2] 19:54:23.7 Driver arrived at Customer 91 at (6956, 5560)
# [ 2] 19:55:23.7 Customer 91 at (6956, 5560) not at home
# [ 2] 19:55:23.7 Driver drives to Customer 94 at (7439, 5560)
# [ 2] 19:57:19.6 Driver arrived at Customer 94 at (7439, 5560)
# [ 2] 19:58:19.6 Customer 94 at (7439, 5560) to slow to answer the door
# [ 2] 19:58:19.6 Driver drives to Customer 83 at (6620, 6039)
# [ 2] 20:03:31.1 Driver arrived at Customer 83 at (6620, 6039)
# [ 2] 20:03:32.8 Customer 83 at (6620, 6039) answers door
# [ 2] 20:03:32.8 Customer 83 at (6620, 6039) accepts Parcel 45 for cust 83
# [ 2] 20:03:35.8 Customer 83 at (6620, 6039) accepts Parcel 46 for cust 83
# [ 2] 20:03:43.2 Customer 83 at (6620, 6039) accepts Parcel 75 for cust 83
# [ 2] 20:03:52.0 Customer 83 at (6620, 6039) signs off
# [ 2] 20:03:57.0 Driver drives to Customer 84 at (6620, 6812)
# [ 2] 20:07:02.5 Driver arrived at Customer 84 at (6620, 6812)
# [ 2] 20:07:06.8 Customer 84 at (6620, 6812) answers door
# [ 2] 20:07:06.8 Customer 84 at (6620, 6812) accepts Parcel 47 for cust 84
# [ 2] 20:07:09.7 Customer 84 at (6620, 6812) accepts Parcel 76 for cust 84
# [ 2] 20:07:13.1 Customer 84 at (6620, 6812) signs off
# [ 2] 20:07:27.1 Driver drives to Customer 88 at (6620, 7535)
# [ 2] 20:10:20.7 Driver arrived at Customer 88 at (6620, 7535)
# [ 2] 20:11:20.7 Customer 88 at (6620, 7535) to slow to answer the door
# [ 2] 20:11:20.7 Driver drives to Customer 89 at (6620, 8231)
# [ 2] 20:14:07.7 Driver arrived at Customer 89 at (6620, 8231)
# [ 2] 20:14:43.9 Customer 89 at (6620, 8231) answers door
# [ 2] 20:14:43.9 Customer 89 at (6620, 8231) accepts Parcel 21 for cust 89
# [ 2] 20:14:44.3 Customer 89 at (6620, 8231) accepts Parcel 22 for cust 89
# [ 2] 20:15:00.0 Customer 89 at (6620, 8231) accepts Parcel 77 for cust 89
# [ 2] 20:15:03.6 Customer 89 at (6620, 8231) accepts Parcel 78 for cust 89
# [ 2] 20:15:07.8 Customer 89 at (6620, 8231) signs off
# [ 2] 20:15:15.3 Driver drives to Customer 50 at (5076, 8740)
# [ 2] 20:23:28.0 Driver arrived at Customer 50 at (5076, 8740)
# [ 2] 20:23:39.5 Customer 50 at (5076, 8740) answers door
# [ 2] 20:23:39.5 Customer 50 at (5076, 8740) accepts Parcel 65 for cust 50
# [ 2] 20:24:04.8 Customer 50 at (5076, 8740) signs off
# [ 2] 20:24:06.5 Driver drives to Customer 49 at (4987, 8740)
# [ 2] 20:24:27.9 Driver arrived at Customer 49 at (4987, 8740)
# [ 2] 20:24:49.3 Customer 49 at (4987, 8740) answers door
# [ 2] 20:24:49.3 Customer 49 at (4987, 8740) accepts Parcel 64 for cust 49
# [ 2] 20:24:52.8 Customer 49 at (4987, 8740) signs off
# [ 2] 20:25:00.1 Driver drives to Customer 46 at (4732, 8740)
# [ 2] 20:26:01.3 Driver arrived at Customer 46 at (4732, 8740)
# [ 2] 20:26:35.4 Customer 46 at (4732, 8740) answers door
# [ 2] 20:26:35.4 Customer 46 at (4732, 8740) accepts Parcel 35 for cust 46
# [ 2] 20:26:45.3 Customer 46 at (4732, 8740) signs off
# [ 2] 20:26:52.9 Driver returns to delivery centre
# [ 2] 20:59:52.4 Driver arrived at delivery centre
# [ 2] 20:59:52.4 Parcel 59 for cust 28 return from delivery
# [ 2] 21:00:22.4 Parcel 53 for cust 6 return from delivery
# [ 2] 21:00:52.4 Parcel 79 for cust 91 return from delivery
# [ 2] 21:01:22.4 Parcel 23 for cust 94 return from delivery
# [ 2] 21:01:52.4 Parcel 80 for cust 94 return from delivery
# [ 2] 21:02:22.4 Parcel 48 for cust 88 return from delivery
# [ 2] 21:02:52.4 41 parcels left over for next day
# [ 2] 21:12:52.4 Driver goes home
# [ 3] 17:00:00.0 Parcel 83 for cust 4 arr at delivery centre
# [ 3] 17:00:00.0 Parcel 84 for cust 6 arr at delivery centre
# [ 3] 17:00:00.0 Parcel 85 for cust 7 arr at delivery centre
# [ 3] 17:00:00.0 Parcel 86 for cust 14 arr at delivery centre
# [ 3] 17:00:00.0 Parcel 87 for cust 22 arr at delivery centre
# [ 3] 17:00:00.0 Parcel 88 for cust 22 arr at delivery centre
# [ 3] 17:00:00.0 Parcel 89 for cust 25 arr at delivery centre
# [ 3] 17:00:00.0 Parcel 90 for cust 28 arr at delivery centre
# [ 3] 17:00:00.0 Parcel 91 for cust 30 arr at delivery centre
# [ 3] 17:00:00.0 Parcel 92 for cust 33 arr at delivery centre
# [ 3] 17:00:00.0 Parcel 93 for cust 37 arr at delivery centre
# [ 3] 17:00:00.0 Parcel 94 for cust 51 arr at delivery centre
# [ 3] 17:00:00.0 Parcel 95 for cust 54 arr at delivery centre
# [ 3] 17:00:00.0 Parcel 96 for cust 55 arr at delivery centre
# [ 3] 17:00:00.0 Parcel 97 for cust 62 arr at delivery centre
# [ 3] 17:00:00.0 Parcel 98 for cust 68 arr at delivery centre
# [ 3] 17:00:00.0 Parcel 99 for cust 69 arr at delivery centre
# [ 3] 17:00:00.0 Parcel 100 for cust 70 arr at delivery centre
# [ 3] 17:00:00.0 Parcel 101 for cust 70 arr at delivery centre
# [ 3] 17:00:00.0 Parcel 102 for cust 76 arr at delivery centre
# [ 3] 17:00:00.0 Parcel 103 for cust 80 arr at delivery centre
# [ 3] 17:00:00.0 Parcel 104 for cust 82 arr at delivery centre
# [ 3] 17:00:00.0 Parcel 105 for cust 82 arr at delivery centre
# [ 3] 17:00:00.0 Parcel 106 for cust 83 arr at delivery centre
# [ 3] 17:00:00.0 Parcel 107 for cust 86 arr at delivery centre
# [ 3] 17:00:00.0 Parcel 108 for cust 88 arr at delivery centre
# [ 3] 17:00:00.0 Parcel 109 for cust 94 arr at delivery centre
# [ 3] 17:00:00.0 Parcel 110 for cust 94 arr at delivery centre
# [ 3] 17:00:00.0 Parcel 111 for cust 98 arr at delivery centre
# [ 3] 18:00:00.0 Driver arrives for work
# [ 3] 18:00:00.0 Parcel 91 for cust 30 out for delivery
# [ 3] 18:00:00.0 Parcel 59 for cust 28 out for delivery
# [ 3] 18:00:00.0 Parcel 90 for cust 28 out for delivery
# [ 3] 18:00:00.0 Parcel 87 for cust 22 out for delivery
# [ 3] 18:00:00.0 Parcel 88 for cust 22 out for delivery
# [ 3] 18:00:00.0 Parcel 85 for cust 7 out for delivery
# [ 3] 18:00:00.0 Parcel 53 for cust 6 out for delivery
# [ 3] 18:00:00.0 Parcel 84 for cust 6 out for delivery
# [ 3] 18:00:00.0 Parcel 83 for cust 4 out for delivery
# [ 3] 18:00:00.0 Parcel 55 for cust 18 out for delivery
# [ 3] 18:00:00.0 Parcel 56 for cust 20 out for delivery
# [ 3] 18:00:00.0 Parcel 57 for cust 20 out for delivery
# [ 3] 18:00:00.0 Parcel 60 for cust 31 out for delivery
# [ 3] 18:00:00.0 Parcel 61 for cust 32 out for delivery
# [ 3] 18:00:00.0 Parcel 93 for cust 37 out for delivery
# [ 3] 18:00:00.0 Parcel 63 for cust 44 out for delivery
# [ 3] 18:00:00.0 Parcel 96 for cust 55 out for delivery
# [ 3] 18:00:00.0 Parcel 7 for cust 57 out for delivery
# [ 3] 18:00:00.0 Parcel 36 for cust 57 out for delivery
# [ 3] 18:00:00.0 Parcel 12 for cust 65 out for delivery
# [ 3] 18:00:00.0 Parcel 13 for cust 65 out for delivery
# [ 3] 18:00:00.0 Parcel 49 for cust 90 out for delivery
# [ 3] 18:00:00.0 Parcel 18 for cust 74 out for delivery
# [ 3] 18:00:00.0 Parcel 102 for cust 76 out for delivery
# [ 3] 18:00:00.0 Parcel 72 for cust 77 out for delivery
# [ 3] 18:00:00.0 Parcel 43 for cust 78 out for delivery
# [ 3] 18:00:00.0 Parcel 73 for cust 78 out for delivery
# [ 3] 18:00:00.0 Parcel 44 for cust 79 out for delivery
# [ 3] 18:00:00.0 Parcel 70 for cust 70 out for delivery
# [ 3] 18:00:00.0 Parcel 100 for cust 70 out for delivery
# [ 3] 18:00:00.0 Parcel 101 for cust 70 out for delivery
# [ 3] 18:00:00.0 Parcel 15 for cust 68 out for delivery
# [ 3] 18:00:00.0 Parcel 41 for cust 68 out for delivery
# [ 3] 18:00:00.0 Parcel 69 for cust 68 out for delivery
# [ 3] 18:00:00.0 Parcel 98 for cust 68 out for delivery
# [ 3] 18:00:00.0 Parcel 68 for cust 63 out for delivery
# [ 3] 18:00:00.0 Parcel 11 for cust 62 out for delivery
# [ 3] 18:00:00.0 Parcel 97 for cust 62 out for delivery
# [ 3] 18:00:00.0 Parcel 67 for cust 61 out for delivery
# [ 3] 18:00:00.0 Parcel 66 for cust 60 out for delivery
# [ 3] 18:00:00.0 Parcel 8 for cust 59 out for delivery
# [ 3] 18:00:00.0 Parcel 9 for cust 59 out for delivery
# [ 3] 18:00:00.0 Parcel 37 for cust 58 out for delivery
# [ 3] 18:35:50.0 Driver leaves for delivery of 43 parcels to 29 customers
# [ 3] 18:35:50.0 Length of delivery tour: 39,972m
# [ 3] 18:35:50.0 Driver drives to Customer 30 at (3068, 6620)
# [ 3] 18:47:33.4 Driver arrived at Customer 30 at (3068, 6620)
# [ 3] 18:48:19.1 Customer 30 at (3068, 6620) answers door
# [ 3] 18:48:19.1 Customer 30 at (3068, 6620) accepts Parcel 91 for cust 30
# [ 3] 18:48:54.4 Customer 30 at (3068, 6620) signs off
# [ 3] 18:48:59.4 Driver drives to Customer 28 at (2879, 6620)
# [ 3] 18:49:44.8 Driver arrived at Customer 28 at (2879, 6620)
# [ 3] 18:50:44.8 Customer 28 at (2879, 6620) to slow to answer the door
# [ 3] 18:50:44.8 Driver drives to Customer 22 at (1969, 6620)
# [ 3] 18:54:23.2 Driver arrived at Customer 22 at (1969, 6620)
# [ 3] 18:54:47.4 Customer 22 at (1969, 6620) answers door
# [ 3] 18:54:47.4 Customer 22 at (1969, 6620) accepts Parcel 87 for cust 22
# [ 3] 18:54:51.5 Customer 22 at (1969, 6620) accepts Parcel 88 for cust 22
# [ 3] 18:54:52.6 Customer 22 at (1969, 6620) signs off
# [ 3] 18:55:14.0 Driver drives to Customer 7 at (260, 5340)
# [ 3] 19:07:11.4 Driver arrived at Customer 7 at (260, 5340)
# [ 3] 19:08:11.4 Customer 7 at (260, 5340) to slow to answer the door
# [ 3] 19:08:11.4 Driver drives to Customer 6 at (260, 5225)
# [ 3] 19:08:39.0 Driver arrived at Customer 6 at (260, 5225)
# [ 3] 19:08:54.6 Customer 6 at (260, 5225) answers door
# [ 3] 19:08:54.6 Customer 6 at (260, 5225) accepts Parcel 53 for cust 6
# [ 3] 19:09:00.7 Customer 6 at (260, 5225) accepts Parcel 84 for cust 6
# [ 3] 19:09:04.6 Customer 6 at (260, 5225) signs off
# [ 3] 19:09:04.9 Driver drives to Customer 4 at (260, 4991)
# [ 3] 19:10:01.1 Driver arrived at Customer 4 at (260, 4991)
# [ 3] 19:10:02.9 Customer 4 at (260, 4991) answers door
# [ 3] 19:10:02.9 Customer 4 at (260, 4991) accepts Parcel 83 for cust 4
# [ 3] 19:10:07.5 Customer 4 at (260, 4991) signs off
# [ 3] 19:10:09.8 Driver drives to Customer 18 at (1577, 1061)
# [ 3] 19:28:03.6 Driver arrived at Customer 18 at (1577, 1061)
# [ 3] 19:28:33.3 Customer 18 at (1577, 1061) answers door
# [ 3] 19:28:33.3 Customer 18 at (1577, 1061) accepts Parcel 55 for cust 18
# [ 3] 19:28:35.4 Customer 18 at (1577, 1061) signs off
# [ 3] 19:28:37.7 Driver drives to Customer 20 at (1739, 900)
# [ 3] 19:29:32.4 Driver arrived at Customer 20 at (1739, 900)
# [ 3] 19:30:17.1 Customer 20 at (1739, 900) answers door
# [ 3] 19:30:17.1 Customer 20 at (1739, 900) accepts Parcel 56 for cust 20
# [ 3] 19:30:30.4 Customer 20 at (1739, 900) accepts Parcel 57 for cust 20
# [ 3] 19:30:34.1 Customer 20 at (1739, 900) signs off
# [ 3] 19:30:53.8 Driver drives to Customer 31 at (3101, 260)
# [ 3] 19:37:24.0 Driver arrived at Customer 31 at (3101, 260)
# [ 3] 19:37:35.8 Customer 31 at (3101, 260) answers door
# [ 3] 19:37:35.8 Customer 31 at (3101, 260) accepts Parcel 60 for cust 31
# [ 3] 19:37:40.0 Customer 31 at (3101, 260) signs off
# [ 3] 19:37:52.4 Driver drives to Customer 32 at (3248, 260)
# [ 3] 19:38:27.7 Driver arrived at Customer 32 at (3248, 260)
# [ 3] 19:38:29.5 Customer 32 at (3248, 260) answers door
# [ 3] 19:38:29.5 Customer 32 at (3248, 260) accepts Parcel 61 for cust 32
# [ 3] 19:38:56.7 Customer 32 at (3248, 260) signs off
# [ 3] 19:38:57.5 Driver drives to Customer 37 at (4138, 260)
# [ 3] 19:42:31.1 Driver arrived at Customer 37 at (4138, 260)
# [ 3] 19:42:55.8 Customer 37 at (4138, 260) answers door
# [ 3] 19:42:55.8 Customer 37 at (4138, 260) accepts Parcel 93 for cust 37
# [ 3] 19:43:08.7 Customer 37 at (4138, 260) signs off
# [ 3] 19:43:09.2 Driver drives to Customer 44 at (4609, 260)
# [ 3] 19:45:02.2 Driver arrived at Customer 44 at (4609, 260)
# [ 3] 19:46:02.2 Customer 44 at (4609, 260) not at home
# [ 3] 19:46:02.2 Driver drives to Customer 55 at (5560, 463)
# [ 3] 19:50:39.2 Driver arrived at Customer 55 at (5560, 463)
# [ 3] 19:51:39.2 Customer 55 at (5560, 463) to slow to answer the door
# [ 3] 19:51:39.2 Driver drives to Customer 57 at (5560, 779)
# [ 3] 19:52:55.0 Driver arrived at Customer 57 at (5560, 779)
# [ 3] 19:53:55.0 Customer 57 at (5560, 779) not at home
# [ 3] 19:53:55.0 Driver drives to Customer 65 at (5895, 1320)
# [ 3] 19:57:25.3 Driver arrived at Customer 65 at (5895, 1320)
# [ 3] 19:58:25.3 Customer 65 at (5895, 1320) to slow to answer the door
# [ 3] 19:58:25.3 Driver drives to Customer 90 at (6864, 1320)
# [ 3] 20:02:17.8 Driver arrived at Customer 90 at (6864, 1320)
# [ 3] 20:02:42.5 Customer 90 at (6864, 1320) answers door
# [ 3] 20:02:42.5 Customer 90 at (6864, 1320) accepts Parcel 49 for cust 90
# [ 3] 20:02:43.8 Customer 90 at (6864, 1320) signs off
# [ 3] 20:02:44.6 Driver drives to Customer 74 at (6620, 1882)
# [ 3] 20:05:58.1 Driver arrived at Customer 74 at (6620, 1882)
# [ 3] 20:06:02.2 Customer 74 at (6620, 1882) answers door
# [ 3] 20:06:02.2 Customer 74 at (6620, 1882) accepts Parcel 18 for cust 74
# [ 3] 20:06:16.7 Customer 74 at (6620, 1882) signs off
# [ 3] 20:06:22.1 Driver drives to Customer 76 at (6620, 2144)
# [ 3] 20:07:24.9 Driver arrived at Customer 76 at (6620, 2144)
# [ 3] 20:08:24.9 Customer 76 at (6620, 2144) to slow to answer the door
# [ 3] 20:08:24.9 Driver drives to Customer 77 at (6620, 2458)
# [ 3] 20:09:40.3 Driver arrived at Customer 77 at (6620, 2458)
# [ 3] 20:10:03.5 Customer 77 at (6620, 2458) answers door
# [ 3] 20:10:03.5 Customer 77 at (6620, 2458) accepts Parcel 72 for cust 77
# [ 3] 20:10:04.3 Customer 77 at (6620, 2458) signs off
# [ 3] 20:10:09.9 Driver drives to Customer 78 at (6620, 2616)
# [ 3] 20:10:47.8 Driver arrived at Customer 78 at (6620, 2616)
# [ 3] 20:11:44.1 Customer 78 at (6620, 2616) answers door
# [ 3] 20:11:44.1 Customer 78 at (6620, 2616) accepts Parcel 43 for cust 78
# [ 3] 20:12:01.7 Customer 78 at (6620, 2616) accepts Parcel 73 for cust 78
# [ 3] 20:12:02.1 Customer 78 at (6620, 2616) signs off
# [ 3] 20:12:04.1 Driver drives to Customer 79 at (6620, 2787)
# [ 3] 20:12:45.2 Driver arrived at Customer 79 at (6620, 2787)
# [ 3] 20:13:12.1 Customer 79 at (6620, 2787) answers door
# [ 3] 20:13:12.1 Customer 79 at (6620, 2787) accepts Parcel 44 for cust 79
# [ 3] 20:13:13.5 Customer 79 at (6620, 2787) signs off
# [ 3] 20:13:34.0 Driver drives to Customer 70 at (6201, 2380)
# [ 3] 20:16:52.2 Driver arrived at Customer 70 at (6201, 2380)
# [ 3] 20:17:52.2 Customer 70 at (6201, 2380) to slow to answer the door
# [ 3] 20:17:52.2 Driver drives to Customer 68 at (6038, 2380)
# [ 3] 20:18:31.3 Driver arrived at Customer 68 at (6038, 2380)
# [ 3] 20:18:46.7 Customer 68 at (6038, 2380) answers door
# [ 3] 20:18:46.7 Customer 68 at (6038, 2380) accepts Parcel 15 for cust 68
# [ 3] 20:18:52.4 Customer 68 at (6038, 2380) accepts Parcel 41 for cust 68
# [ 3] 20:19:00.6 Customer 68 at (6038, 2380) accepts Parcel 69 for cust 68
# [ 3] 20:19:03.9 Customer 68 at (6038, 2380) accepts Parcel 98 for cust 68
# [ 3] 20:19:11.7 Customer 68 at (6038, 2380) signs off
# [ 3] 20:19:14.0 Driver drives to Customer 63 at (5756, 2380)
# [ 3] 20:20:21.7 Driver arrived at Customer 63 at (5756, 2380)
# [ 3] 20:21:21.7 Customer 63 at (5756, 2380) not at home
# [ 3] 20:21:21.7 Driver drives to Customer 62 at (5560, 2149)
# [ 3] 20:23:04.1 Driver arrived at Customer 62 at (5560, 2149)
# [ 3] 20:23:18.2 Customer 62 at (5560, 2149) answers door
# [ 3] 20:23:18.2 Customer 62 at (5560, 2149) accepts Parcel 11 for cust 62
# [ 3] 20:23:24.0 Customer 62 at (5560, 2149) accepts Parcel 97 for cust 62
# [ 3] 20:23:33.3 Customer 62 at (5560, 2149) signs off
# [ 3] 20:23:41.0 Driver drives to Customer 61 at (5560, 2022)
# [ 3] 20:24:11.5 Driver arrived at Customer 61 at (5560, 2022)
# [ 3] 20:24:23.6 Customer 61 at (5560, 2022) answers door
# [ 3] 20:24:23.6 Customer 61 at (5560, 2022) accepts Parcel 67 for cust 61
# [ 3] 20:24:26.2 Customer 61 at (5560, 2022) signs off
# [ 3] 20:24:27.5 Driver drives to Customer 60 at (5560, 1879)
# [ 3] 20:25:01.8 Driver arrived at Customer 60 at (5560, 1879)
# [ 3] 20:26:01.8 Customer 60 at (5560, 1879) to slow to answer the door
# [ 3] 20:26:01.8 Driver drives to Customer 59 at (5560, 1672)
# [ 3] 20:26:51.5 Driver arrived at Customer 59 at (5560, 1672)
# [ 3] 20:26:55.7 Customer 59 at (5560, 1672) answers door
# [ 3] 20:26:55.7 Customer 59 at (5560, 1672) accepts Parcel 8 for cust 59
# [ 3] 20:27:08.9 Customer 59 at (5560, 1672) accepts Parcel 9 for cust 59
# [ 3] 20:27:11.7 Customer 59 at (5560, 1672) signs off
# [ 3] 20:27:15.1 Driver drives to Customer 58 at (5560, 1479)
# [ 3] 20:28:01.4 Driver arrived at Customer 58 at (5560, 1479)
# [ 3] 20:28:54.7 Customer 58 at (5560, 1479) answers door
# [ 3] 20:28:54.7 Customer 58 at (5560, 1479) accepts Parcel 37 for cust 58
# [ 3] 20:29:05.4 Customer 58 at (5560, 1479) signs off
# [ 3] 20:29:19.0 Driver returns to delivery centre
# [ 3] 21:38:48.7 Driver arrived at delivery centre
# [ 3] 21:38:48.7 Parcel 59 for cust 28 return from delivery
# [ 3] 21:39:18.7 Parcel 90 for cust 28 return from delivery
# [ 3] 21:39:48.7 Parcel 85 for cust 7 return from delivery
# [ 3] 21:40:18.7 Parcel 63 for cust 44 return from delivery
# [ 3] 21:40:48.7 Parcel 96 for cust 55 return from delivery
# [ 3] 21:41:18.7 Parcel 7 for cust 57 return from delivery
# [ 3] 21:41:48.7 Parcel 36 for cust 57 return from delivery
# [ 3] 21:42:18.7 Parcel 12 for cust 65 return from delivery
# [ 3] 21:42:48.7 Parcel 13 for cust 65 return from delivery
# [ 3] 21:43:18.7 Parcel 102 for cust 76 return from delivery
# [ 3] 21:43:48.7 Parcel 70 for cust 70 return from delivery
# [ 3] 21:44:18.7 Parcel 100 for cust 70 return from delivery
# [ 3] 21:44:48.7 Parcel 101 for cust 70 return from delivery
# [ 3] 21:45:18.7 Parcel 68 for cust 63 return from delivery
# [ 3] 21:45:48.7 Parcel 66 for cust 60 return from delivery
# [ 3] 21:46:18.7 42 parcels left over for next day
# [ 3] 21:56:18.7 Driver goes home
# Delivery Centre Inventory: 42 parcels

# %%
rec2.histTourLength()
rec2.plotTourLength()

# %%
rec3 = simulation(M, W, C, p=0.6, days=100)
# Out:
# Simulating delivery of 5939 parcels over 100 days to 100 customers
# Delivery Centre Inventory: 374 parcels

# %%
rec3.histTourLength()
rec3.plotTourLength()

# %% [markdown]
# ### Using Test Data

# %%
import pickle
with open('testData.pickled', 'rb') as f:
    MX, CX = pickle.load(f)

# %%
WX = generateWarehouseLocation(MX)

# %%
rec4 = simulation(MX, WX, CX, p=0.15, days=7)
# Out:
# Simulating delivery of 14 parcels over 7 days to 20 customers
# Delivery Centre Inventory: 3 parcels

# %%
rec4.histTourLength()
rec4.plotTourLength()

# %%
rec5 = simulation(MX, WX, CX, p=1.2, days=100)
# Out:
# Simulating delivery of 2342 parcels over 100 days to 20 customers
# Delivery Centre Inventory: 15 parcels

# %%
rec5.histTourLength()
rec5.plotTourLength()

# %% [markdown]
# ### Using Full Data

# %%
import pickle
with open('data.pickled', 'rb') as f:
    MM, CC = pickle.load(f)

# %%
WW = generateWarehouseLocation(MM)

# %%
plotMap(MM, T=CC, w=WW, scale=True, grid=True)

# %%
rec6 = simulation(MM, WW, CC, p=0.15, days=50)
# Out:
# Simulating delivery of 761 parcels over 50 days to 100 customers
# Delivery Centre Inventory: 54 parcels

# %%
rec6.histWorkingTime()
rec6.plotWorkingTime()

# %%
rec6.histTourLength()
rec6.plotTourLength()

# %%
rec6.histParcelsArrived()
rec6.histParcelsOutForDelivery()
rec6.histParcelsReturnedFromDelivery()
rec6.histParcelsDelivered()
rec6.histParcelsLeftOver()

# %%
rec6.plotParcelsLeftOver()

# %%
rec6.histParcelDeliveryTime()

# %%
rec7 = simulation(MM, WW, CC, p=0.20, days=100)
# Out:
# Simulating delivery of 1968 parcels over 100 days to 100 customers
# Delivery Centre Inventory: 129 parcels

# %%
rec7.plotWorkingTime()
rec7.plotTourLength()

# %%
rec7.histParcelsArrived()
rec7.histParcelsOutForDelivery()
rec7.histParcelsReturnedFromDelivery()
rec7.histParcelsDelivered()

# %%
rec7.plotParcelsArrived()
rec7.plotParcelsOutForDelivery()
rec7.plotParcelsReturnedFromDelivery()
rec7.plotParcelsDelivered()

# %%
rec7.plotParcelsLeftOver()

# %%
rec7.histParcelDeliveryTime()
